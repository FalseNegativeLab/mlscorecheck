# %%
from mlscorecheck.check import (check_kfold_rom_scores)
from mlscorecheck.core import (IntervalUnion)
from mlscorecheck.utils import (calculate_scores,
                                generate_problems_with_folds)

# %%
k = 4
eps = 10**(-k)

# %%
folds, problem = generate_problems_with_folds(n_repeats=2, 
                                                n_folds=3,
                                                random_seed=5)
problem, folds
# Out:
# ({'p': 869, 'n': 208, 'n_folds': 3, 'n_repeats': 2},
#  [{'p': 290, 'n': 69, 'tp': 190, 'tn': 17},
#   {'p': 290, 'n': 69, 'tp': 74, 'tn': 9},
#   {'p': 289, 'n': 70, 'tp': 229, 'tn': 63},
#   {'p': 290, 'n': 69, 'tp': 113, 'tn': 31},
#   {'p': 290, 'n': 69, 'tp': 209, 'tn': 8},
#   {'p': 289, 'n': 70, 'tp': 205, 'tn': 16}])

# %%
scores = calculate_scores(folds, strategy='rom', rounding_decimals=k)
scores
# Out:
# {'acc': 0.5404,
#  'sens': 0.5869,
#  'spec': 0.3462,
#  'npv': 0.1671,
#  'ppv': 0.7895,
#  'bacc': 0.4665,
#  'f1p': 0.6733,
#  'fm': 0.6807}

# %%
flag, details = check_kfold_rom_scores(scores, 
                                        eps=eps, 
                                        dataset=problem, 
                                        return_details=True)
# Out:
# 2023-08-17 11:10:02,093:INFO:checking acc and sens against spec
# 2023-08-17 11:10:02,094:INFO:checking acc and sens against npv
# 2023-08-17 11:10:02,096:INFO:checking acc and sens against ppv
# 2023-08-17 11:10:02,097:INFO:checking acc and sens against bacc
# 2023-08-17 11:10:02,098:INFO:checking acc and sens against f1p
# 2023-08-17 11:10:02,099:INFO:checking acc and sens against fm
# 2023-08-17 11:10:02,100:INFO:checking acc and spec against sens
# 2023-08-17 11:10:02,101:INFO:checking acc and spec against npv
# 2023-08-17 11:10:02,101:INFO:checking acc and spec against ppv
# 2023-08-17 11:10:02,102:INFO:checking acc and spec against bacc
# 2023-08-17 11:10:02,104:INFO:checking acc and spec against f1p
# 2023-08-17 11:10:02,105:INFO:checking acc and spec against fm
# 2023-08-17 11:10:02,105:INFO:checking acc and npv against sens
# 2023-08-17 11:10:02,106:INFO:checking acc and npv against spec
# 2023-08-17 11:10:02,107:INFO:checking acc and npv against ppv
# 2023-08-17 11:10:02,108:INFO:checking acc and npv against bacc
# 2023-08-17 11:10:02,108:INFO:checking acc and npv against f1p
# 2023-08-17 11:10:02,109:INFO:checking acc and npv against fm
# 2023-08-17 11:10:02,110:INFO:checking acc and ppv against sens
# 2023-08-17 11:10:02,111:INFO:checking acc and ppv against spec
# 2023-08-17 11:10:02,112:INFO:checking acc and ppv against npv
# 2023-08-17 11:10:02,113:INFO:checking acc and ppv against bacc
# 2023-08-17 11:10:02,114:INFO:checking acc and ppv against f1p
# 2023-08-17 11:10:02,115:INFO:checking acc and ppv against fm
# 2023-08-17 11:10:02,116:INFO:checking acc and bacc against sens
# 2023-08-17 11:10:02,117:INFO:checking acc and bacc against spec
# 2023-08-17 11:10:02,118:INFO:checking acc and bacc against npv
# 2023-08-17 11:10:02,118:INFO:checking acc and bacc against ppv
# 2023-08-17 11:10:02,121:INFO:checking acc and bacc against f1p
# 2023-08-17 11:10:02,122:INFO:checking acc and bacc against fm
# 2023-08-17 11:10:02,123:INFO:checking acc and f1p against sens
# 2023-08-17 11:10:02,123:INFO:checking acc and f1p against spec
# 2023-08-17 11:10:02,124:INFO:checking acc and f1p against npv
# 2023-08-17 11:10:02,125:INFO:checking acc and f1p against ppv
# 2023-08-17 11:10:02,129:INFO:checking acc and f1p against bacc
# 2023-08-17 11:10:02,129:INFO:checking acc and f1p against fm
# 2023-08-17 11:10:02,130:INFO:checking acc and fm against sens
# 2023-08-17 11:10:02,132:INFO:checking acc and fm against spec
# 2023-08-17 11:10:02,133:INFO:checking acc and fm against npv
# 2023-08-17 11:10:02,134:INFO:checking acc and fm against ppv
# 2023-08-17 11:10:02,135:INFO:checking acc and fm against bacc
# 2023-08-17 11:10:02,136:INFO:checking acc and fm against f1p
# 2023-08-17 11:10:02,138:INFO:checking sens and spec against acc
# 2023-08-17 11:10:02,139:INFO:checking sens and spec against npv
# 2023-08-17 11:10:02,140:INFO:checking sens and spec against ppv
# 2023-08-17 11:10:02,140:INFO:checking sens and spec against bacc
# 2023-08-17 11:10:02,141:INFO:checking sens and spec against f1p
# 2023-08-17 11:10:02,142:INFO:checking sens and spec against fm
# 2023-08-17 11:10:02,142:INFO:checking sens and npv against acc
# 2023-08-17 11:10:02,145:INFO:checking sens and npv against spec
# 2023-08-17 11:10:02,146:INFO:checking sens and npv against ppv
# 2023-08-17 11:10:02,147:INFO:checking sens and npv against bacc
# 2023-08-17 11:10:02,148:INFO:checking sens and npv against f1p
# 2023-08-17 11:10:02,149:INFO:checking sens and npv against fm
# 2023-08-17 11:10:02,150:INFO:checking sens and ppv against acc
# 2023-08-17 11:10:02,151:INFO:checking sens and ppv against spec
# 2023-08-17 11:10:02,152:INFO:checking sens and ppv against npv
# 2023-08-17 11:10:02,153:INFO:checking sens and ppv against bacc
# 2023-08-17 11:10:02,154:INFO:checking sens and ppv against f1p
# 2023-08-17 11:10:02,154:INFO:checking sens and ppv against fm
# 2023-08-17 11:10:02,157:INFO:checking sens and bacc against acc
# 2023-08-17 11:10:02,158:INFO:checking sens and bacc against spec
# 2023-08-17 11:10:02,159:INFO:checking sens and bacc against npv
# 2023-08-17 11:10:02,159:INFO:checking sens and bacc against ppv
# 2023-08-17 11:10:02,160:INFO:checking sens and bacc against f1p
# 2023-08-17 11:10:02,161:INFO:checking sens and bacc against fm
# 2023-08-17 11:10:02,163:INFO:checking sens and f1p against acc
# 2023-08-17 11:10:02,164:INFO:checking sens and f1p against spec
# 2023-08-17 11:10:02,165:INFO:checking sens and f1p against npv
# 2023-08-17 11:10:02,166:INFO:checking sens and f1p against ppv
# 2023-08-17 11:10:02,167:INFO:checking sens and f1p against bacc
# 2023-08-17 11:10:02,167:INFO:checking sens and f1p against fm
# 2023-08-17 11:10:02,169:INFO:checking sens and fm against acc
# 2023-08-17 11:10:02,170:INFO:checking sens and fm against spec
# 2023-08-17 11:10:02,171:INFO:checking sens and fm against npv
# 2023-08-17 11:10:02,172:INFO:checking sens and fm against ppv
# 2023-08-17 11:10:02,172:INFO:checking sens and fm against bacc
# 2023-08-17 11:10:02,173:INFO:checking sens and fm against f1p
# 2023-08-17 11:10:02,174:INFO:checking spec and npv against acc
# 2023-08-17 11:10:02,175:INFO:checking spec and npv against sens
# 2023-08-17 11:10:02,176:INFO:checking spec and npv against ppv
# 2023-08-17 11:10:02,177:INFO:checking spec and npv against bacc
# 2023-08-17 11:10:02,177:INFO:checking spec and npv against f1p
# 2023-08-17 11:10:02,178:INFO:checking spec and npv against fm
# 2023-08-17 11:10:02,178:INFO:checking spec and ppv against acc
# 2023-08-17 11:10:02,179:INFO:checking spec and ppv against sens
# 2023-08-17 11:10:02,179:INFO:checking spec and ppv against npv
# 2023-08-17 11:10:02,180:INFO:checking spec and ppv against bacc
# 2023-08-17 11:10:02,184:INFO:checking spec and ppv against f1p
# 2023-08-17 11:10:02,185:INFO:checking spec and ppv against fm
# 2023-08-17 11:10:02,186:INFO:checking spec and bacc against acc
# 2023-08-17 11:10:02,187:INFO:checking spec and bacc against sens
# 2023-08-17 11:10:02,188:INFO:checking spec and bacc against npv
# 2023-08-17 11:10:02,189:INFO:checking spec and bacc against ppv
# 2023-08-17 11:10:02,189:INFO:checking spec and bacc against f1p
# 2023-08-17 11:10:02,190:INFO:checking spec and bacc against fm
# 2023-08-17 11:10:02,191:INFO:checking spec and f1p against acc
# 2023-08-17 11:10:02,192:INFO:checking spec and f1p against sens
# 2023-08-17 11:10:02,193:INFO:checking spec and f1p against npv
# 2023-08-17 11:10:02,194:INFO:checking spec and f1p against ppv
# 2023-08-17 11:10:02,194:INFO:checking spec and f1p against bacc
# 2023-08-17 11:10:02,195:INFO:checking spec and f1p against fm
# 2023-08-17 11:10:02,196:INFO:checking spec and fm against acc
# 2023-08-17 11:10:02,197:INFO:checking spec and fm against sens
# 2023-08-17 11:10:02,198:INFO:checking spec and fm against npv
# 2023-08-17 11:10:02,199:INFO:checking spec and fm against ppv
# 2023-08-17 11:10:02,200:INFO:checking spec and fm against bacc
# 2023-08-17 11:10:02,201:INFO:checking spec and fm against f1p
# 2023-08-17 11:10:02,202:INFO:checking npv and ppv against acc
# 2023-08-17 11:10:02,203:INFO:checking npv and ppv against sens
# 2023-08-17 11:10:02,204:INFO:checking npv and ppv against spec
# 2023-08-17 11:10:02,205:INFO:checking npv and ppv against bacc
# 2023-08-17 11:10:02,206:INFO:checking npv and ppv against f1p
# 2023-08-17 11:10:02,207:INFO:checking npv and ppv against fm
# 2023-08-17 11:10:02,207:INFO:checking npv and bacc against acc
# 2023-08-17 11:10:02,208:INFO:checking npv and bacc against sens
# 2023-08-17 11:10:02,210:INFO:checking npv and bacc against spec
# 2023-08-17 11:10:02,210:INFO:checking npv and bacc against ppv
# 2023-08-17 11:10:02,211:INFO:checking npv and bacc against f1p
# 2023-08-17 11:10:02,212:INFO:checking npv and bacc against fm
# 2023-08-17 11:10:02,213:INFO:checking npv and f1p against acc
# 2023-08-17 11:10:02,213:INFO:checking npv and f1p against sens
# 2023-08-17 11:10:02,214:INFO:checking npv and f1p against spec
# 2023-08-17 11:10:02,215:INFO:checking npv and f1p against ppv
# 2023-08-17 11:10:02,216:INFO:checking npv and f1p against bacc
# 2023-08-17 11:10:02,217:INFO:checking npv and f1p against fm
# 2023-08-17 11:10:02,217:INFO:checking npv and fm against acc
# 2023-08-17 11:10:02,219:INFO:checking npv and fm against sens
# 2023-08-17 11:10:02,220:INFO:checking npv and fm against spec
# 2023-08-17 11:10:02,221:INFO:checking npv and fm against ppv
# 2023-08-17 11:10:02,223:INFO:checking npv and fm against bacc
# 2023-08-17 11:10:02,225:INFO:checking npv and fm against f1p
# 2023-08-17 11:10:02,232:INFO:checking ppv and bacc against acc
# 2023-08-17 11:10:02,233:INFO:checking ppv and bacc against sens
# 2023-08-17 11:10:02,234:INFO:checking ppv and bacc against spec
# 2023-08-17 11:10:02,235:INFO:checking ppv and bacc against npv
# 2023-08-17 11:10:02,236:INFO:checking ppv and bacc against f1p
# 2023-08-17 11:10:02,237:INFO:checking ppv and bacc against fm
# 2023-08-17 11:10:02,238:INFO:checking ppv and f1p against acc
# 2023-08-17 11:10:02,238:INFO:checking ppv and f1p against sens
# 2023-08-17 11:10:02,239:INFO:checking ppv and f1p against spec
# 2023-08-17 11:10:02,240:INFO:checking ppv and f1p against npv
# 2023-08-17 11:10:02,242:INFO:checking ppv and f1p against bacc
# 2023-08-17 11:10:02,244:INFO:checking ppv and f1p against fm
# 2023-08-17 11:10:02,245:INFO:checking ppv and fm against acc
# 2023-08-17 11:10:02,246:INFO:checking ppv and fm against sens
# 2023-08-17 11:10:02,247:INFO:checking ppv and fm against spec
# 2023-08-17 11:10:02,248:INFO:checking ppv and fm against npv
# 2023-08-17 11:10:02,250:INFO:checking ppv and fm against bacc
# 2023-08-17 11:10:02,251:INFO:checking ppv and fm against f1p
# 2023-08-17 11:10:02,252:INFO:checking bacc and f1p against acc
# 2023-08-17 11:10:02,253:INFO:checking bacc and f1p against sens
# 2023-08-17 11:10:02,254:INFO:checking bacc and f1p against spec
# 2023-08-17 11:10:02,256:INFO:checking bacc and f1p against npv
# 2023-08-17 11:10:02,257:INFO:checking bacc and f1p against ppv
# 2023-08-17 11:10:02,258:INFO:checking bacc and f1p against fm
# 2023-08-17 11:10:02,258:INFO:checking bacc and fm against acc
# 2023-08-17 11:10:02,260:INFO:checking bacc and fm against sens
# 2023-08-17 11:10:02,262:INFO:checking bacc and fm against spec
# 2023-08-17 11:10:02,264:INFO:checking bacc and fm against npv
# 2023-08-17 11:10:02,266:INFO:checking bacc and fm against ppv
# 2023-08-17 11:10:02,268:INFO:checking bacc and fm against f1p
# 2023-08-17 11:10:02,269:INFO:checking f1p and fm against acc
# 2023-08-17 11:10:02,270:INFO:checking f1p and fm against sens
# 2023-08-17 11:10:02,271:INFO:checking f1p and fm against spec
# 2023-08-17 11:10:02,273:INFO:checking f1p and fm against npv
# 2023-08-17 11:10:02,277:INFO:checking f1p and fm against ppv
# 2023-08-17 11:10:02,278:INFO:checking f1p and fm against bacc

# %%
assert flag

# %%
for tmp in details['succeeded']:
    assert tmp['consistency']
    for item in tmp['details']:
        if item.get('target_interval_reconstructed') is not None and item.get('consistency'):
            target_interval = item['target_interval_reconstructed']
            iun = IntervalUnion(target_interval)
            assert not iun.intersection(IntervalUnion(item['target_interval'])).is_empty()

# %%
scores['bacc'] = 0.9

# %%
flag, details = check_kfold_rom_scores(scores, 
                                        eps=eps, 
                                        dataset=problem, 
                                        return_details=True)
# Out:
# 2023-08-17 11:10:02,344:INFO:checking acc and sens against spec
# 2023-08-17 11:10:02,345:INFO:checking acc and sens against npv
# 2023-08-17 11:10:02,346:INFO:checking acc and sens against ppv
# 2023-08-17 11:10:02,347:INFO:checking acc and sens against bacc
# 2023-08-17 11:10:02,349:INFO:checking acc and sens against f1p
# 2023-08-17 11:10:02,350:INFO:checking acc and sens against fm
# 2023-08-17 11:10:02,351:INFO:checking acc and spec against sens
# 2023-08-17 11:10:02,352:INFO:checking acc and spec against npv
# 2023-08-17 11:10:02,353:INFO:checking acc and spec against ppv
# 2023-08-17 11:10:02,354:INFO:checking acc and spec against bacc
# 2023-08-17 11:10:02,355:INFO:checking acc and spec against f1p
# 2023-08-17 11:10:02,356:INFO:checking acc and spec against fm
# 2023-08-17 11:10:02,358:INFO:checking acc and npv against sens
# 2023-08-17 11:10:02,359:INFO:checking acc and npv against spec
# 2023-08-17 11:10:02,360:INFO:checking acc and npv against ppv
# 2023-08-17 11:10:02,361:INFO:checking acc and npv against bacc
# 2023-08-17 11:10:02,362:INFO:checking acc and npv against f1p
# 2023-08-17 11:10:02,363:INFO:checking acc and npv against fm
# 2023-08-17 11:10:02,364:INFO:checking acc and ppv against sens
# 2023-08-17 11:10:02,364:INFO:checking acc and ppv against spec
# 2023-08-17 11:10:02,365:INFO:checking acc and ppv against npv
# 2023-08-17 11:10:02,366:INFO:checking acc and ppv against bacc
# 2023-08-17 11:10:02,366:INFO:checking acc and ppv against f1p
# 2023-08-17 11:10:02,367:INFO:checking acc and ppv against fm
# 2023-08-17 11:10:02,368:INFO:checking acc and bacc against sens
# 2023-08-17 11:10:02,369:INFO:checking acc and bacc against spec
# 2023-08-17 11:10:02,370:INFO:checking acc and bacc against npv
# 2023-08-17 11:10:02,370:INFO:checking acc and bacc against ppv
# 2023-08-17 11:10:02,371:INFO:checking acc and bacc against f1p
# 2023-08-17 11:10:02,372:INFO:checking acc and bacc against fm
# 2023-08-17 11:10:02,372:INFO:checking acc and f1p against sens
# 2023-08-17 11:10:02,373:INFO:checking acc and f1p against spec
# 2023-08-17 11:10:02,374:INFO:checking acc and f1p against npv
# 2023-08-17 11:10:02,375:INFO:checking acc and f1p against ppv
# 2023-08-17 11:10:02,381:INFO:checking acc and f1p against bacc
# 2023-08-17 11:10:02,382:INFO:checking acc and f1p against fm
# 2023-08-17 11:10:02,383:INFO:checking acc and fm against sens
# 2023-08-17 11:10:02,385:INFO:checking acc and fm against spec
# 2023-08-17 11:10:02,386:INFO:checking acc and fm against npv
# 2023-08-17 11:10:02,388:INFO:checking acc and fm against ppv
# 2023-08-17 11:10:02,389:INFO:checking acc and fm against bacc
# 2023-08-17 11:10:02,390:INFO:checking acc and fm against f1p
# 2023-08-17 11:10:02,391:INFO:checking sens and spec against acc
# 2023-08-17 11:10:02,391:INFO:checking sens and spec against npv
# 2023-08-17 11:10:02,392:INFO:checking sens and spec against ppv
# 2023-08-17 11:10:02,392:INFO:checking sens and spec against bacc
# 2023-08-17 11:10:02,393:INFO:checking sens and spec against f1p
# 2023-08-17 11:10:02,394:INFO:checking sens and spec against fm
# 2023-08-17 11:10:02,395:INFO:checking sens and npv against acc
# 2023-08-17 11:10:02,396:INFO:checking sens and npv against spec
# 2023-08-17 11:10:02,396:INFO:checking sens and npv against ppv
# 2023-08-17 11:10:02,397:INFO:checking sens and npv against bacc
# 2023-08-17 11:10:02,398:INFO:checking sens and npv against f1p
# 2023-08-17 11:10:02,400:INFO:checking sens and npv against fm
# 2023-08-17 11:10:02,401:INFO:checking sens and ppv against acc
# 2023-08-17 11:10:02,401:INFO:checking sens and ppv against spec
# 2023-08-17 11:10:02,402:INFO:checking sens and ppv against npv
# 2023-08-17 11:10:02,403:INFO:checking sens and ppv against bacc
# 2023-08-17 11:10:02,404:INFO:checking sens and ppv against f1p
# 2023-08-17 11:10:02,407:INFO:checking sens and ppv against fm
# 2023-08-17 11:10:02,407:INFO:checking sens and bacc against acc
# 2023-08-17 11:10:02,408:INFO:checking sens and bacc against spec
# 2023-08-17 11:10:02,409:INFO:checking sens and bacc against npv
# 2023-08-17 11:10:02,410:INFO:checking sens and bacc against ppv
# 2023-08-17 11:10:02,410:INFO:checking sens and bacc against f1p
# 2023-08-17 11:10:02,411:INFO:checking sens and bacc against fm
# 2023-08-17 11:10:02,416:INFO:checking sens and f1p against acc
# 2023-08-17 11:10:02,417:INFO:checking sens and f1p against spec
# 2023-08-17 11:10:02,418:INFO:checking sens and f1p against npv
# 2023-08-17 11:10:02,419:INFO:checking sens and f1p against ppv
# 2023-08-17 11:10:02,420:INFO:checking sens and f1p against bacc
# 2023-08-17 11:10:02,421:INFO:checking sens and f1p against fm
# 2023-08-17 11:10:02,422:INFO:checking sens and fm against acc
# 2023-08-17 11:10:02,423:INFO:checking sens and fm against spec
# 2023-08-17 11:10:02,424:INFO:checking sens and fm against npv
# 2023-08-17 11:10:02,425:INFO:checking sens and fm against ppv
# 2023-08-17 11:10:02,427:INFO:checking sens and fm against bacc
# 2023-08-17 11:10:02,429:INFO:checking sens and fm against f1p
# 2023-08-17 11:10:02,430:INFO:checking spec and npv against acc
# 2023-08-17 11:10:02,431:INFO:checking spec and npv against sens
# 2023-08-17 11:10:02,432:INFO:checking spec and npv against ppv
# 2023-08-17 11:10:02,432:INFO:checking spec and npv against bacc
# 2023-08-17 11:10:02,434:INFO:checking spec and npv against f1p
# 2023-08-17 11:10:02,435:INFO:checking spec and npv against fm
# 2023-08-17 11:10:02,436:INFO:checking spec and ppv against acc
# 2023-08-17 11:10:02,436:INFO:checking spec and ppv against sens
# 2023-08-17 11:10:02,437:INFO:checking spec and ppv against npv
# 2023-08-17 11:10:02,438:INFO:checking spec and ppv against bacc
# 2023-08-17 11:10:02,439:INFO:checking spec and ppv against f1p
# 2023-08-17 11:10:02,440:INFO:checking spec and ppv against fm
# 2023-08-17 11:10:02,441:INFO:checking spec and bacc against acc
# 2023-08-17 11:10:02,442:INFO:checking spec and bacc against sens
# 2023-08-17 11:10:02,443:INFO:checking spec and bacc against npv
# 2023-08-17 11:10:02,444:INFO:checking spec and bacc against ppv
# 2023-08-17 11:10:02,444:INFO:checking spec and bacc against f1p
# 2023-08-17 11:10:02,445:INFO:checking spec and bacc against fm
# 2023-08-17 11:10:02,446:INFO:checking spec and f1p against acc
# 2023-08-17 11:10:02,446:INFO:checking spec and f1p against sens
# 2023-08-17 11:10:02,447:INFO:checking spec and f1p against npv
# 2023-08-17 11:10:02,448:INFO:checking spec and f1p against ppv
# 2023-08-17 11:10:02,448:INFO:checking spec and f1p against bacc
# 2023-08-17 11:10:02,449:INFO:checking spec and f1p against fm
# 2023-08-17 11:10:02,450:INFO:checking spec and fm against acc
# 2023-08-17 11:10:02,451:INFO:checking spec and fm against sens
# 2023-08-17 11:10:02,452:INFO:checking spec and fm against npv
# 2023-08-17 11:10:02,453:INFO:checking spec and fm against ppv
# 2023-08-17 11:10:02,454:INFO:checking spec and fm against bacc
# 2023-08-17 11:10:02,455:INFO:checking spec and fm against f1p
# 2023-08-17 11:10:02,455:INFO:checking npv and ppv against acc
# 2023-08-17 11:10:02,456:INFO:checking npv and ppv against sens
# 2023-08-17 11:10:02,457:INFO:checking npv and ppv against spec
# 2023-08-17 11:10:02,458:INFO:checking npv and ppv against bacc
# 2023-08-17 11:10:02,459:INFO:checking npv and ppv against f1p
# 2023-08-17 11:10:02,459:INFO:checking npv and ppv against fm
# 2023-08-17 11:10:02,460:INFO:checking npv and bacc against acc
# 2023-08-17 11:10:02,461:INFO:checking npv and bacc against sens
# 2023-08-17 11:10:02,461:INFO:checking npv and bacc against spec
# 2023-08-17 11:10:02,462:INFO:checking npv and bacc against ppv
# 2023-08-17 11:10:02,463:INFO:checking npv and bacc against f1p
# 2023-08-17 11:10:02,466:INFO:checking npv and bacc against fm
# 2023-08-17 11:10:02,467:INFO:checking npv and f1p against acc
# 2023-08-17 11:10:02,468:INFO:checking npv and f1p against sens
# 2023-08-17 11:10:02,470:INFO:checking npv and f1p against spec
# 2023-08-17 11:10:02,472:INFO:checking npv and f1p against ppv
# 2023-08-17 11:10:02,473:INFO:checking npv and f1p against bacc
# 2023-08-17 11:10:02,474:INFO:checking npv and f1p against fm
# 2023-08-17 11:10:02,475:INFO:checking npv and fm against acc
# 2023-08-17 11:10:02,477:INFO:checking npv and fm against sens
# 2023-08-17 11:10:02,478:INFO:checking npv and fm against spec
# 2023-08-17 11:10:02,480:INFO:checking npv and fm against ppv
# 2023-08-17 11:10:02,482:INFO:checking npv and fm against bacc
# 2023-08-17 11:10:02,483:INFO:checking npv and fm against f1p
# 2023-08-17 11:10:02,485:INFO:checking ppv and bacc against acc
# 2023-08-17 11:10:02,486:INFO:checking ppv and bacc against sens
# 2023-08-17 11:10:02,486:INFO:checking ppv and bacc against spec
# 2023-08-17 11:10:02,487:INFO:checking ppv and bacc against npv
# 2023-08-17 11:10:02,488:INFO:checking ppv and bacc against f1p
# 2023-08-17 11:10:02,489:INFO:checking ppv and bacc against fm
# 2023-08-17 11:10:02,489:INFO:checking ppv and f1p against acc
# 2023-08-17 11:10:02,490:INFO:checking ppv and f1p against sens
# 2023-08-17 11:10:02,491:INFO:checking ppv and f1p against spec
# 2023-08-17 11:10:02,495:INFO:checking ppv and f1p against npv
# 2023-08-17 11:10:02,496:INFO:checking ppv and f1p against bacc
# 2023-08-17 11:10:02,497:INFO:checking ppv and f1p against fm
# 2023-08-17 11:10:02,497:INFO:checking ppv and fm against acc
# 2023-08-17 11:10:02,498:INFO:checking ppv and fm against sens
# 2023-08-17 11:10:02,499:INFO:checking ppv and fm against spec
# 2023-08-17 11:10:02,500:INFO:checking ppv and fm against npv
# 2023-08-17 11:10:02,502:INFO:checking ppv and fm against bacc
# 2023-08-17 11:10:02,503:INFO:checking ppv and fm against f1p
# 2023-08-17 11:10:02,504:INFO:checking bacc and f1p against acc
# 2023-08-17 11:10:02,505:INFO:checking bacc and f1p against sens
# 2023-08-17 11:10:02,506:INFO:checking bacc and f1p against spec
# 2023-08-17 11:10:02,507:INFO:checking bacc and f1p against npv
# 2023-08-17 11:10:02,508:INFO:checking bacc and f1p against ppv
# 2023-08-17 11:10:02,509:INFO:checking bacc and f1p against fm
# 2023-08-17 11:10:02,510:INFO:checking bacc and fm against acc
# 2023-08-17 11:10:02,510:INFO:checking bacc and fm against sens
# 2023-08-17 11:10:02,511:INFO:checking bacc and fm against spec
# 2023-08-17 11:10:02,514:INFO:checking bacc and fm against npv
# 2023-08-17 11:10:02,514:INFO:checking bacc and fm against ppv
# 2023-08-17 11:10:02,515:INFO:checking bacc and fm against f1p
# 2023-08-17 11:10:02,516:INFO:checking f1p and fm against acc
# 2023-08-17 11:10:02,518:INFO:checking f1p and fm against sens
# 2023-08-17 11:10:02,520:INFO:checking f1p and fm against spec
# 2023-08-17 11:10:02,521:INFO:checking f1p and fm against npv
# 2023-08-17 11:10:02,523:INFO:checking f1p and fm against ppv
# 2023-08-17 11:10:02,524:INFO:checking f1p and fm against bacc

# %%
assert not flag
