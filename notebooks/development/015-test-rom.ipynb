# %%
import numpy as np

from mlscorecheck.check import (check_scores,
                                check_kfold_rom_scores,
                                check_multiple_datasets_rom_kfold_rom_scores)

from mlscorecheck.core import (score_functions_with_solutions,
                                load_solutions,
                                Interval,
                                IntervalUnion)

from mlscorecheck.utils import (generate_problem,
                                generate_n_problems,
                                calculate_scores_rom,
                                generate_folding_problem,
                                calculate_all_scores)

# %%
help(check_scores)
# Out:
# Help on function check_scores in module mlscorecheck.check._check_scores:
#
# check_scores(scores, eps, dataset, *, return_details=False)
#     Use for one dataset - based on the solution formulas

# %%
k = 4
eps = 10**(-k)

problem = generate_problem()

problem, eps
# Out:
# ({'p': 350, 'n': 491, 'tp': 28, 'tn': 411, 'fp': 80, 'fn': 322}, 0.0001)

# %%
scores = calculate_all_scores(problem, rounding_decimals=k)
scores
# Out:
# {'acc': 0.522,
#  'sens': 0.08,
#  'spec': 0.8371,
#  'npv': 0.5607,
#  'ppv': 0.2593,
#  'bacc': 0.4585,
#  'f1p': 0.1223,
#  'fm': 0.144}

# %%
flag, details = check_scores(scores, eps, problem, return_details=True)
# Out:
# 2023-08-14 12:12:52,072:INFO:checking acc and sens against spec
# 2023-08-14 12:12:52,075:INFO:checking acc and sens against npv
# 2023-08-14 12:12:52,077:INFO:checking acc and sens against ppv
# 2023-08-14 12:12:52,078:INFO:checking acc and sens against bacc
# 2023-08-14 12:12:52,080:INFO:checking acc and sens against f1p
# 2023-08-14 12:12:52,082:INFO:checking acc and sens against fm
# 2023-08-14 12:12:52,084:INFO:checking acc and spec against sens
# 2023-08-14 12:12:52,086:INFO:checking acc and spec against npv
# 2023-08-14 12:12:52,089:INFO:checking acc and spec against ppv
# 2023-08-14 12:12:52,090:INFO:checking acc and spec against bacc
# 2023-08-14 12:12:52,091:INFO:checking acc and spec against f1p
# 2023-08-14 12:12:52,093:INFO:checking acc and spec against fm
# 2023-08-14 12:12:52,094:INFO:checking acc and npv against sens
# 2023-08-14 12:12:52,096:INFO:checking acc and npv against spec
# 2023-08-14 12:12:52,099:INFO:checking acc and npv against ppv
# 2023-08-14 12:12:52,101:INFO:checking acc and npv against bacc
# 2023-08-14 12:12:52,102:INFO:checking acc and npv against f1p
# 2023-08-14 12:12:52,104:INFO:checking acc and npv against fm
# 2023-08-14 12:12:52,106:INFO:checking acc and ppv against sens
# 2023-08-14 12:12:52,108:INFO:checking acc and ppv against spec
# 2023-08-14 12:12:52,113:INFO:checking acc and ppv against npv
# 2023-08-14 12:12:52,114:INFO:checking acc and ppv against bacc
# 2023-08-14 12:12:52,116:INFO:checking acc and ppv against f1p
# 2023-08-14 12:12:52,117:INFO:checking acc and ppv against fm
# 2023-08-14 12:12:52,120:INFO:checking acc and bacc against sens
# 2023-08-14 12:12:52,122:INFO:checking acc and bacc against spec
# 2023-08-14 12:12:52,123:INFO:checking acc and bacc against npv
# 2023-08-14 12:12:52,125:INFO:checking acc and bacc against ppv
# 2023-08-14 12:12:52,128:INFO:checking acc and bacc against f1p
# 2023-08-14 12:12:52,131:INFO:checking acc and bacc against fm
# 2023-08-14 12:12:52,133:INFO:checking acc and f1p against sens
# 2023-08-14 12:12:52,135:INFO:checking acc and f1p against spec
# 2023-08-14 12:12:52,140:INFO:checking acc and f1p against npv
# 2023-08-14 12:12:52,142:INFO:checking acc and f1p against ppv
# 2023-08-14 12:12:52,148:INFO:checking acc and f1p against bacc
# 2023-08-14 12:12:52,150:INFO:checking acc and f1p against fm
# 2023-08-14 12:12:52,153:INFO:checking acc and fm against sens
# 2023-08-14 12:12:52,156:INFO:checking acc and fm against spec
# 2023-08-14 12:12:52,159:INFO:checking acc and fm against npv
# 2023-08-14 12:12:52,161:INFO:checking acc and fm against ppv
# 2023-08-14 12:12:52,164:INFO:checking acc and fm against bacc
# 2023-08-14 12:12:52,168:INFO:checking acc and fm against f1p
# 2023-08-14 12:12:52,171:INFO:checking sens and spec against acc
# 2023-08-14 12:12:52,173:INFO:checking sens and spec against npv
# 2023-08-14 12:12:52,174:INFO:checking sens and spec against ppv
# 2023-08-14 12:12:52,179:INFO:checking sens and spec against bacc
# 2023-08-14 12:12:52,182:INFO:checking sens and spec against f1p
# 2023-08-14 12:12:52,185:INFO:checking sens and spec against fm
# 2023-08-14 12:12:52,187:INFO:checking sens and npv against acc
# 2023-08-14 12:12:52,190:INFO:checking sens and npv against spec
# 2023-08-14 12:12:52,192:INFO:checking sens and npv against ppv
# 2023-08-14 12:12:52,194:INFO:checking sens and npv against bacc
# 2023-08-14 12:12:52,195:INFO:checking sens and npv against f1p
# 2023-08-14 12:12:52,197:INFO:checking sens and npv against fm
# 2023-08-14 12:12:52,198:INFO:checking sens and ppv against acc
# 2023-08-14 12:12:52,200:INFO:checking sens and ppv against spec
# 2023-08-14 12:12:52,201:INFO:checking sens and ppv against npv
# 2023-08-14 12:12:52,203:INFO:checking sens and ppv against bacc
# 2023-08-14 12:12:52,204:INFO:checking sens and ppv against f1p
# 2023-08-14 12:12:52,205:INFO:checking sens and ppv against fm
# 2023-08-14 12:12:52,207:INFO:checking sens and bacc against acc
# 2023-08-14 12:12:52,208:INFO:checking sens and bacc against spec
# 2023-08-14 12:12:52,209:INFO:checking sens and bacc against npv
# 2023-08-14 12:12:52,218:INFO:checking sens and bacc against ppv
# 2023-08-14 12:12:52,220:INFO:checking sens and bacc against f1p
# 2023-08-14 12:12:52,222:INFO:checking sens and bacc against fm
# 2023-08-14 12:12:52,223:INFO:checking sens and f1p against acc
# 2023-08-14 12:12:52,224:INFO:checking sens and f1p against spec
# 2023-08-14 12:12:52,226:INFO:checking sens and f1p against npv
# 2023-08-14 12:12:52,227:INFO:checking sens and f1p against ppv
# 2023-08-14 12:12:52,236:INFO:checking sens and f1p against bacc
# 2023-08-14 12:12:52,238:INFO:checking sens and f1p against fm
# 2023-08-14 12:12:52,240:INFO:checking sens and fm against acc
# 2023-08-14 12:12:52,241:INFO:checking sens and fm against spec
# 2023-08-14 12:12:52,243:INFO:checking sens and fm against npv
# 2023-08-14 12:12:52,244:INFO:checking sens and fm against ppv
# 2023-08-14 12:12:52,253:INFO:checking sens and fm against bacc
# 2023-08-14 12:12:52,256:INFO:checking sens and fm against f1p
# 2023-08-14 12:12:52,257:INFO:checking spec and npv against acc
# 2023-08-14 12:12:52,261:INFO:checking spec and npv against sens
# 2023-08-14 12:12:52,262:INFO:checking spec and npv against ppv
# 2023-08-14 12:12:52,264:INFO:checking spec and npv against bacc
# 2023-08-14 12:12:52,265:INFO:checking spec and npv against f1p
# 2023-08-14 12:12:52,267:INFO:checking spec and npv against fm
# 2023-08-14 12:12:52,268:INFO:checking spec and ppv against acc
# 2023-08-14 12:12:52,270:INFO:checking spec and ppv against sens
# 2023-08-14 12:12:52,279:INFO:checking spec and ppv against npv
# 2023-08-14 12:12:52,281:INFO:checking spec and ppv against bacc
# 2023-08-14 12:12:52,283:INFO:checking spec and ppv against f1p
# 2023-08-14 12:12:52,284:INFO:checking spec and ppv against fm
# 2023-08-14 12:12:52,286:INFO:checking spec and bacc against acc
# 2023-08-14 12:12:52,287:INFO:checking spec and bacc against sens
# 2023-08-14 12:12:52,288:INFO:checking spec and bacc against npv
# 2023-08-14 12:12:52,291:INFO:checking spec and bacc against ppv
# 2023-08-14 12:12:52,296:INFO:checking spec and bacc against f1p
# 2023-08-14 12:12:52,302:INFO:checking spec and bacc against fm
# 2023-08-14 12:12:52,304:INFO:checking spec and f1p against acc
# 2023-08-14 12:12:52,306:INFO:checking spec and f1p against sens
# 2023-08-14 12:12:52,307:INFO:checking spec and f1p against npv
# 2023-08-14 12:12:52,309:INFO:checking spec and f1p against ppv
# 2023-08-14 12:12:52,310:INFO:checking spec and f1p against bacc
# 2023-08-14 12:12:52,311:INFO:checking spec and f1p against fm
# 2023-08-14 12:12:52,313:INFO:checking spec and fm against acc
# 2023-08-14 12:12:52,314:INFO:checking spec and fm against sens
# 2023-08-14 12:12:52,315:INFO:checking spec and fm against npv
# 2023-08-14 12:12:52,316:INFO:checking spec and fm against ppv
# 2023-08-14 12:12:52,318:INFO:checking spec and fm against bacc
# 2023-08-14 12:12:52,319:INFO:checking spec and fm against f1p
# 2023-08-14 12:12:52,320:INFO:checking npv and ppv against acc
# 2023-08-14 12:12:52,321:INFO:checking npv and ppv against sens
# 2023-08-14 12:12:52,322:INFO:checking npv and ppv against spec
# 2023-08-14 12:12:52,326:INFO:checking npv and ppv against bacc
# 2023-08-14 12:12:52,327:INFO:checking npv and ppv against f1p
# 2023-08-14 12:12:52,329:INFO:checking npv and ppv against fm
# 2023-08-14 12:12:52,330:INFO:checking npv and bacc against acc
# 2023-08-14 12:12:52,332:INFO:checking npv and bacc against sens
# 2023-08-14 12:12:52,332:INFO:checking npv and bacc against spec
# 2023-08-14 12:12:52,333:INFO:checking npv and bacc against ppv
# 2023-08-14 12:12:52,335:INFO:checking npv and bacc against f1p
# 2023-08-14 12:12:52,336:INFO:checking npv and bacc against fm
# 2023-08-14 12:12:52,336:INFO:checking npv and f1p against acc
# 2023-08-14 12:12:52,337:INFO:checking npv and f1p against sens
# 2023-08-14 12:12:52,338:INFO:checking npv and f1p against spec
# 2023-08-14 12:12:52,339:INFO:checking npv and f1p against ppv
# 2023-08-14 12:12:52,341:INFO:checking npv and f1p against bacc
# 2023-08-14 12:12:52,341:INFO:checking npv and f1p against fm
# 2023-08-14 12:12:52,343:INFO:checking npv and fm against acc
# 2023-08-14 12:12:52,344:INFO:checking npv and fm against sens
# 2023-08-14 12:12:52,346:INFO:checking npv and fm against spec
# 2023-08-14 12:12:52,348:INFO:checking npv and fm against ppv
# 2023-08-14 12:12:52,349:INFO:checking npv and fm against bacc
# 2023-08-14 12:12:52,351:INFO:checking npv and fm against f1p
# 2023-08-14 12:12:52,354:INFO:checking ppv and bacc against acc
# 2023-08-14 12:12:52,355:INFO:checking ppv and bacc against sens
# 2023-08-14 12:12:52,356:INFO:checking ppv and bacc against spec
# 2023-08-14 12:12:52,358:INFO:checking ppv and bacc against npv
# 2023-08-14 12:12:52,362:INFO:checking ppv and bacc against f1p
# 2023-08-14 12:12:52,363:INFO:checking ppv and bacc against fm
# 2023-08-14 12:12:52,364:INFO:checking ppv and f1p against acc
# 2023-08-14 12:12:52,365:INFO:checking ppv and f1p against sens
# 2023-08-14 12:12:52,366:INFO:checking ppv and f1p against spec
# 2023-08-14 12:12:52,367:INFO:checking ppv and f1p against npv
# 2023-08-14 12:12:52,368:INFO:checking ppv and f1p against bacc
# 2023-08-14 12:12:52,369:INFO:checking ppv and f1p against fm
# 2023-08-14 12:12:52,370:INFO:checking ppv and fm against acc
# 2023-08-14 12:12:52,371:INFO:checking ppv and fm against sens
# 2023-08-14 12:12:52,372:INFO:checking ppv and fm against spec
# 2023-08-14 12:12:52,373:INFO:checking ppv and fm against npv
# 2023-08-14 12:12:52,374:INFO:checking ppv and fm against bacc
# 2023-08-14 12:12:52,376:INFO:checking ppv and fm against f1p
# 2023-08-14 12:12:52,377:INFO:checking bacc and f1p against acc
# 2023-08-14 12:12:52,378:INFO:checking bacc and f1p against sens
# 2023-08-14 12:12:52,382:INFO:checking bacc and f1p against spec
# 2023-08-14 12:12:52,384:INFO:checking bacc and f1p against npv
# 2023-08-14 12:12:52,387:INFO:checking bacc and f1p against ppv
# 2023-08-14 12:12:52,388:INFO:checking bacc and f1p against fm
# 2023-08-14 12:12:52,390:INFO:checking bacc and fm against acc
# 2023-08-14 12:12:52,395:INFO:checking bacc and fm against sens
# 2023-08-14 12:12:52,397:INFO:checking bacc and fm against spec
# 2023-08-14 12:12:52,401:INFO:checking bacc and fm against npv
# 2023-08-14 12:12:52,404:INFO:checking bacc and fm against ppv
# 2023-08-14 12:12:52,406:INFO:checking bacc and fm against f1p
# 2023-08-14 12:12:52,409:INFO:checking f1p and fm against acc
# 2023-08-14 12:12:52,412:INFO:checking f1p and fm against sens
# 2023-08-14 12:12:52,416:INFO:checking f1p and fm against spec
# 2023-08-14 12:12:52,423:INFO:checking f1p and fm against npv
# 2023-08-14 12:12:52,426:INFO:checking f1p and fm against ppv
# 2023-08-14 12:12:52,428:INFO:checking f1p and fm against bacc

# %%
details
# Out:
# {'succeeded': [{'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'sens',
#      'score_1_interval': (0.0799, 0.0801),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.8829, 411.12110000000007),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'acc*n + acc*p - p*sens'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.836828716904277, 0.8373138492871692)) do intersect',
#      'target_interval_reconstructed': (0.836828716904277,
#       0.8373138492871692)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'sens',
#      'score_1_interval': (0.0799, 0.0801),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.8829, 411.12110000000007),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'acc*n + acc*p - p*sens'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5604303094525163, 0.5609910323820263)) do intersect',
#      'target_interval_reconstructed': (0.5604303094525163,
#       0.5609910323820263)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'sens',
#      'score_1_interval': (0.0799, 0.0801),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.8829, 411.12110000000007),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'acc*n + acc*p - p*sens'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.25857103098321726, 0.2599590704713016)) do intersect',
#      'target_interval_reconstructed': (0.25857103098321726,
#       0.2599590704713016)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'sens',
#      'score_1_interval': (0.0799, 0.0801),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.8829, 411.12110000000007),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'acc*n + acc*p - p*sens'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.45836435845213847, 0.45870692464358465)) do intersect',
#      'target_interval_reconstructed': (0.45836435845213847,
#       0.45870692464358465)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'sens',
#      'score_1_interval': (0.0799, 0.0801),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.8829, 411.12110000000007),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'acc*n + acc*p - p*sens'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.12207736251781884, 0.12246532060381282)) do intersect',
#      'target_interval_reconstructed': (0.12207736251781884,
#       0.12246532060381282)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'sens',
#      'score_1_interval': (0.0799, 0.0801),
#      'target_score': 'fm',
#      'target_interval': (0.1439, 0.14409999999999998),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.8829, 411.12110000000007),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'acc*n + acc*p - p*sens'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1439, 0.14409999999999998)) and the reconstructed intervals ((0.1437352614202898, 0.1443008023011351)) do intersect',
#      'target_interval_reconstructed': (0.1437352614202898,
#       0.1443008023011351)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tn': (410.967, 411.06519999999995),
#       'tp': (27.852700000000084, 28.11910000000006),
#       'tp_formula': 'acc*n + acc*p - n*spec',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.0799, 0.0801)) and the reconstructed intervals ((0.0795791428571431, 0.08034028571428589)) do intersect',
#      'target_interval_reconstructed': (0.0795791428571431,
#       0.08034028571428589)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tn': (410.967, 411.06519999999995),
#       'tp': (27.852700000000084, 28.11910000000006),
#       'tp_formula': 'acc*n + acc*p - n*spec',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5605019008813953, 0.5609147546168857)) do intersect',
#      'target_interval_reconstructed': (0.5605019008813953,
#       0.5609147546168857)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tn': (410.967, 411.06519999999995),
#       'tp': (27.852700000000084, 28.11910000000006),
#       'tp_formula': 'acc*n + acc*p - n*spec',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.25753267851479583, 0.26087533341064606)) do intersect',
#      'target_interval_reconstructed': (0.25753267851479583,
#       0.26087533341064606)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tn': (410.967, 411.06519999999995),
#       'tp': (27.852700000000084, 28.11910000000006),
#       'tp_formula': 'acc*n + acc*p - n*spec',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.4582895714285715, 0.4587701428571429)) do intersect',
#      'target_interval_reconstructed': (0.4582895714285715,
#       0.4587701428571429)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tn': (410.967, 411.06519999999995),
#       'tp': (27.852700000000084, 28.11910000000006),
#       'tp_formula': 'acc*n + acc*p - n*spec',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.12158713230824468, 0.1228478278677336)) do intersect',
#      'target_interval_reconstructed': (0.12158713230824468,
#       0.1228478278677336)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'fm',
#      'target_interval': (0.1439, 0.14409999999999998),
#      'solution': {'tn': (410.967, 411.06519999999995),
#       'tp': (27.852700000000084, 28.11910000000006),
#       'tp_formula': 'acc*n + acc*p - n*spec',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1439, 0.14409999999999998)) and the reconstructed intervals ((0.143158058850739, 0.14477154009687437)) do intersect',
#      'target_interval_reconstructed': (0.143158058850739,
#       0.14477154009687437)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tp': (26.161798848683926, 29.716046864686398),
#       'tn': (409.92906858552664, 412.206970957096),
#       'tp_formula': '(acc*n*npv + acc*npv*p - acc*n - acc*p + npv*p)/(2*npv - 1)',
#       'tn_formula': '(acc*n + acc*p - p)*npv/(2*npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.0799, 0.0801)) and the reconstructed intervals ((0.0747479967105255, 0.08490299104196114)) do intersect',
#      'target_interval_reconstructed': (0.0747479967105255,
#       0.08490299104196114)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (26.161798848683926, 29.716046864686398),
#       'tn': (409.92906858552664, 412.206970957096),
#       'tp_formula': '(acc*n*npv + acc*npv*p - acc*n - acc*p + npv*p)/(2*npv - 1)',
#       'tn_formula': '(acc*n + acc*p - p)*npv/(2*npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.8348860867322335, 0.8395253990979552)) do intersect',
#      'target_interval_reconstructed': (0.8348860867322335,
#       0.8395253990979552)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (26.161798848683926, 29.716046864686398),
#       'tn': (409.92906858552664, 412.206970957096),
#       'tp_formula': '(acc*n*npv + acc*npv*p - acc*n - acc*p + npv*p)/(2*npv - 1)',
#       'tn_formula': '(acc*n + acc*p - p)*npv/(2*npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.23614507097360957, 0.2831317764189114)) do intersect',
#      'target_interval_reconstructed': (0.23614507097360957,
#       0.2831317764189114)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (26.161798848683926, 29.716046864686398),
#       'tn': (409.92906858552664, 412.206970957096),
#       'tp_formula': '(acc*n*npv + acc*npv*p - acc*n - acc*p + npv*p)/(2*npv - 1)',
#       'tn_formula': '(acc*n + acc*p - p)*npv/(2*npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.4548170417213795, 0.4622141950699582)) do intersect',
#      'target_interval_reconstructed': (0.4548170417213795,
#       0.4622141950699582)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (26.161798848683926, 29.716046864686398),
#       'tn': (409.92906858552664, 412.206970957096),
#       'tp_formula': '(acc*n*npv + acc*npv*p - acc*n - acc*p + npv*p)/(2*npv - 1)',
#       'tn_formula': '(acc*n + acc*p - p)*npv/(2*npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.11355268304840965, 0.13063295537449485)) do intersect',
#      'target_interval_reconstructed': (0.11355268304840965,
#       0.13063295537449485)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'fm',
#      'target_interval': (0.1439, 0.14409999999999998),
#      'solution': {'tp': (26.161798848683926, 29.716046864686398),
#       'tn': (409.92906858552664, 412.206970957096),
#       'tp_formula': '(acc*n*npv + acc*npv*p - acc*n - acc*p + npv*p)/(2*npv - 1)',
#       'tn_formula': '(acc*n + acc*p - p)*npv/(2*npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1439, 0.14409999999999998)) and the reconstructed intervals ((0.1328584622383617, 0.1550442990792934)) do intersect',
#      'target_interval_reconstructed': (0.1328584622383617,
#       0.1550442990792934)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tp': (27.940371428571403, 28.07584526184536),
#       'tn': (410.41022769933573, 411.5780970906068),
#       'tp_formula': '(acc*n + acc*p - n)*ppv/(2*ppv - 1)',
#       'tn_formula': '(acc*n*ppv + acc*p*ppv - acc*n - acc*p + n*ppv)/(2*ppv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.0799, 0.0801)) and the reconstructed intervals ((0.07982963265306116, 0.0802167007481296)) do intersect',
#      'target_interval_reconstructed': (0.07982963265306116,
#       0.0802167007481296)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.940371428571403, 28.07584526184536),
#       'tn': (410.41022769933573, 411.5780970906068),
#       'tp_formula': '(acc*n + acc*p - n)*ppv/(2*ppv - 1)',
#       'tn_formula': '(acc*n*ppv + acc*p*ppv - acc*n - acc*p + n*ppv)/(2*ppv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.8358660441941664, 0.8382445969258794)) do intersect',
#      'target_interval_reconstructed': (0.8358660441941664,
#       0.8382445969258794)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.940371428571403, 28.07584526184536),
#       'tn': (410.41022769933573, 411.5780970906068),
#       'tp_formula': '(acc*n + acc*p - n)*ppv/(2*ppv - 1)',
#       'tn_formula': '(acc*n*ppv + acc*p*ppv - acc*n - acc*p + n*ppv)/(2*ppv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5594181069805008, 0.5620084307945731)) do intersect',
#      'target_interval_reconstructed': (0.5594181069805008,
#       0.5620084307945731)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (27.940371428571403, 28.07584526184536),
#       'tn': (410.41022769933573, 411.5780970906068),
#       'tp_formula': '(acc*n + acc*p - n)*ppv/(2*ppv - 1)',
#       'tn_formula': '(acc*n*ppv + acc*p*ppv - acc*n - acc*p + n*ppv)/(2*ppv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.4578478384236138, 0.4592306488370045)) do intersect',
#      'target_interval_reconstructed': (0.4578478384236138,
#       0.4592306488370045)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (27.940371428571403, 28.07584526184536),
#       'tn': (410.41022769933573, 411.5780970906068),
#       'tp_formula': '(acc*n + acc*p - n)*ppv/(2*ppv - 1)',
#       'tn_formula': '(acc*n*ppv + acc*p*ppv - acc*n - acc*p + n*ppv)/(2*ppv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.12183329361836687, 0.1227728950862218)) do intersect',
#      'target_interval_reconstructed': (0.12183329361836687,
#       0.1227728950862218)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'fm',
#      'target_interval': (0.1439, 0.14409999999999998),
#      'solution': {'tp': (27.940371428571403, 28.07584526184536),
#       'tn': (410.41022769933573, 411.5780970906068),
#       'tp_formula': '(acc*n + acc*p - n)*ppv/(2*ppv - 1)',
#       'tn_formula': '(acc*n*ppv + acc*p*ppv - acc*n - acc*p + n*ppv)/(2*ppv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1439, 0.14409999999999998)) and the reconstructed intervals ((0.14326894957812128, 0.1448348141955381)) do intersect',
#      'target_interval_reconstructed': (0.14326894957812128,
#       0.1448348141955381)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'bacc',
#      'score_1_interval': (0.45840000000000003, 0.4586),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tp': (27.46060283687945, 28.365638297872344),
#       'tn': (410.55226170212785, 411.62549716312077),
#       'tp_formula': '-(acc*n - 2*bacc*n + acc*p)*p/(n - p)',
#       'tn_formula': '(acc*n + acc*p - 2*bacc*p)*n/(n - p)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.0799, 0.0801)) and the reconstructed intervals ((0.078458865248227, 0.08104468085106384)) do intersect',
#      'target_interval_reconstructed': (0.078458865248227,
#       0.08104468085106384)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'bacc',
#      'score_1_interval': (0.45840000000000003, 0.4586),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.46060283687945, 28.365638297872344),
#       'tn': (410.55226170212785, 411.62549716312077),
#       'tp_formula': '-(acc*n - 2*bacc*n + acc*p)*p/(n - p)',
#       'tn_formula': '(acc*n + acc*p - 2*bacc*p)*n/(n - p)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.8361553191489366, 0.8383411347517734)) do intersect',
#      'target_interval_reconstructed': (0.8361553191489366,
#       0.8383411347517734)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'bacc',
#      'score_1_interval': (0.45840000000000003, 0.4586),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.46060283687945, 28.365638297872344),
#       'tn': (410.55226170212785, 411.62549716312077),
#       'tp_formula': '-(acc*n - 2*bacc*n + acc*p)*p/(n - p)',
#       'tn_formula': '(acc*n + acc*p - 2*bacc*p)*n/(n - p)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5592098789726256, 0.5621865846842352)) do intersect',
#      'target_interval_reconstructed': (0.5592098789726256,
#       0.5621865846842352)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'bacc',
#      'score_1_interval': (0.45840000000000003, 0.4586),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (27.46060283687945, 28.365638297872344),
#       'tn': (410.55226170212785, 411.62549716312077),
#       'tp_formula': '-(acc*n - 2*bacc*n + acc*p)*p/(n - p)',
#       'tn_formula': '(acc*n + acc*p - 2*bacc*p)*n/(n - p)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.2523642193266281, 0.2655085902614465)) do intersect',
#      'target_interval_reconstructed': (0.2523642193266281,
#       0.2655085902614465)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'bacc',
#      'score_1_interval': (0.45840000000000003, 0.4586),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (27.46060283687945, 28.365638297872344),
#       'tn': (410.55226170212785, 411.62549716312077),
#       'tp_formula': '-(acc*n - 2*bacc*n + acc*p)*p/(n - p)',
#       'tn_formula': '(acc*n + acc*p - 2*bacc*p)*n/(n - p)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.11970271242145884, 0.12418326851671162)) do intersect',
#      'target_interval_reconstructed': (0.11970271242145884,
#       0.12418326851671162)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'bacc',
#      'score_1_interval': (0.45840000000000003, 0.4586),
#      'target_score': 'fm',
#      'target_interval': (0.1439, 0.14409999999999998),
#      'solution': {'tp': (27.46060283687945, 28.365638297872344),
#       'tn': (410.55226170212785, 411.62549716312077),
#       'tp_formula': '-(acc*n - 2*bacc*n + acc*p)*p/(n - p)',
#       'tn_formula': '(acc*n + acc*p - 2*bacc*p)*n/(n - p)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1439, 0.14409999999999998)) and the reconstructed intervals ((0.14071321998171288, 0.14669035060614866)) do intersect',
#      'target_interval_reconstructed': (0.14071321998171288,
#       0.14669035060614866)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'f1p',
#      'score_1_interval': (0.1222, 0.12240000000000001),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tp': (27.975551708817495, 28.039453646308115),
#       'tn': (410.77310398724086, 411.21594839334557),
#       'tp_formula': '1/2*(acc - 1)*f1p*(n + p)/(f1p - 1)',
#       'tn_formula': '1/2*(acc*f1p - 2*acc + f1p)*(n + p)/(f1p - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.0799, 0.0801)) and the reconstructed intervals ((0.07993014773947855, 0.08011272470373747)) do intersect',
#      'target_interval_reconstructed': (0.07993014773947855,
#       0.08011272470373747)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'f1p',
#      'score_1_interval': (0.1222, 0.12240000000000001),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.975551708817495, 28.039453646308115),
#       'tn': (410.77310398724086, 411.21594839334557),
#       'tp_formula': '1/2*(acc - 1)*f1p*(n + p)/(f1p - 1)',
#       'tn_formula': '1/2*(acc*f1p - 2*acc + f1p)*(n + p)/(f1p - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.836605099770348, 0.8375070232043698)) do intersect',
#      'target_interval_reconstructed': (0.836605099770348,
#       0.8375070232043698)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'f1p',
#      'score_1_interval': (0.1222, 0.12240000000000001),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.975551708817495, 28.039453646308115),
#       'tn': (410.77310398724086, 411.21594839334557),
#       'tp_formula': '1/2*(acc - 1)*f1p*(n + p)/(f1p - 1)',
#       'tn_formula': '1/2*(acc*f1p - 2*acc + f1p)*(n + p)/(f1p - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5602161389970081, 0.5612079480750085)) do intersect',
#      'target_interval_reconstructed': (0.5602161389970081,
#       0.5612079480750085)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'f1p',
#      'score_1_interval': (0.1222, 0.12240000000000001),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (27.975551708817495, 28.039453646308115),
#       'tn': (410.77310398724086, 411.21594839334557),
#       'tp_formula': '1/2*(acc - 1)*f1p*(n + p)/(f1p - 1)',
#       'tn_formula': '1/2*(acc*f1p - 2*acc + f1p)*(n + p)/(f1p - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.2583956307468852, 0.2602037571001549)) do intersect',
#      'target_interval_reconstructed': (0.2583956307468852,
#       0.2602037571001549)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'f1p',
#      'score_1_interval': (0.1222, 0.12240000000000001),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (27.975551708817495, 28.039453646308115),
#       'tn': (410.77310398724086, 411.21594839334557),
#       'tp_formula': '1/2*(acc - 1)*f1p*(n + p)/(f1p - 1)',
#       'tn_formula': '1/2*(acc*f1p - 2*acc + f1p)*(n + p)/(f1p - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.4582676237549133, 0.4588098739540536)) do intersect',
#      'target_interval_reconstructed': (0.4582676237549133,
#       0.4588098739540536)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'f1p',
#      'score_1_interval': (0.1222, 0.12240000000000001),
#      'target_score': 'fm',
#      'target_interval': (0.1439, 0.14409999999999998),
#      'solution': {'tp': (27.975551708817495, 28.039453646308115),
#       'tn': (410.77310398724086, 411.21594839334557),
#       'tp_formula': '1/2*(acc - 1)*f1p*(n + p)/(f1p - 1)',
#       'tn_formula': '1/2*(acc*f1p - 2*acc + f1p)*(n + p)/(f1p - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1439, 0.14409999999999998)) and the reconstructed intervals ((0.14371360736142658, 0.14438016470222942)) do intersect',
#      'target_interval_reconstructed': (0.14371360736142658,
#       0.14438016470222942)}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tp': (27.95437760944169, 28.036300263557507),
#       'tn': (410.8815997364425, 411.13172239055837),
#       'tp_formula': '(fm*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.0799, 0.0801)) and the reconstructed intervals ((0.07986965031269054, 0.08010371503873573)) do intersect',
#      'target_interval_reconstructed': (0.07986965031269054,
#       0.08010371503873573)},
#     {'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tp': (-13.511020263557507, -13.449257609441688),
#       'tn': (452.35707060944173, 452.6071932635576),
#       'tp_formula': '(fm*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.95437760944169, 28.036300263557507),
#       'tn': (410.8815997364425, 411.13172239055837),
#       'tp_formula': '(fm*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.8368260687096589, 0.8373354834838256)) do intersect',
#      'target_interval_reconstructed': (0.8368260687096589,
#       0.8373354834838256)},
#     {'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (-13.511020263557507, -13.449257609441688),
#       'tn': (452.35707060944173, 452.6071932635576),
#       'tp_formula': '(fm*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.95437760944169, 28.036300263557507),
#       'tn': (410.8815997364425, 411.13172239055837),
#       'tp_formula': '(fm*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5604122967808115, 0.561007517802562)) do intersect',
#      'target_interval_reconstructed': (0.5604122967808115, 0.561007517802562)},
#     {'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (-13.511020263557507, -13.449257609441688),
#       'tn': (452.35707060944173, 452.6071932635576),
#       'tp_formula': '(fm*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (27.95437760944169, 28.036300263557507),
#       'tn': (410.8815997364425, 411.13172239055837),
#       'tp_formula': '(fm*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.25846659898460345, 0.2600223506520308)) do intersect',
#      'target_interval_reconstructed': (0.25846659898460345,
#       0.2600223506520308)},
#     {'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (-13.511020263557507, -13.449257609441688),
#       'tn': (452.35707060944173, 452.6071932635576),
#       'tp_formula': '(fm*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (27.95437760944169, 28.036300263557507),
#       'tn': (410.8815997364425, 411.13172239055837),
#       'tp_formula': '(fm*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.45834785951117474, 0.45871959926128064)) do intersect',
#      'target_interval_reconstructed': (0.45834785951117474,
#       0.45871959926128064)},
#     {'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (-13.511020263557507, -13.449257609441688),
#       'tn': (452.35707060944173, 452.6071932635576),
#       'tp_formula': '(fm*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (27.95437760944169, 28.036300263557507),
#       'tn': (410.8815997364425, 411.13172239055837),
#       'tp_formula': '(fm*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.12203029927349733, 0.12247668368509834)) do intersect',
#      'target_interval_reconstructed': (0.12203029927349733,
#       0.12247668368509834)},
#     {'score_0': 'acc',
#      'score_0_interval': (0.5219, 0.5221),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (-13.511020263557507, -13.449257609441688),
#       'tn': (452.35707060944173, 452.6071932635576),
#       'tp_formula': '(fm*p - sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p))*fm',
#       'tn_formula': '-fm**2*p + acc*n + acc*p + sqrt(-((acc - 1)*n - (fm**2 - acc)*p)*p)*fm'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'acc',
#      'target_interval': (0.5219, 0.5221),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.967, 411.06519999999995),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5219, 0.5221)) and the reconstructed intervals ((0.5219167657550534, 0.5221167657550535)) do intersect',
#      'target_interval_reconstructed': (0.5219167657550534,
#       0.5221167657550535)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.967, 411.06519999999995),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.560587761400147, 0.5608503926694426)) do intersect',
#      'target_interval_reconstructed': (0.560587761400147,
#       0.5608503926694426)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.967, 411.06519999999995),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.25877225450642194, 0.2598243926309407)) do intersect',
#      'target_interval_reconstructed': (0.25877225450642194,
#       0.2598243926309407)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.967, 411.06519999999995),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.45844999999999997, 0.45865)) do intersect',
#      'target_interval_reconstructed': (0.45844999999999997, 0.45865)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.967, 411.06519999999995),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.12209977557917162, 0.12245037014648183)) do intersect',
#      'target_interval_reconstructed': (0.12209977557917162,
#       0.12245037014648183)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'spec',
#      'score_1_interval': (0.837, 0.8371999999999999),
#      'target_score': 'fm',
#      'target_interval': (0.1439, 0.14409999999999998),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.967, 411.06519999999995),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'n*spec'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1439, 0.14409999999999998)) and the reconstructed intervals ((0.14379117891951199, 0.144263418265818)) do intersect',
#      'target_interval_reconstructed': (0.14379117891951199,
#       0.144263418265818)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'acc',
#      'target_interval': (0.5219, 0.5221),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.7728243058716, 411.19587431693986),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'npv*p*(sens - 1)/(npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5219, 0.5221)) and the reconstructed intervals ((0.5216858790795144, 0.5222721454422591)) do intersect',
#      'target_interval_reconstructed': (0.5216858790795144,
#       0.5222721454422591)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.7728243058716, 411.19587431693986),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'npv*p*(sens - 1)/(npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.8366045301545246, 0.8374661391383704)) do intersect',
#      'target_interval_reconstructed': (0.8366045301545246,
#       0.8374661391383704)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.7728243058716, 411.19587431693986),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'npv*p*(sens - 1)/(npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.2583081285841616, 0.26013943995842137)) do intersect',
#      'target_interval_reconstructed': (0.2583081285841616,
#       0.26013943995842137)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.7728243058716, 411.19587431693986),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'npv*p*(sens - 1)/(npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.4582522650772623, 0.45878306956918524)) do intersect',
#      'target_interval_reconstructed': (0.4582522650772623,
#       0.45878306956918524)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.7728243058716, 411.19587431693986),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'npv*p*(sens - 1)/(npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.12204803923710915, 0.12248532470671797)) do intersect',
#      'target_interval_reconstructed': (0.12204803923710915,
#       0.12248532470671797)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'npv',
#      'score_1_interval': (0.5606, 0.5608),
#      'target_score': 'fm',
#      'target_interval': (0.1439, 0.14409999999999998),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.7728243058716, 411.19587431693986),
#       'tp_formula': 'p*sens',
#       'tn_formula': 'npv*p*(sens - 1)/(npv - 1)'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1439, 0.14409999999999998)) and the reconstructed intervals ((0.14366217133913334, 0.14435085431222622)) do intersect',
#      'target_interval_reconstructed': (0.14366217133913334,
#       0.14435085431222622)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'acc',
#      'target_interval': (0.5219, 0.5221),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.4885427910563, 411.5458294753086),
#       'tp_formula': 'p*sens',
#       'tn_formula': '(p*ppv*sens + n*ppv - p*sens)/ppv'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5219, 0.5221)) and the reconstructed intervals ((0.521347851118973, 0.5226882633475727)) do intersect',
#      'target_interval_reconstructed': (0.521347851118973,
#       0.5226882633475727)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.4885427910563, 411.5458294753086),
#       'tp_formula': 'p*sens',
#       'tn_formula': '(p*ppv*sens + n*ppv - p*sens)/ppv'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.8360255453993001, 0.8381788787684493)) do intersect',
#      'target_interval_reconstructed': (0.8360255453993001,
#       0.8381788787684493)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.4885427910563, 411.5458294753086),
#       'tp_formula': 'p*sens',
#       'tn_formula': '(p*ppv*sens + n*ppv - p*sens)/ppv'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5595682524646356, 0.561872945425439)) do intersect',
#      'target_interval_reconstructed': (0.5595682524646356,
#       0.561872945425439)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.4885427910563, 411.5458294753086),
#       'tp_formula': 'p*sens',
#       'tn_formula': '(p*ppv*sens + n*ppv - p*sens)/ppv'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.45796277269965, 0.45913943938422463)) do intersect',
#      'target_interval_reconstructed': (0.45796277269965,
#       0.45913943938422463)}],
#    'consistency': True},
#   {'details': [{'score_0': 'sens',
#      'score_0_interval': (0.0799, 0.0801),
#      'score_1': 'ppv',
#      'score_1_interval': (0.2592, 0.25939999999999996),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (27.965, 28.035),
#       'tn': (410.4885427910563, 411.5458294753086),
#       'tp_formula': 'p*sens',
#       'tn_formula': '(p*ppv*sens + n*ppv - p*sens)/ppv'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.12197237405437991, 0.12257903387757851)) do intersect',
#      'target_interval_reconstructed': (0.12197237405437991,
# ...
#       'tn': (464.90106023086094, 465.22854246366495),
#       'tp_formula': '1/2*(fm*n + fm*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'bacc',
#      'score_0_interval': (0.45840000000000003, 0.4586),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.954852191672767, 28.04829166515838),
#       'tn': (410.8010536925921, 411.12853592539614),
#       'tp_formula': '1/2*(fm*n + fm*p + sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p + sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.8366620238138333, 0.8373289937380777)) do intersect',
#      'target_interval_reconstructed': (0.8366620238138333,
#       0.8373289937380777)},
#     {'score_0': 'bacc',
#      'score_0_interval': (0.45840000000000003, 0.4586),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (-10.59720526515838, -10.527986591672768),
#       'tn': (464.90106023086094, 465.22854246366495),
#       'tp_formula': '1/2*(fm*n + fm*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'bacc',
#      'score_0_interval': (0.45840000000000003, 0.4586),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.954852191672767, 28.04829166515838),
#       'tn': (410.8010536925921, 411.12853592539614),
#       'tp_formula': '1/2*(fm*n + fm*p + sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p + sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5603052357260934, 0.5610740173641321)) do intersect',
#      'target_interval_reconstructed': (0.5603052357260934,
#       0.5610740173641321)},
#     {'score_0': 'bacc',
#      'score_0_interval': (0.45840000000000003, 0.4586),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (-10.59720526515838, -10.527986591672768),
#       'tn': (464.90106023086094, 465.22854246366495),
#       'tp_formula': '1/2*(fm*n + fm*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'bacc',
#      'score_0_interval': (0.45840000000000003, 0.4586),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (27.954852191672767, 28.04829166515838),
#       'tn': (410.8010536925921, 411.12853592539614),
#       'tp_formula': '1/2*(fm*n + fm*p + sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p + sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.2582500275781406, 0.26012473240663475)) do intersect',
#      'target_interval_reconstructed': (0.2582500275781406,
#       0.26012473240663475)},
#     {'score_0': 'bacc',
#      'score_0_interval': (0.45840000000000003, 0.4586),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (-10.59720526515838, -10.527986591672768),
#       'tn': (464.90106023086094, 465.22854246366495),
#       'tp_formula': '1/2*(fm*n + fm*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'bacc',
#      'score_0_interval': (0.45840000000000003, 0.4586),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (27.954852191672767, 28.04829166515838),
#       'tn': (410.8010536925921, 411.12853592539614),
#       'tp_formula': '1/2*(fm*n + fm*p + sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p + sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.1222, 0.12240000000000001)) and the reconstructed intervals ((0.12200772803499729, 0.12252808835412246)) do intersect',
#      'target_interval_reconstructed': (0.12200772803499729,
#       0.12252808835412246)},
#     {'score_0': 'bacc',
#      'score_0_interval': (0.45840000000000003, 0.4586),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'f1p',
#      'target_interval': (0.1222, 0.12240000000000001),
#      'solution': {'tp': (-10.59720526515838, -10.527986591672768),
#       'tn': (464.90106023086094, 465.22854246366495),
#       'tp_formula': '1/2*(fm*n + fm*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p))*fm',
#       'tn_formula': '-1/2*(fm**2*n + fm**2*p - 4*bacc*p - sqrt(fm**2*n**2 + fm**2*p**2 + 2*(fm**2 - 4*bacc + 2)*n*p)*fm)*n/p'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'acc',
#      'target_interval': (0.5219, 0.5221),
#      'solution': {'tp': (27.78825673947125, 28.244135148625),
#       'tn': (404.44324595093934, 417.31192981400926),
#       'tp_formula': '(fm - sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p - sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p + 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5219, 0.5221)) and the reconstructed intervals ((0.5139494681217724, 0.5297931806927875)) do intersect',
#      'target_interval_reconstructed': (0.5139494681217724,
#       0.5297931806927875)},
#     {'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'acc',
#      'target_interval': (0.5219, 0.5221),
#      'solution': {'tp': (90.34703444118959, 90.99239025045148),
#       'tn': (-557.7422543805347, -544.4150228249509),
#       'tp_formula': '(fm + sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p + sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p - 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tp': (27.78825673947125, 28.244135148625),
#       'tn': (404.44324595093934, 417.31192981400926),
#       'tp_formula': '(fm - sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p - sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p + 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.0799, 0.0801)) and the reconstructed intervals ((0.07939501925563215, 0.08069752899607142)) do intersect',
#      'target_interval_reconstructed': (0.07939501925563215,
#       0.08069752899607142)},
#     {'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'sens',
#      'target_interval': (0.0799, 0.0801),
#      'solution': {'tp': (90.34703444118959, 90.99239025045148),
#       'tn': (-557.7422543805347, -544.4150228249509),
#       'tp_formula': '(fm + sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p + sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p - 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (27.78825673947125, 28.244135148625),
#       'tn': (404.44324595093934, 417.31192981400926),
#       'tp_formula': '(fm - sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p - sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p + 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.837, 0.8371999999999999)) and the reconstructed intervals ((0.8237133318756402, 0.8499224639796522)) do intersect',
#      'target_interval_reconstructed': (0.8237133318756402,
#       0.8499224639796522)},
#     {'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'spec',
#      'target_interval': (0.837, 0.8371999999999999),
#      'solution': {'tp': (90.34703444118959, 90.99239025045148),
#       'tn': (-557.7422543805347, -544.4150228249509),
#       'tp_formula': '(fm + sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p + sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p - 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (27.78825673947125, 28.244135148625),
#       'tn': (404.44324595093934, 417.31192981400926),
#       'tp_formula': '(fm - sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p - sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p + 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.5606, 0.5608)) and the reconstructed intervals ((0.5468969563468926, 0.5746522181126847)) do intersect',
#      'target_interval_reconstructed': (0.5468969563468926,
#       0.5746522181126847)},
#     {'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'npv',
#      'target_interval': (0.5606, 0.5608),
#      'solution': {'tp': (90.34703444118959, 90.99239025045148),
#       'tn': (-557.7422543805347, -544.4150228249509),
#       'tp_formula': '(fm + sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p + sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p - 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (27.78825673947125, 28.244135148625),
#       'tn': (404.44324595093934, 417.31192981400926),
#       'tp_formula': '(fm - sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p - sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p + 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.2592, 0.25939999999999996)) and the reconstructed intervals ((0.2420561106597374, 0.2783322574276)) do intersect',
#      'target_interval_reconstructed': (0.2420561106597374, 0.2783322574276)},
#     {'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'ppv',
#      'target_interval': (0.2592, 0.25939999999999996),
#      'solution': {'tp': (90.34703444118959, 90.99239025045148),
#       'tn': (-557.7422543805347, -544.4150228249509),
#       'tp_formula': '(fm + sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p + sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p - 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True},
#   {'details': [{'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (27.78825673947125, 28.244135148625),
#       'tn': (404.44324595093934, 417.31192981400926),
#       'tp_formula': '(fm - sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p - sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p + 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': True,
#      'explanation': 'the target score interval ((0.45840000000000003, 0.4586)) and the reconstructed intervals ((0.4515541755656362, 0.4653099964878618)) do intersect',
#      'target_interval_reconstructed': (0.4515541755656362,
#       0.4653099964878618)},
#     {'score_0': 'f1p',
#      'score_0_interval': (0.1222, 0.12240000000000001),
#      'score_1': 'fm',
#      'score_1_interval': (0.1439, 0.14409999999999998),
#      'target_score': 'bacc',
#      'target_interval': (0.45840000000000003, 0.4586),
#      'solution': {'tp': (90.34703444118959, 90.99239025045148),
#       'tn': (-557.7422543805347, -544.4150228249509),
#       'tp_formula': '(fm + sqrt(-f1p**2 + fm**2))*fm*p/f1p',
#       'tn_formula': '(f1p*fm**2*p + sqrt(-f1p**2 + fm**2)*f1p*fm*p + f1p**2*n + f1p**2*p - 2*fm**2*p - 2*sqrt(-f1p**2 + fm**2)*fm*p)/f1p**2'},
#      'consistency': False,
#      'explanation': 'the interval for tp does not contain integers'}],
#    'consistency': True}],
#  'failed': [],
#  'overall_consistency': True}

# %%
for tmp in details['succeeded']:
    for item in tmp['details']:
        if item.get('target_interval_reconstructed') is not None and item.get('consistency'):
            target_interval = item['target_interval_reconstructed']
            iun = IntervalUnion(target_int)
            assert iun.contains(scores[item['target_score']])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[21], line 5
#       3 if item.get('target_interval_reconstructed') is not None and item.get('consistency'):
#       4     target_interval = item['target_interval_reconstructed']
# ----> 5     iun = IntervalUnion([Interval(*target_int) for target_int in target_interval])
#       6     assert iun.contains(scores[item['target_score']])
#
# Cell In[21], line 5, in <listcomp>(.0)
#       3 if item.get('target_interval_reconstructed') is not None and item.get('consistency'):
#       4     target_interval = item['target_interval_reconstructed']
# ----> 5     iun = IntervalUnion([Interval(*target_int) for target_int in target_interval])
#       6     assert iun.contains(scores[item['target_score']])
#
# TypeError: mlscorecheck.core._interval.Interval() argument after * must be an iterable, not numpy.float64

# %%
help(check_kfold_rom_scores)
# Out:
# Help on function check_kfold_rom_scores in module mlscorecheck.check._check_scores:
#
# check_kfold_rom_scores(scores, eps, *, dataset_setup, return_details=False)
#     Use when scores are aggregated in the RoM manner

# %%
folds, problem = generate_folding_problem()

# %%
problem
# Out:
# {'p': 311, 'n': 576, 'n_folds': 5, 'n_repeats': 1}

# %%
scores = calculate_scores_rom(folds)

# %%
scores
# Out:
# {'acc': 0.5050732807215332,
#  'sens': 0.5755627009646302,
#  'spec': 0.4670138888888889,
#  'bacc': 0.5212882949267595}

# %%
check_kfold_rom_scores(scores, 1e-4, dataset_setup=problem, return_details=True)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 check_kfold_rom_scores(scores, 1e-4, dataset_setup=problem, return_details=True)
#
# File ~/workspaces/mlscorecheck/mlscorecheck/check/_check_scores.py:58, in check_kfold_rom_scores(scores, eps, dataset_setup, return_details)
#      55 dataset_resolved['p'] = dataset_resolved['p'] * dataset_resolved['n_repeats']
#      56 dataset_resolved['n'] = dataset_resolved['n'] * dataset_resolved['n_repeats']
# ---> 58 return check_scores(scores,
#      59                     eps,
#      60                     dataset_setup=dataset_resolved,
#      61                     return_details=return_details)
#
# TypeError: check_scores() got an unexpected keyword argument 'dataset_setup'
