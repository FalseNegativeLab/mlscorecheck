# %%
import sympy
from sympy import Symbol

from mlscorecheck.core import (score_function_set, sqrt)

# %%
tp = Symbol('tp')
fp = Symbol('fp')
tn = Symbol('tn')
fn = Symbol('fn')
eps = Symbol('eps')
p = Symbol('p')
n = Symbol('n')
beta = Symbol('beta')

# %%
atomic_symbols = {'tp': tp, 
                  'fp': fp, 
                  'tn': tn, 
                  'fn': fn, 
                  'eps': eps, 
                  'p': p, 
                  'n': n,
                  'beta': beta}

# %%
score_functions = score_function_set()
#del score_functions['mcc']

# %%
score_functions
# Out:
# {'acc': <function mlscorecheck.core._scores.accuracy(*, tp, tn, p, n)>,
#  'sens': <function mlscorecheck.core._scores.sensitivity(*, tp, p)>,
#  'spec': <function mlscorecheck.core._scores.specificity(*, tn, n)>,
#  'npv': <function mlscorecheck.core._scores.negative_predictive_value(*, tn, fn)>,
#  'ppv': <function mlscorecheck.core._scores.positive_predictive_value(*, tp, fp)>,
#  'f1_plus': <function mlscorecheck.core._scores.f1_plus(*, tp, fp, p)>,
#  'f1_minus': <function mlscorecheck.core._scores.f1_minus(*, tn, fn, n)>,
#  'fm': <function mlscorecheck.core._scores.fowlkes_mallows_index(*, tp, fp, p)>,
#  'bm': <function mlscorecheck.core._scores.informedness(*, tp, tn, p, n)>,
#  'pt': <function mlscorecheck.core._scores.prevalence_threshold(*, tp, fp, p, n)>,
#  'lrp': <function mlscorecheck.core._scores.positive_likelihood_ratio(*, tp, fp, p, n)>,
#  'lrn': <function mlscorecheck.core._scores.negative_likelihood_ratio(*, tn, fn, p, n)>,
#  'mk': <function mlscorecheck.core._scores.markedness(*, tp, tn, fp, fn)>,
#  'dor': <function mlscorecheck.core._scores.diagnostic_odds_ratio(*, tp, tn, fp, fn, p, n)>,
#  'mcc': <function mlscorecheck.core._scores.matthews_correlation_coefficient(*, tp, tn, fp, fn, p, n)>,
#  'ji': <function mlscorecheck.core._scores.jaccard_index(*, tp, fp, p)>,
#  'ba': <function mlscorecheck.core._scores.balanced_accuracy(*, tp, tn, p, n)>,
#  'kappa': <function mlscorecheck.core._scores.cohens_kappa(*, tp, tn, p, n)>,
#  'gm': <function mlscorecheck.core._scores.geometric_mean(*, tp, tn, p, n)>,
#  'upm': <function mlscorecheck.core._scores.unified_performance_measure(*, tp, tn, p, n)>}

# %%
score_symbols = {key: Symbol(key) for key in score_functions}

# %%
score_symbols
# Out:
# {'acc': acc,
#  'sens': sens,
#  'spec': spec,
#  'npv': npv,
#  'ppv': ppv,
#  'f1_plus': f1_plus,
#  'f1_minus': f1_minus,
#  'fm': fm,
#  'bm': bm,
#  'pt': pt,
#  'lrp': lrp,
#  'lrn': lrn,
#  'mk': mk,
#  'dor': dor,
#  'mcc': mcc,
#  'ji': ji,
#  'ba': ba,
#  'kappa': kappa,
#  'gm': gm,
#  'upm': upm}

# %%
score_equations = {}

for key in score_symbols:
    function = score_functions[key]
    params = function.__code__.co_varnames[:function.__code__.co_kwonlyargcount]
    params = {param: atomic_symbols[param] for param in params}
    score_equations[key] = score_symbols[key] - score_functions[key](**params)

# %%
score_equations
# Out:
# {'acc': acc - (tn + tp)/(n + p),
#  'sens': sens - tp/p,
#  'spec': spec - tn/n,
#  'npv': npv - tn/(fn + tn),
#  'ppv': ppv - tp/(fp + tp),
#  'f1_plus': f1_plus - 2*tp/(fp + p + tp),
#  'f1_minus': f1_minus - 2*tn/(fn + n + tn),
#  'fm': fm - sqrt(tp**2/(p*(fp + tp))),
#  'bm': bm + 1 - tp/p - tn/n,
#  'pt': pt - (-fp/n + sqrt(fp*tp/(n*p)))/(-fp/n + tp/p),
#  'lrp': lrp - n*tp/(fp*p),
#  'lrn': -fn*n/(p*tn) + lrn,
#  'mk': mk - tn/(fn + tn) - tp/(fp + tp) + 1,
#  'dor': dor - tn*tp/(fn*fp),
#  'mcc': mcc - (-fn*fp + tn*tp)/sqrt(n*p*(fn + tn)*(fp + tp)),
#  'ji': ji - tp/(fp + p),
#  'ba': ba - 0.5*tp/p - 0.5*tn/n,
#  'kappa': kappa - (tn + tp)/((n + p)*((tn + tp)*(n + p - tn - tp)/(2*tn*tp - 2*(n - tp)*(p - tn)) + (tn + tp)/(n + p))),
#  'gm': gm - sqrt(tn*tp/(n*p)),
#  'upm': -8*tn*tp/((2*tn/(n + p + tn - tp) + 2*tp/(n + p - tn + tp))*(n + p - tn + tp)*(n + p + tn - tp)) + upm}

# %%
tp = Symbol('tp')
fp = Symbol('fp')
tn = Symbol('tn')
fn = Symbol('fn')
eps = Symbol('eps')
p = Symbol('p')
n = Symbol('n')
beta = Symbol('beta')

# %%
score_symbols = {key: Symbol(key) for key in score_functions}

# %%
score_equations = {}

for key in score_symbols:
    function = score_functions[key]
    params = function.__code__.co_varnames[:function.__code__.co_kwonlyargcount]
    params = {param: atomic_symbols[param] for param in params}
    score_equations[key] = score_symbols[key] - score_functions[key](**params)

# %%
scores = list(score_equations.keys())

for idx, score0 in enumerate(scores):
    for score1 in scores[idx+1:]:
        if (score0 == 'fm' and score1 in ('mk', 'gm', 'upm')) \
            or (score0 == 'pt' and score1 in ('upm'))\
            or (score0 == 'mk' and score1 in ('kappa', 'gm', 'upm'))\
            or (score0 == 'dor' and score1 in ('kappa', 'upm'))\
            or (score0 == 'mcc' and score1 in ('gm', 'upm'))\
            or (score0 == 'kappa' and score1 in ('upm')):
            continue
        print(score0, score1)
        results = sympy.solve([score_equations[score0], 
                               score_equations[score1], 
                               p-tp-fn, 
                               n-tn-fp], 
                              [tp, tn, fp, fn], 
                              dict=True,
                              check=False)
        print(len(results), results)
# Out:
# acc sens
# 1 [{tp: p*sens, tn: acc*n + acc*p - p*sens, fp: -acc*n - acc*p + n + p*sens, fn: -p*sens + p}]
# acc spec
# 1 [{tp: acc*n + acc*p - n*spec, tn: n*spec, fp: -n*spec + n, fn: -acc*n - acc*p + n*spec + p}]
# acc npv
# 1 [{tp: (acc*n*npv - acc*n + acc*npv*p - acc*p + npv*p)/(2*npv - 1), tn: (acc*n*npv + acc*npv*p - npv*p)/(2*npv - 1), fp: (-acc*n*npv - acc*npv*p + 2*n*npv - n + npv*p)/(2*npv - 1), fn: (-acc*n*npv + acc*n - acc*npv*p + acc*p + npv*p - p)/(2*npv - 1)}]
# acc ppv
# 1 [{tp: (acc*n*ppv + acc*p*ppv - n*ppv)/(2*ppv - 1), tn: (acc*n*ppv - acc*n + acc*p*ppv - acc*p + n*ppv)/(2*ppv - 1), fp: (-acc*n*ppv + acc*n - acc*p*ppv + acc*p + n*ppv - n)/(2*ppv - 1), fn: (-acc*n*ppv - acc*p*ppv + n*ppv + 2*p*ppv - p)/(2*ppv - 1)}]
# acc f1_plus
# 1 [{tp: (acc*f1_plus*n + acc*f1_plus*p - f1_plus*n - f1_plus*p)/(2*f1_plus - 2), tn: (acc*f1_plus*n + acc*f1_plus*p - 2*acc*n - 2*acc*p + f1_plus*n + f1_plus*p)/(2*f1_plus - 2), fp: (-acc*f1_plus*n - acc*f1_plus*p + 2*acc*n + 2*acc*p + f1_plus*n - f1_plus*p - 2*n)/(2*f1_plus - 2), fn: (-acc*f1_plus*n - acc*f1_plus*p + f1_plus*n + 3*f1_plus*p - 2*p)/(2*f1_plus - 2)}]
# acc f1_minus
# 1 [{tp: (acc*f1_minus*n + acc*f1_minus*p - 2*acc*n - 2*acc*p + f1_minus*n + f1_minus*p)/(2*f1_minus - 2), tn: (acc*f1_minus*n + acc*f1_minus*p - f1_minus*n - f1_minus*p)/(2*f1_minus - 2), fp: (-acc*f1_minus*n - acc*f1_minus*p + 3*f1_minus*n + f1_minus*p - 2*n)/(2*f1_minus - 2), fn: (-acc*f1_minus*n - acc*f1_minus*p + 2*acc*n + 2*acc*p - f1_minus*n + f1_minus*p - 2*p)/(2*f1_minus - 2)}]
# acc fm
# 2 [{fn: -fm*sqrt(-p*(acc*n + acc*p - fm**2*p - n)) - p*(fm - 1)*(fm + 1), fp: -acc*n - acc*p + fm**2*p + fm*sqrt(p*(-acc*n - acc*p + fm**2*p + n)) + n, tn: acc*n + acc*p - fm**2*p - fm*sqrt(p*(-acc*n - acc*p + fm**2*p + n)), tp: fm*(fm*p + sqrt(p*(-acc*n - acc*p + fm**2*p + n)))}, {fn: fm*sqrt(-p*(acc*n + acc*p - fm**2*p - n)) - p*(fm - 1)*(fm + 1), fp: -acc*n - acc*p + fm**2*p - fm*sqrt(-p*(acc*n + acc*p - fm**2*p - n)) + n, tn: acc*n + acc*p - fm**2*p + fm*sqrt(p*(-acc*n - acc*p + fm**2*p + n)), tp: fm*(fm*p - sqrt(p*(-acc*n - acc*p + fm**2*p + n)))}]
# acc bm
# 1 [{tp: (acc*n*p + acc*p**2 - bm*n*p - n*p)/(-n + p), tn: (-acc*n**2 - acc*n*p + bm*n*p + n*p)/(-n + p), fp: (acc*n**2 + acc*n*p - bm*n*p - n**2)/(-n + p), fn: (-acc*n*p - acc*p**2 + bm*n*p + p**2)/(-n + p)}]
# acc pt
# 2 [{fn: p*(acc*n + acc*p - p)/(n - p), fp: n*(acc*n + acc*p - n)/(-n + p), tn: n*(acc*n + acc*p - p)/(n - p), tp: p*(-acc*n - acc*p + n)/(n - p)}, {fn: p*(acc*n*pt**2 - 2*acc*n*pt + acc*n + acc*p*pt**2 - 2*acc*p*pt + acc*p + 2*n*pt - n - p*pt**2 + 2*p*pt - p)/(n*pt**2 - p*pt**2 + 2*p*pt - p), fp: n*pt**2*(acc*n + acc*p - n)/(-n*pt**2 + p*pt**2 - 2*p*pt + p), tn: n*(-acc*n*pt**2 - acc*p*pt**2 + p*pt**2 - 2*p*pt + p)/(-n*pt**2 + p*pt**2 - 2*p*pt + p), tp: p*(-acc*n*pt**2 + 2*acc*n*pt - acc*n - acc*p*pt**2 + 2*acc*p*pt - acc*p + n*pt**2 - 2*n*pt + n)/(n*pt**2 - p*pt**2 + 2*p*pt - p)}]
# acc lrp
# 1 [{tp: (acc*lrp*n*p + acc*lrp*p**2 - lrp*n*p)/(lrp*p - n), tn: (-acc*n**2 - acc*n*p + lrp*n*p)/(lrp*p - n), fp: (acc*n**2 + acc*n*p - n**2)/(lrp*p - n), fn: (-acc*lrp*n*p - acc*lrp*p**2 + lrp*n*p + lrp*p**2 - n*p)/(lrp*p - n)}]
# acc lrn
# 1 [{tp: (acc*lrn*n*p + acc*lrn*p**2 - n*p)/(lrn*p - n), tn: (-acc*n**2 - acc*n*p + n*p)/(lrn*p - n), fp: (acc*n**2 + acc*n*p + lrn*n*p - n**2 - n*p)/(lrn*p - n), fn: (-acc*lrn*n*p - acc*lrn*p**2 + lrn*p**2)/(lrn*p - n)}]
# acc mk
# 2 [{fn: -(4*acc*mk*n + 4*acc*mk*p - 2*mk*n - 6*mk*p - n + p)/(8*mk) - sqrt(-8*acc*mk*n**2 - 16*acc*mk*n*p - 8*acc*mk*p**2 + 4*mk**2*n**2 + 8*mk**2*n*p + 4*mk**2*p**2 + 4*mk*n**2 + 8*mk*n*p + 4*mk*p**2 + n**2 - 2*n*p + p**2)/(8*mk), fp: (-4*acc*mk*n - 4*acc*mk*p + 6*mk*n + 2*mk*p - n + p + sqrt(-8*acc*mk*n**2 - 16*acc*mk*n*p - 8*acc*mk*p**2 + 4*mk**2*n**2 + 8*mk**2*n*p + 4*mk**2*p**2 + 4*mk*n**2 + 8*mk*n*p + 4*mk*p**2 + n**2 - 2*n*p + p**2))/(8*mk), tn: (4*acc*mk*n + 4*acc*mk*p + 2*mk*n - 2*mk*p + n - p - sqrt(-8*acc*mk*n**2 - 16*acc*mk*n*p - 8*acc*mk*p**2 + 4*mk**2*n**2 + 8*mk**2*n*p + 4*mk**2*p**2 + 4*mk*n**2 + 8*mk*n*p + 4*mk*p**2 + n**2 - 2*n*p + p**2))/(8*mk), tp: (4*acc*mk*n + 4*acc*mk*p - 2*mk*n + 2*mk*p - n + p + sqrt(-8*acc*mk*n**2 - 16*acc*mk*n*p - 8*acc*mk*p**2 + 4*mk**2*n**2 + 8*mk**2*n*p + 4*mk**2*p**2 + 4*mk*n**2 + 8*mk*n*p + 4*mk*p**2 + n**2 - 2*n*p + p**2))/(8*mk)}, {fn: -(4*acc*mk*n + 4*acc*mk*p - 2*mk*n - 6*mk*p - n + p)/(8*mk) + sqrt(-8*acc*mk*n**2 - 16*acc*mk*n*p - 8*acc*mk*p**2 + 4*mk**2*n**2 + 8*mk**2*n*p + 4*mk**2*p**2 + 4*mk*n**2 + 8*mk*n*p + 4*mk*p**2 + n**2 - 2*n*p + p**2)/(8*mk), fp: (-4*acc*mk*n - 4*acc*mk*p + 6*mk*n + 2*mk*p - n + p - sqrt(-8*acc*mk*n**2 - 16*acc*mk*n*p - 8*acc*mk*p**2 + 4*mk**2*n**2 + 8*mk**2*n*p + 4*mk**2*p**2 + 4*mk*n**2 + 8*mk*n*p + 4*mk*p**2 + n**2 - 2*n*p + p**2))/(8*mk), tn: (4*acc*mk*n + 4*acc*mk*p + 2*mk*n - 2*mk*p + n - p + sqrt(-8*acc*mk*n**2 - 16*acc*mk*n*p - 8*acc*mk*p**2 + 4*mk**2*n**2 + 8*mk**2*n*p + 4*mk**2*p**2 + 4*mk*n**2 + 8*mk*n*p + 4*mk*p**2 + n**2 - 2*n*p + p**2))/(8*mk), tp: (4*acc*mk*n + 4*acc*mk*p - 2*mk*n + 2*mk*p - n + p - sqrt(-8*acc*mk*n**2 - 16*acc*mk*n*p - 8*acc*mk*p**2 + 4*mk**2*n**2 + 8*mk**2*n*p + 4*mk**2*p**2 + 4*mk*n**2 + 8*mk*n*p + 4*mk*p**2 + n**2 - 2*n*p + p**2))/(8*mk)}]
# acc dor
# 2 [{fn: -(acc*dor*n + acc*dor*p - acc*n - acc*p - dor*n - dor*p + 2*p)/(2*(dor - 1)) - sqrt(acc**2*dor**2*n**2 + 2*acc**2*dor**2*n*p + acc**2*dor**2*p**2 - 2*acc**2*dor*n**2 - 4*acc**2*dor*n*p - 2*acc**2*dor*p**2 + acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 2*acc*dor**2*n**2 - 4*acc*dor**2*n*p - 2*acc*dor**2*p**2 + 2*acc*dor*n**2 + 4*acc*dor*n*p + 2*acc*dor*p**2 + dor**2*n**2 + 2*dor**2*n*p + dor**2*p**2 - 4*dor*n*p)/(2*(dor - 1)), fp: (-acc*dor*n - acc*dor*p + acc*n + acc*p + dor*n + dor*p - 2*n + sqrt(acc**2*dor**2*n**2 + 2*acc**2*dor**2*n*p + acc**2*dor**2*p**2 - 2*acc**2*dor*n**2 - 4*acc**2*dor*n*p - 2*acc**2*dor*p**2 + acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 2*acc*dor**2*n**2 - 4*acc*dor**2*n*p - 2*acc*dor**2*p**2 + 2*acc*dor*n**2 + 4*acc*dor*n*p + 2*acc*dor*p**2 + dor**2*n**2 + 2*dor**2*n*p + dor**2*p**2 - 4*dor*n*p))/(2*(dor - 1)), tn: (acc*dor*n + acc*dor*p - acc*n - acc*p + dor*n - dor*p - sqrt(acc**2*dor**2*n**2 + 2*acc**2*dor**2*n*p + acc**2*dor**2*p**2 - 2*acc**2*dor*n**2 - 4*acc**2*dor*n*p - 2*acc**2*dor*p**2 + acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 2*acc*dor**2*n**2 - 4*acc*dor**2*n*p - 2*acc*dor**2*p**2 + 2*acc*dor*n**2 + 4*acc*dor*n*p + 2*acc*dor*p**2 + dor**2*n**2 + 2*dor**2*n*p + dor**2*p**2 - 4*dor*n*p))/(2*(dor - 1)), tp: (acc*dor*n + acc*dor*p - acc*n - acc*p - dor*n + dor*p + sqrt(acc**2*dor**2*n**2 + 2*acc**2*dor**2*n*p + acc**2*dor**2*p**2 - 2*acc**2*dor*n**2 - 4*acc**2*dor*n*p - 2*acc**2*dor*p**2 + acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 2*acc*dor**2*n**2 - 4*acc*dor**2*n*p - 2*acc*dor**2*p**2 + 2*acc*dor*n**2 + 4*acc*dor*n*p + 2*acc*dor*p**2 + dor**2*n**2 + 2*dor**2*n*p + dor**2*p**2 - 4*dor*n*p))/(2*(dor - 1))}, {fn: -(acc*dor*n + acc*dor*p - acc*n - acc*p - dor*n - dor*p + 2*p)/(2*(dor - 1)) + sqrt(acc**2*dor**2*n**2 + 2*acc**2*dor**2*n*p + acc**2*dor**2*p**2 - 2*acc**2*dor*n**2 - 4*acc**2*dor*n*p - 2*acc**2*dor*p**2 + acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 2*acc*dor**2*n**2 - 4*acc*dor**2*n*p - 2*acc*dor**2*p**2 + 2*acc*dor*n**2 + 4*acc*dor*n*p + 2*acc*dor*p**2 + dor**2*n**2 + 2*dor**2*n*p + dor**2*p**2 - 4*dor*n*p)/(2*(dor - 1)), fp: (-acc*dor*n - acc*dor*p + acc*n + acc*p + dor*n + dor*p - 2*n - sqrt(acc**2*dor**2*n**2 + 2*acc**2*dor**2*n*p + acc**2*dor**2*p**2 - 2*acc**2*dor*n**2 - 4*acc**2*dor*n*p - 2*acc**2*dor*p**2 + acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 2*acc*dor**2*n**2 - 4*acc*dor**2*n*p - 2*acc*dor**2*p**2 + 2*acc*dor*n**2 + 4*acc*dor*n*p + 2*acc*dor*p**2 + dor**2*n**2 + 2*dor**2*n*p + dor**2*p**2 - 4*dor*n*p))/(2*(dor - 1)), tn: (acc*dor*n + acc*dor*p - acc*n - acc*p + dor*n - dor*p + sqrt(acc**2*dor**2*n**2 + 2*acc**2*dor**2*n*p + acc**2*dor**2*p**2 - 2*acc**2*dor*n**2 - 4*acc**2*dor*n*p - 2*acc**2*dor*p**2 + acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 2*acc*dor**2*n**2 - 4*acc*dor**2*n*p - 2*acc*dor**2*p**2 + 2*acc*dor*n**2 + 4*acc*dor*n*p + 2*acc*dor*p**2 + dor**2*n**2 + 2*dor**2*n*p + dor**2*p**2 - 4*dor*n*p))/(2*(dor - 1)), tp: (acc*dor*n + acc*dor*p - acc*n - acc*p - dor*n + dor*p - sqrt(acc**2*dor**2*n**2 + 2*acc**2*dor**2*n*p + acc**2*dor**2*p**2 - 2*acc**2*dor*n**2 - 4*acc**2*dor*n*p - 2*acc**2*dor*p**2 + acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 2*acc*dor**2*n**2 - 4*acc*dor**2*n*p - 2*acc*dor**2*p**2 + 2*acc*dor*n**2 + 4*acc*dor*n*p + 2*acc*dor*p**2 + dor**2*n**2 + 2*dor**2*n*p + dor**2*p**2 - 4*dor*n*p))/(2*(dor - 1))}]
# acc mcc
# 2 [{fn: (-mcc*sqrt(-n*p*(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - acc*n**2 - 2*acc*n*p - acc*p**2 - mcc**2*n*p + n*p))*(n + p) - p*(2*acc*mcc**2*n**2 + 2*acc*mcc**2*n*p - acc*n**2 + acc*p**2 - mcc**2*n**2 - 3*mcc**2*n*p + n*p - p**2))/(4*mcc**2*n*p + n**2 - 2*n*p + p**2), fp: (mcc*sqrt(-n*p*(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - acc*n**2 - 2*acc*n*p - acc*p**2 - mcc**2*n*p + n*p))*(n + p) + p*(2*acc*mcc**2*n**2 + 2*acc*mcc**2*n*p - acc*n**2 + acc*p**2 - mcc**2*n**2 - 3*mcc**2*n*p + n*p - p**2) + (-acc*n - acc*p + n + p)*(4*mcc**2*n*p + n**2 - 2*n*p + p**2))/(4*mcc**2*n*p + n**2 - 2*n*p + p**2), tn: (-mcc*sqrt(-n*p*(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - acc*n**2 - 2*acc*n*p - acc*p**2 - mcc**2*n*p + n*p))*(n + p) - p*(2*acc*mcc**2*n**2 + 2*acc*mcc**2*n*p - acc*n**2 + acc*p**2 - mcc**2*n**2 - 3*mcc**2*n*p + n*p - p**2) + (acc*n + acc*p - p)*(4*mcc**2*n*p + n**2 - 2*n*p + p**2))/(4*mcc**2*n*p + n**2 - 2*n*p + p**2), tp: (mcc*sqrt(-n*p*(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - acc*n**2 - 2*acc*n*p - acc*p**2 - mcc**2*n*p + n*p))*(n + p) + p*(4*mcc**2*n*p + n**2 - 2*n*p + p**2) + p*(2*acc*mcc**2*n**2 + 2*acc*mcc**2*n*p - acc*n**2 + acc*p**2 - mcc**2*n**2 - 3*mcc**2*n*p + n*p - p**2))/(4*mcc**2*n*p + n**2 - 2*n*p + p**2)}, {fn: (mcc*sqrt(-n*p*(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - acc*n**2 - 2*acc*n*p - acc*p**2 - mcc**2*n*p + n*p))*(n + p) - p*(2*acc*mcc**2*n**2 + 2*acc*mcc**2*n*p - acc*n**2 + acc*p**2 - mcc**2*n**2 - 3*mcc**2*n*p + n*p - p**2))/(4*mcc**2*n*p + n**2 - 2*n*p + p**2), fp: (-mcc*sqrt(-n*p*(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - acc*n**2 - 2*acc*n*p - acc*p**2 - mcc**2*n*p + n*p))*(n + p) + p*(2*acc*mcc**2*n**2 + 2*acc*mcc**2*n*p - acc*n**2 + acc*p**2 - mcc**2*n**2 - 3*mcc**2*n*p + n*p - p**2) + (-acc*n - acc*p + n + p)*(4*mcc**2*n*p + n**2 - 2*n*p + p**2))/(4*mcc**2*n*p + n**2 - 2*n*p + p**2), tn: (mcc*sqrt(-n*p*(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - acc*n**2 - 2*acc*n*p - acc*p**2 - mcc**2*n*p + n*p))*(n + p) - p*(2*acc*mcc**2*n**2 + 2*acc*mcc**2*n*p - acc*n**2 + acc*p**2 - mcc**2*n**2 - 3*mcc**2*n*p + n*p - p**2) + (acc*n + acc*p - p)*(4*mcc**2*n*p + n**2 - 2*n*p + p**2))/(4*mcc**2*n*p + n**2 - 2*n*p + p**2), tp: (-mcc*sqrt(-n*p*(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - acc*n**2 - 2*acc*n*p - acc*p**2 - mcc**2*n*p + n*p))*(n + p) + p*(4*mcc**2*n*p + n**2 - 2*n*p + p**2) + p*(2*acc*mcc**2*n**2 + 2*acc*mcc**2*n*p - acc*n**2 + acc*p**2 - mcc**2*n**2 - 3*mcc**2*n*p + n*p - p**2))/(4*mcc**2*n*p + n**2 - 2*n*p + p**2)}]
# acc ji
# 1 [{tp: (acc*ji*n + acc*ji*p - ji*n - ji*p)/(ji - 1), tn: (-acc*n - acc*p + ji*n + ji*p)/(ji - 1), fp: (acc*n + acc*p - ji*p - n)/(ji - 1), fn: (-acc*ji*n - acc*ji*p + ji*n + 2*ji*p - p)/(ji - 1)}]
# acc ba
# 1 [{tp: (acc*n*p + acc*p**2 - 2.0*ba*n*p)/(-n + p), tn: (-acc*n**2 - acc*n*p + 2.0*ba*n*p)/(-n + p), fp: (acc*n**2 + acc*n*p - 2.0*ba*n*p - n**2 + n*p)/(-n + p), fn: (-acc*n*p - acc*p**2 + 2.0*ba*n*p - n*p + p**2)/(-n + p)}]
# acc kappa
# 1 [{fn: -(-acc*kappa*n**2 + acc*kappa*p**2 + 2*acc*n**2 + 2*acc*n*p - kappa*n**2 + 2*kappa*n*p - 3*kappa*p**2 - 4*n*p + 2*p**2)/(2*(kappa - 1)*(-n + p)), fp: -(-acc*kappa*n**2 + acc*kappa*p**2 - 2*acc*n*p - 2*acc*p**2 + 3*kappa*n**2 - 2*kappa*n*p + kappa*p**2 - 2*n**2 + 4*n*p)/(2*(kappa - 1)*(-n + p)), tn: (-acc*kappa*n**2 + acc*kappa*p**2 - 2*acc*n*p - 2*acc*p**2 + kappa*n**2 + kappa*p**2 + 2*n*p)/(2*(kappa - 1)*(-n + p)), tp: (-acc*kappa*n**2 + acc*kappa*p**2 + 2*acc*n**2 + 2*acc*n*p - kappa*n**2 - kappa*p**2 - 2*n*p)/(2*(kappa - 1)*(-n + p))}]
# acc gm
# 2 [{fn: -acc*n/2 - acc*p/2 + p - sqrt(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 4*gm**2*n*p)/2, fp: -acc*n/2 - acc*p/2 + n + sqrt(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 4*gm**2*n*p)/2, tn: acc*n/2 + acc*p/2 - sqrt(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 4*gm**2*n*p)/2, tp: acc*n/2 + acc*p/2 + sqrt(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 4*gm**2*n*p)/2}, {fn: -acc*n/2 - acc*p/2 + p + sqrt(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 4*gm**2*n*p)/2, fp: -acc*n/2 - acc*p/2 + n - sqrt(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 4*gm**2*n*p)/2, tn: acc*n/2 + acc*p/2 + sqrt(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 4*gm**2*n*p)/2, tp: acc*n/2 + acc*p/2 - sqrt(acc**2*n**2 + 2*acc**2*n*p + acc**2*p**2 - 4*gm**2*n*p)/2}]
# acc upm
# 4 [{fn: (-acc*n*upm + acc*n - acc*p*upm + acc*p - n*sqrt(-acc**2*upm + acc**2 + acc*upm**2 - acc*upm) + 2*p*upm - p*sqrt(-acc**2*upm + acc**2 + acc*upm**2 - acc*upm) - 2*p)/(2*upm - 2), fp: (-acc*n*upm + acc*n - acc*p*upm + acc*p + 2*n*upm + n*sqrt(acc*(-acc*upm + acc + upm**2 - upm)) - 2*n + p*sqrt(acc*(-acc*upm + acc + upm**2 - upm)))/(2*(upm - 1)), tn: (acc*n*upm - acc*n + acc*p*upm - acc*p - n*sqrt(acc*(-acc*upm + acc + upm**2 - upm)) - p*sqrt(acc*(-acc*upm + acc + upm**2 - upm)))/(2*(upm - 1)), tp: (acc*n*upm - acc*n + acc*p*upm - acc*p + n*sqrt(acc*(-acc*upm + acc + upm**2 - upm)) + p*sqrt(acc*(-acc*upm + acc + upm**2 - upm)))/(2*(upm - 1))}, {fn: (-acc*n*upm + acc*n - acc*p*upm + acc*p + n*sqrt(-acc**2*upm + acc**2 + acc*upm**2 - acc*upm) + 2*p*upm + p*sqrt(-acc**2*upm + acc**2 + acc*upm**2 - acc*upm) - 2*p)/(2*upm - 2), fp: (-acc*n*upm + acc*n - acc*p*upm + acc*p + 2*n*upm - n*sqrt(acc*(-acc*upm + acc + upm**2 - upm)) - 2*n - p*sqrt(acc*(-acc*upm + acc + upm**2 - upm)))/(2*(upm - 1)), tn: (acc*n*upm - acc*n + acc*p*upm - acc*p + n*sqrt(acc*(-acc*upm + acc + upm**2 - upm)) + p*sqrt(acc*(-acc*upm + acc + upm**2 - upm)))/(2*(upm - 1)), tp: (acc*n*upm - acc*n + acc*p*upm - acc*p - n*sqrt(acc*(-acc*upm + acc + upm**2 - upm)) - p*sqrt(acc*(-acc*upm + acc + upm**2 - upm)))/(2*(upm - 1))}, {fn: -acc*n/2 - acc*p/2 - n/2 + p/2, fp: -(acc*n + acc*p - 3*n - p)/2, tn: (acc - 1)*(n + p)/2, tp: (acc + 1)*(n + p)/2}, {fn: -acc*n/2 - acc*p/2 + n/2 + 3*p/2, fp: -(acc*n + acc*p - n + p)/2, tn: (acc + 1)*(n + p)/2, tp: (acc - 1)*(n + p)/2}]
# sens spec
# 1 [{tp: p*sens, fn: -p*sens + p, tn: n*spec, fp: -n*spec + n}]
# sens npv
# 1 [{tp: p*sens, tn: (npv*p*sens - npv*p)/(npv - 1), fp: (n*npv - n - npv*p*sens + npv*p)/(npv - 1), fn: -p*sens + p}]
# sens ppv
# 1 [{tp: p*sens, tn: (n*ppv + p*ppv*sens - p*sens)/ppv, fp: (-p*ppv*sens + p*sens)/ppv, fn: -p*sens + p}]
# sens f1_plus
# 1 [{tp: p*sens, tn: (f1_plus*n + f1_plus*p*sens + f1_plus*p - 2*p*sens)/f1_plus, fp: (-f1_plus*p*sens - f1_plus*p + 2*p*sens)/f1_plus, fn: -p*sens + p}]
# sens f1_minus
# 1 [{tp: p*sens, tn: (-f1_minus*n + f1_minus*p*sens - f1_minus*p)/(f1_minus - 2), fp: (2*f1_minus*n - f1_minus*p*sens + f1_minus*p - 2*n)/(f1_minus - 2), fn: -p*sens + p}]
# sens fm
# 1 [{fn: -p*(sens - 1), fp: -p*sens*(fm**2 - sens)/fm**2, tn: (fm**2*n + fm**2*p*sens - p*sens**2)/fm**2, tp: p*sens}]
# sens bm
# 1 [{tp: p*sens, tn: bm*n - n*sens + n, fp: -bm*n + n*sens, fn: -p*sens + p}]
# sens pt
# 2 [{fn: p*(1 - sens), fp: n*sens, tn: n*(1 - sens), tp: p*sens}, {fn: p*(1 - sens), fp: n*pt**2*sens/(pt**2 - 2*pt + 1), tn: n*(-pt**2*sens + pt**2 - 2*pt + 1)/(pt**2 - 2*pt + 1), tp: p*sens}]
# sens lrp
# 1 [{tp: p*sens, tn: (lrp*n - n*sens)/lrp, fp: n*sens/lrp, fn: -p*sens + p}]
# sens lrn
# 1 [{tp: p*sens, tn: (-n*sens + n)/lrn, fp: (lrn*n + n*sens - n)/lrn, fn: -p*sens + p}]
# sens mk
# 2 [{fn: -p*(sens - 1), fp: -(-mk*n + 2*mk*p*sens - mk*p - p)/(2*mk) - sqrt(mk**2*n**2 + 2*mk**2*n*p + mk**2*p**2 - 4*mk*n*p*sens + 2*mk*n*p - 4*mk*p**2*sens + 2*mk*p**2 + p**2)/(2*mk), tn: (mk*n + 2*mk*p*sens - mk*p - p + sqrt(mk**2*n**2 + 2*mk**2*n*p + mk**2*p**2 - 4*mk*n*p*sens + 2*mk*n*p - 4*mk*p**2*sens + 2*mk*p**2 + p**2))/(2*mk), tp: p*sens}, {fn: -p*(sens - 1), fp: -(-mk*n + 2*mk*p*sens - mk*p - p)/(2*mk) + sqrt(mk**2*n**2 + 2*mk**2*n*p + mk**2*p**2 - 4*mk*n*p*sens + 2*mk*n*p - 4*mk*p**2*sens + 2*mk*p**2 + p**2)/(2*mk), tn: (mk*n + 2*mk*p*sens - mk*p - p - sqrt(mk**2*n**2 + 2*mk**2*n*p + mk**2*p**2 - 4*mk*n*p*sens + 2*mk*n*p - 4*mk*p**2*sens + 2*mk*p**2 + p**2))/(2*mk), tp: p*sens}]
# sens dor
# 1 [{fn: -p*(sens - 1), fp: -n*sens/(dor*sens - dor - sens), tn: dor*n*(sens - 1)/(dor*sens - dor - sens), tp: p*sens}]
# sens mcc
# 2 [{fn: p*(1 - sens), fp: (-mcc*sqrt(n*(mcc**2*n - 4*p*sens**2 + 4*p*sens))*(n + p) + n*(mcc**2*n - 2*mcc**2*p*sens + mcc**2*p + 2*p*sens))/(2*(mcc**2*n + p)), tn: (mcc*sqrt(n*(mcc**2*n - 4*p*sens**2 + 4*p*sens))*(n + p)/2 + n*(mcc**2*n + p) - n*(mcc**2*n - 2*mcc**2*p*sens + mcc**2*p + 2*p*sens)/2)/(mcc**2*n + p), tp: p*sens}, {fn: p*(1 - sens), fp: (mcc*sqrt(n*(mcc**2*n - 4*p*sens**2 + 4*p*sens))*(n + p) + n*(mcc**2*n - 2*mcc**2*p*sens + mcc**2*p + 2*p*sens))/(2*(mcc**2*n + p)), tn: (-mcc*sqrt(n*(mcc**2*n - 4*p*sens**2 + 4*p*sens))*(n + p)/2 + n*(mcc**2*n + p) - n*(mcc**2*n - 2*mcc**2*p*sens + mcc**2*p + 2*p*sens)/2)/(mcc**2*n + p), tp: p*sens}]
# sens ji
# 1 [{tp: p*sens, tn: (ji*n + ji*p - p*sens)/ji, fp: (-ji*p + p*sens)/ji, fn: -p*sens + p}]
# sens ba
# 1 [{tp: p*sens, tn: 2.0*ba*n - n*sens, fp: -2.0*ba*n + n*sens + n, fn: -p*sens + p}]
# sens kappa
# 2 [{fn: -p*(sens - 1), fp: (-2*kappa*n**2 + kappa*n*p*sens + kappa*n*p - kappa*p**2*sens - kappa*p**2 + 2*n**2 - 2*n*p + 2*p**2*sens)/(-kappa*n + kappa*p + 2*n), tn: (kappa*n**2 - kappa*n*p*sens + kappa*p**2*sens + kappa*p**2 + 2*n*p - 2*p**2*sens)/(-kappa*n + kappa*p + 2*n), tp: p*sens}, {fn: -p*(sens - 1), fp: n + p*sens, tn: -p*sens, tp: p*sens}]
# sens gm
# 1 [{fn: -p*(sens - 1), fp: -n*(gm**2 - sens)/sens, tn: gm**2*n/sens, tp: p*sens}]
# sens upm
# 4 [{fn: -p*(sens - 1), fp: (n*upm - 2*p*sens*upm + 4*p*sens - p*upm - sqrt(n**2*upm**2 + 8*n*p*sens*upm**2 - 8*n*p*sens*upm + 2*n*p*upm**2 - 16*p**2*sens**2*upm + 16*p**2*sens**2 + 8*p**2*sens*upm**2 - 8*p**2*sens*upm + p**2*upm**2))/(2*upm), tn: n/2 + p*sens - 2*p*sens/upm + p/2 + sqrt(n**2*upm**2 + 8*n*p*sens*upm**2 - 8*n*p*sens*upm + 2*n*p*upm**2 - 16*p**2*sens**2*upm + 16*p**2*sens**2 + 8*p**2*sens*upm**2 - 8*p**2*sens*upm + p**2*upm**2)/(2*upm), tp: p*sens}, {fn: -p*(sens - 1), fp: (n*upm - 2*p*sens*upm + 4*p*sens - p*upm + sqrt(n**2*upm**2 + 8*n*p*sens*upm**2 - 8*n*p*sens*upm + 2*n*p*upm**2 - 16*p**2*sens**2*upm + 16*p**2*sens**2 + 8*p**2*sens*upm**2 - 8*p**2*sens*upm + p**2*upm**2))/(2*upm), tn: n/2 + p*sens - 2*p*sens/upm + p/2 - sqrt(n**2*upm**2 + 8*n*p*sens*upm**2 - 8*n*p*sens*upm + 2*n*p*upm**2 - 16*p**2*sens**2*upm + 16*p**2*sens**2 + 8*p**2*sens*upm**2 - 8*p**2*sens*upm + p**2*upm**2)/(2*upm), tp: p*sens}, {fn: -p*(sens - 1), fp: -p*sens - p, tn: n + p*sens + p, tp: p*sens}, {fn: -p*(sens - 1), fp: 2*n - p*sens + p, tn: -n + p*sens - p, tp: p*sens}]
# spec npv
# 1 [{tp: (n*npv*spec - n*spec + npv*p)/npv, tn: n*spec, fp: -n*spec + n, fn: (-n*npv*spec + n*spec)/npv}]
# spec ppv
# 1 [{tp: (n*ppv*spec - n*ppv)/(ppv - 1), tn: n*spec, fp: -n*spec + n, fn: (-n*ppv*spec + n*ppv + p*ppv - p)/(ppv - 1)}]
# spec f1_plus
# 1 [{tp: (f1_plus*n*spec - f1_plus*n - f1_plus*p)/(f1_plus - 2), tn: n*spec, fp: -n*spec + n, fn: (-f1_plus*n*spec + f1_plus*n + 2*f1_plus*p - 2*p)/(f1_plus - 2)}]
# spec f1_minus
# 1 [{tp: (f1_minus*n*spec + f1_minus*n + f1_minus*p - 2*n*spec)/f1_minus, tn: n*spec, fp: -n*spec + n, fn: (-f1_minus*n*spec - f1_minus*n + 2*n*spec)/f1_minus}]
# spec fm
# 2 [{fn: -fm*sqrt(p*(fm**2*p - 4*n*spec + 4*n))/2 - p*(fm**2 - 2)/2, fp: -n*(spec - 1), tn: n*spec, tp: fm*(fm*p + sqrt(p*(fm**2*p - 4*n*spec + 4*n)))/2}, {fn: fm*sqrt(p*(fm**2*p - 4*n*spec + 4*n))/2 - p*(fm**2 - 2)/2, fp: -n*(spec - 1), tn: n*spec, tp: fm*(fm*p - sqrt(p*(fm**2*p - 4*n*spec + 4*n)))/2}]
# spec bm
# 1 [{tp: bm*p - p*spec + p, tn: n*spec, fp: -n*spec + n, fn: -bm*p + p*spec}]
# spec pt
# 2 [{fn: p*spec, fp: n*(1 - spec), tn: n*spec, tp: p*(1 - spec)}, {fn: p*(pt**2*spec - 2*pt*spec + 2*pt + spec - 1)/pt**2, fp: n*(1 - spec), tn: n*spec, tp: p*(-pt**2*spec + pt**2 + 2*pt*spec - 2*pt - spec + 1)/pt**2}]
# spec lrp
# 1 [{tp: -lrp*p*spec + lrp*p, tn: n*spec, fp: -n*spec + n, fn: lrp*p*spec - lrp*p + p}]
# spec lrn
# 1 [{tp: -lrn*p*spec + p, tn: n*spec, fp: -n*spec + n, fn: lrn*p*spec}]
# spec mk
# 2 [{fn: (-2*mk*n*spec + mk*n + mk*p + n)/(2*mk) - sqrt(mk**2*n**2 + 2*mk**2*n*p + mk**2*p**2 - 4*mk*n**2*spec + 2*mk*n**2 - 4*mk*n*p*spec + 2*mk*n*p + n**2)/(2*mk), fp: -n*(spec - 1), tn: n*spec, tp: (2*mk*n*spec - mk*n + mk*p - n + sqrt(mk**2*n**2 + 2*mk**2*n*p + mk**2*p**2 - 4*mk*n**2*spec + 2*mk*n**2 - 4*mk*n*p*spec + 2*mk*n*p + n**2))/(2*mk)}, {fn: (-2*mk*n*spec + mk*n + mk*p + n)/(2*mk) + sqrt(mk**2*n**2 + 2*mk**2*n*p + mk**2*p**2 - 4*mk*n**2*spec + 2*mk*n**2 - 4*mk*n*p*spec + 2*mk*n*p + n**2)/(2*mk), fp: -n*(spec - 1), tn: n*spec, tp: (2*mk*n*spec - mk*n + mk*p - n - sqrt(mk**2*n**2 + 2*mk**2*n*p + mk**2*p**2 - 4*mk*n**2*spec + 2*mk*n**2 - 4*mk*n*p*spec + 2*mk*n*p + n**2))/(2*mk)}]
# spec dor
# 1 [{fn: -p*spec/(dor*spec - dor - spec), fp: -n*(spec - 1), tn: n*spec, tp: dor*p*(spec - 1)/(dor*spec - dor - spec)}]
# spec mcc
# 2 [{fn: (-mcc*sqrt(p*(mcc**2*p - 4*n*spec**2 + 4*n*spec))*(n + p) + p*(-2*mcc**2*n*spec + mcc**2*n + mcc**2*p + 2*n*spec))/(2*(mcc**2*p + n)), fp: n*(1 - spec), tn: n*spec, tp: (mcc*sqrt(p*(mcc**2*p - 4*n*spec**2 + 4*n*spec))*(n + p)/2 + p*(mcc**2*p + n) - p*(-2*mcc**2*n*spec + mcc**2*n + mcc**2*p + 2*n*spec)/2)/(mcc**2*p + n)}, {fn: (mcc*sqrt(p*(mcc**2*p - 4*n*spec**2 + 4*n*spec))*(n + p) + p*(-2*mcc**2*n*spec + mcc**2*n + mcc**2*p + 2*n*spec))/(2*(mcc**2*p + n)), fp: n*(1 - spec), tn: n*spec, tp: (-mcc*sqrt(p*(mcc**2*p - 4*n*spec**2 + 4*n*spec))*(n + p)/2 + p*(mcc**2*p + n) - p*(-2*mcc**2*n*spec + mcc**2*n + mcc**2*p + 2*n*spec)/2)/(mcc**2*p + n)}]
# spec ji
# 1 [{tp: -ji*n*spec + ji*n + ji*p, tn: n*spec, fp: -n*spec + n, fn: ji*n*spec - ji*n - ji*p + p}]
# spec ba
# 1 [{tp: 2.0*ba*p - p*spec, tn: n*spec, fp: -n*spec + n, fn: -2.0*ba*p + p*spec + p}]
# spec kappa
# 2 [{fn: (kappa*n**2*spec + kappa*n**2 - kappa*n*p*spec - kappa*n*p + 2*kappa*p**2 - 2*n**2*spec + 2*n*p - 2*p**2)/(-kappa*n + kappa*p - 2*p), fp: -n*(spec - 1), tn: n*spec, tp: -(kappa*n**2*spec + kappa*n**2 - kappa*n*p*spec + kappa*p**2 - 2*n**2*spec + 2*n*p)/(-kappa*n + kappa*p - 2*p)}, {fn: n*spec + p, fp: -n*(spec - 1), tn: n*spec, tp: -n*spec}]
# spec gm
# 1 [{fn: -p*(gm**2 - spec)/spec, fp: -n*(spec - 1), tn: n*spec, tp: gm**2*p/spec}]
# spec upm
# 4 [{fn: (-2*n*spec*upm + 4*n*spec - n*upm + p*upm - sqrt(-16*n**2*spec**2*upm + 16*n**2*spec**2 + 8*n**2*spec*upm**2 - 8*n**2*spec*upm + n**2*upm**2 + 8*n*p*spec*upm**2 - 8*n*p*spec*upm + 2*n*p*upm**2 + p**2*upm**2))/(2*upm), fp: -n*(spec - 1), tn: n*spec, tp: n*spec - 2*n*spec/upm + n/2 + p/2 + sqrt(-16*n**2*spec**2*upm + 16*n**2*spec**2 + 8*n**2*spec*upm**2 - 8*n**2*spec*upm + n**2*upm**2 + 8*n*p*spec*upm**2 - 8*n*p*spec*upm + 2*n*p*upm**2 + p**2*upm**2)/(2*upm)}, {fn: (-2*n*spec*upm + 4*n*spec - n*upm + p*upm + sqrt(-16*n**2*spec**2*upm + 16*n**2*spec**2 + 8*n**2*spec*upm**2 - 8*n**2*spec*upm + n**2*upm**2 + 8*n*p*spec*upm**2 - 8*n*p*spec*upm + 2*n*p*upm**2 + p**2*upm**2))/(2*upm), fp: -n*(spec - 1), tn: n*spec, tp: n*spec - 2*n*spec/upm + n/2 + p/2 - sqrt(-16*n**2*spec**2*upm + 16*n**2*spec**2 + 8*n**2*spec*upm**2 - 8*n**2*spec*upm + n**2*upm**2 + 8*n*p*spec*upm**2 - 8*n*p*spec*upm + 2*n*p*upm**2 + p**2*upm**2)/(2*upm)}, {fn: -n*spec - n, fp: -n*(spec - 1), tn: n*spec, tp: n*spec + n + p}, {fn: -n*spec + n + 2*p, fp: -n*(spec - 1), tn: n*spec, tp: n*spec - n - p}]
# npv ppv
# 1 [{tp: (n*npv*ppv - n*ppv + npv*p*ppv)/(npv + ppv - 1), tn: (n*npv*ppv + npv*p*ppv - npv*p)/(npv + ppv - 1), fp: (-n*npv*ppv + n*npv + n*ppv - n - npv*p*ppv + npv*p)/(npv + ppv - 1), fn: (-n*npv*ppv + n*ppv - npv*p*ppv + npv*p + p*ppv - p)/(npv + ppv - 1)}]
# npv f1_plus
# 1 [{tp: (f1_plus*n*npv - f1_plus*n + 2*f1_plus*npv*p - f1_plus*p)/(f1_plus + 2*npv - 2), tn: (f1_plus*n*npv + 2*f1_plus*npv*p - 2*npv*p)/(f1_plus + 2*npv - 2), fp: (-f1_plus*n*npv + f1_plus*n - 2*f1_plus*npv*p + 2*n*npv - 2*n + 2*npv*p)/(f1_plus + 2*npv - 2), fn: (-f1_plus*n*npv + f1_plus*n - 2*f1_plus*npv*p + 2*f1_plus*p + 2*npv*p - 2*p)/(f1_plus + 2*npv - 2)}]
# npv f1_minus
# 1 [{tp: (-f1_minus*n*npv + f1_minus*n + f1_minus*p - 2*npv*p)/(f1_minus - 2*npv), tn: -f1_minus*n*npv/(f1_minus - 2*npv), fp: (f1_minus*n*npv + f1_minus*n - 2*n*npv)/(f1_minus - 2*npv), fn: (f1_minus*n*npv - f1_minus*n)/(f1_minus - 2*npv)}]
# npv fm
# 2 [{fn: -fm*sqrt(p*(fm**2*p + 4*n*npv**2 - 8*n*npv + 4*n + 4*npv**2*p - 4*npv*p))/(2*(npv - 1)) + p*(fm**2 + 2*npv - 2)/(2*(npv - 1)), fp: (fm**2*npv*p/2 - fm*npv*sqrt(p*(fm**2*p + 4*n*npv**2 - 8*n*npv + 4*n + 4*npv**2*p - 4*npv*p))/2 + n*npv**2 - 2*n*npv + n + npv**2*p - npv*p)/(npv**2 - 2*npv + 1), tn: npv*(-fm**2*p + fm*sqrt(p*(fm**2*p + 4*n*npv**2 - 8*n*npv + 4*n + 4*npv**2*p - 4*npv*p)) - 2*npv*p + 2*p)/(2*(npv**2 - 2*npv + 1)), tp: fm*(-fm*p + sqrt(p*(fm**2*p + 4*n*npv**2 - 8*n*npv + 4*n + 4*npv**2*p - 4*npv*p)))/(2*(npv - 1))}, {fn: fm*sqrt(p*(fm**2*p + 4*n*npv**2 - 8*n*npv + 4*n + 4*npv**2*p - 4*npv*p))/(2*(npv - 1)) + p*(fm**2 + 2*npv - 2)/(2*(npv - 1)), fp: (fm**2*npv*p/2 + fm*npv*sqrt(p*(fm**2*p + 4*n*npv**2 - 8*n*npv + 4*n + 4*npv**2*p - 4*npv*p))/2 + n*npv**2 - 2*n*npv + n + npv**2*p - npv*p)/(npv**2 - 2*npv + 1), tn: npv*(-fm**2*p - fm*sqrt(p*(fm**2*p + 4*n*npv**2 - 8*n*npv + 4*n + 4*npv**2*p - 4*npv*p)) - 2*npv*p + 2*p)/(2*(npv**2 - 2*npv + 1)), tp: fm*(-fm*p - sqrt(p*(fm**2*p + 4*n*npv**2 - 8*n*npv + 4*n + 4*npv**2*p - 4*npv*p)))/(2*(npv - 1))}]
# npv bm
# 1 [{tp: (bm*n*npv*p - bm*n*p + n*npv*p - n*p + npv*p**2)/(n*npv - n + npv*p), tn: bm*n*npv*p/(n*npv - n + npv*p), fp: (-bm*n*npv*p + n**2*npv - n**2 + n*npv*p)/(n*npv - n + npv*p), fn: (-bm*n*npv*p + bm*n*p)/(n*npv - n + npv*p)}]
# npv pt
# 2 [{fn: 0, fp: n, tn: 0, tp: p}, {fn: n*p*(2*npv*pt - npv - 2*pt + 1)/(n*npv*pt**2 - n*pt**2 + npv*p*pt**2 - 2*npv*p*pt + npv*p), fp: n*pt**2*(n*npv - n + npv*p)/(n*npv*pt**2 - n*pt**2 + npv*p*pt**2 - 2*npv*p*pt + npv*p), tn: n*npv*p*(1 - 2*pt)/(n*npv*pt**2 - n*pt**2 + npv*p*pt**2 - 2*npv*p*pt + npv*p), tp: p*(n*npv*pt**2 - n*pt**2 - n*(2*npv*pt - npv - 2*pt + 1) + npv*p*pt**2 - 2*npv*p*pt + npv*p)/(n*npv*pt**2 - n*pt**2 + npv*p*pt**2 - 2*npv*p*pt + npv*p)}]
# npv lrp
# 1 [{tp: (lrp*n*npv*p - lrp*n*p + lrp*npv*p**2)/(lrp*npv*p + n*npv - n), tn: (lrp*n*npv*p - n*npv*p)/(lrp*npv*p + n*npv - n), fp: (n**2*npv - n**2 + n*npv*p)/(lrp*npv*p + n*npv - n), fn: (-lrp*n*npv*p + lrp*n*p + n*npv*p - n*p)/(lrp*npv*p + n*npv - n)}]
# npv lrn
# 1 [{tp: p, tn: 0, fp: n, fn: 0}]
# npv mk
# 2 [{fn: 0, fp: n, tn: 0, tp: p}, {fn: -(npv - 1)*(mk*n + mk*p - n*npv + n - npv*p)/mk, fp: -(mk - npv)*(n*npv - n + npv*p)/mk, tn: npv*(mk*n + mk*p - n*npv + n - npv*p)/mk, tp: (mk - npv + 1)*(n*npv - n + npv*p)/mk}]
# npv dor
# 2 [{fn: 0, fp: n, tn: 0, tp: p}, {fn: -(dor*n*npv - dor*n + npv*p)/(npv*(dor - 1)), fp: -(n*npv - n + npv*p)/((dor - 1)*(npv - 1)), tn: (dor*n*npv - dor*n + npv*p)/((dor - 1)*(npv - 1)), tp: dor*(n*npv - n + npv*p)/(npv*(dor - 1))}]
# npv mcc
# 2 [{fn: 0, fp: n, tn: 0, tp: p}, {fn: mcc**2*n*p*(-n*npv + n - npv*p + p)/(mcc**2*n*p + n**2*npv**2 - 2*n**2*npv + n**2 + 2*n*npv**2*p - 2*n*npv*p + npv**2*p**2), fp: n*(-mcc**2*n*npv*p + mcc**2*n*p - mcc**2*npv*p**2 + n**2*npv**2 - 2*n**2*npv + n**2 + 2*n*npv**2*p - 2*n*npv*p + npv**2*p**2)/(mcc**2*n*p + n**2*npv**2 - 2*n**2*npv + n**2 + 2*n*npv**2*p - 2*n*npv*p + npv**2*p**2), tn: mcc**2*n*npv*p*(n + p)/(mcc**2*n*p + n**2*npv**2 - 2*n**2*npv + n**2 + 2*n*npv**2*p - 2*n*npv*p + npv**2*p**2), tp: mcc**2*n*p*(n*npv - n + npv*p - p)/(mcc**2*n*p + n**2*npv**2 - 2*n**2*npv + n**2 + 2*n*npv**2*p - 2*n*npv*p + npv**2*p**2) + p}]
# npv ji
# 1 [{tp: (ji*n*npv - ji*n + 2*ji*npv*p - ji*p)/(ji*npv + npv - 1), tn: (ji*n*npv + ji*npv*p - npv*p)/(ji*npv + npv - 1), fp: (-ji*npv*p + n*npv - n + npv*p)/(ji*npv + npv - 1), fn: (-ji*n*npv + ji*n - ji*npv*p + ji*p + npv*p - p)/(ji*npv + npv - 1)}]
# npv ba
# 1 [{tp: (2.0*ba*n*npv*p - 2.0*ba*n*p + npv*p**2)/(n*npv - n + npv*p), tn: (2.0*ba*n*npv*p - n*npv*p)/(n*npv - n + npv*p), fp: (-2.0*ba*n*npv*p + n**2*npv - n**2 + 2.0*n*npv*p)/(n*npv - n + npv*p), fn: (-2.0*ba*n*npv*p + 2.0*ba*n*p + n*npv*p - n*p)/(n*npv - n + npv*p)}]
# npv kappa
# 2 [{fn: (npv*p - p)/(2*npv - 1), fp: (2*n*npv - n + npv*p)/(2*npv - 1), tn: -npv*p/(2*npv - 1), tp: npv*p/(2*npv - 1)}, {fn: (-kappa*n**2*npv + kappa*n**2 + kappa*n*npv*p - kappa*n*p - 2*kappa*npv*p**2 + 2*kappa*p**2 - 2*n*npv*p + 2*n*p + 2*npv*p**2 - 2*p**2)/(-kappa*n + kappa*p + 2*n*npv + 2*npv*p - 2*p), fp: -(kappa*n**2*npv + kappa*n**2 - kappa*n*npv*p - kappa*n*p + 2*kappa*npv*p**2 - 2*n**2*npv + 2*n*p - 2*npv*p**2)/(-kappa*n + kappa*p + 2*n*npv + 2*npv*p - 2*p), tn: npv*(kappa*n**2 - kappa*n*p + 2*kappa*p**2 + 2*n*p - 2*p**2)/(-kappa*n + kappa*p + 2*n*npv + 2*npv*p - 2*p), tp: (kappa*n**2*npv - kappa*n**2 - kappa*n*npv*p + 2*kappa*npv*p**2 - kappa*p**2 + 4*n*npv*p - 2*n*p)/(-kappa*n + kappa*p + 2*n*npv + 2*npv*p - 2*p)}]
# npv gm
# 2 [{fn: p/2 - sqrt(npv*p*(4*gm**2*n*npv - 4*gm**2*n + npv*p))/(2*npv), fp: (n*npv - n + npv*p/2 - sqrt(npv*p*(4*gm**2*n*npv - 4*gm**2*n + npv*p))/2)/(npv - 1), tn: (-npv*p + sqrt(npv*p*(4*gm**2*n*npv - 4*gm**2*n + npv*p)))/(2*(npv - 1)), tp: (npv*p + sqrt(npv*p*(4*gm**2*n*npv - 4*gm**2*n + npv*p)))/(2*npv)}, {fn: p/2 + sqrt(npv*p*(4*gm**2*n*npv - 4*gm**2*n + npv*p))/(2*npv), fp: (n*npv - n + npv*p/2 + sqrt(npv*p*(4*gm**2*n*npv - 4*gm**2*n + npv*p))/2)/(npv - 1), tn: (-npv*p - sqrt(npv*p*(4*gm**2*n*npv - 4*gm**2*n + npv*p)))/(2*(npv - 1)), tp: (npv*p - sqrt(npv*p*(4*gm**2*n*npv - 4*gm**2*n + npv*p)))/(2*npv)}]
# npv upm
# 4 [{fn: (-2*n*npv**2*upm + 3*n*npv*upm - n*upm - 2*npv**2*p*upm + 4*npv**2*p + npv*p*upm - 4*npv*p - npv*sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2) + p*upm + sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2))/(8*npv**2 - 8*npv + 2*upm), fp: (-n*npv**2*upm + 4*n*npv**2 + n*npv*upm/2 - 4*n*npv + n*upm - npv**2*p*upm + 2*npv**2*p - npv*p*upm/2 - npv*sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2)/2)/(4*npv**2 - 4*npv + upm), tn: npv*(2*n*npv*upm - n*upm + 2*npv*p*upm - 4*npv*p + p*upm + sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2))/(2*(4*npv**2 - 4*npv + upm)), tp: (2*n*npv**2*upm - 3*n*npv*upm + n*upm + 2*npv**2*p*upm + 4*npv**2*p - npv*p*upm - 4*npv*p + npv*sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2) + p*upm - sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2))/(2*(4*npv**2 - 4*npv + upm))}, {fn: (-2*n*npv**2*upm + 3*n*npv*upm - n*upm - 2*npv**2*p*upm + 4*npv**2*p + npv*p*upm - 4*npv*p + npv*sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2) + p*upm - sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2))/(8*npv**2 - 8*npv + 2*upm), fp: (-n*npv**2*upm + 4*n*npv**2 + n*npv*upm/2 - 4*n*npv + n*upm - npv**2*p*upm + 2*npv**2*p - npv*p*upm/2 + npv*sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2)/2)/(4*npv**2 - 4*npv + upm), tn: npv*(2*n*npv*upm - n*upm + 2*npv*p*upm - 4*npv*p + p*upm - sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2))/(2*(4*npv**2 - 4*npv + upm)), tp: (2*n*npv**2*upm - 3*n*npv*upm + n*upm + 2*npv**2*p*upm + 4*npv**2*p - npv*p*upm - 4*npv*p - npv*sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2) + p*upm + sqrt(4*n**2*npv**2*upm**2 - 4*n**2*npv*upm**2 + n**2*upm**2 + 8*n*npv**2*p*upm**2 - 8*n*npv*p*upm + 2*n*p*upm**2 + 4*npv**2*p**2*upm**2 - 16*npv**2*p**2*upm + 16*npv**2*p**2 + 4*npv*p**2*upm**2 - 8*npv*p**2*upm + p**2*upm**2))/(2*(4*npv**2 - 4*npv + upm))}, {fn: n*npv - n, fp: n*(npv + 1), tn: -n*npv, tp: -n*npv + n + p}, {fn: -n*npv + n - 2*npv*p + 2*p, fp: -n*npv + n - 2*npv*p, tn: npv*(n + 2*p), tp: n*npv - n + 2*npv*p - p}]
# ppv f1_plus
# 1 [{tp: -f1_plus*p*ppv/(f1_plus - 2*ppv), tn: (f1_plus*n - f1_plus*p*ppv + f1_plus*p - 2*n*ppv)/(f1_plus - 2*ppv), fp: (f1_plus*p*ppv - f1_plus*p)/(f1_plus - 2*ppv), fn: (f1_plus*p*ppv + f1_plus*p - 2*p*ppv)/(f1_plus - 2*ppv)}]
# ppv f1_minus
# 1 [{tp: (2*f1_minus*n*ppv + f1_minus*p*ppv - 2*n*ppv)/(f1_minus + 2*ppv - 2), tn: (2*f1_minus*n*ppv - f1_minus*n + f1_minus*p*ppv - f1_minus*p)/(f1_minus + 2*ppv - 2), fp: (-2*f1_minus*n*ppv + 2*f1_minus*n - f1_minus*p*ppv + f1_minus*p + 2*n*ppv - 2*n)/(f1_minus + 2*ppv - 2), fn: (-2*f1_minus*n*ppv - f1_minus*p*ppv + f1_minus*p + 2*n*ppv + 2*p*ppv - 2*p)/(f1_minus + 2*ppv - 2)}]
# ppv fm
# 2 [{fn: p, fp: 0, tn: n, tp: 0}, {fn: (-fm**2*p + p*ppv)/ppv, fp: -fm**2*p*(ppv - 1)/ppv**2, tn: (fm**2*p*ppv - fm**2*p + n*ppv**2)/ppv**2, tp: fm**2*p/ppv}]
# ppv bm
# 1 [{tp: bm*n*p*ppv/(n*ppv + p*ppv - p), tn: (bm*n*p*ppv - bm*n*p + n**2*ppv + n*p*ppv - n*p)/(n*ppv + p*ppv - p), fp: (-bm*n*p*ppv + bm*n*p)/(n*ppv + p*ppv - p), fn: (-bm*n*p*ppv + n*p*ppv + p**2*ppv - p**2)/(n*ppv + p*ppv - p)}]
# ppv pt
# 1 [{fn: p, fp: 0, tn: n, tp: 0}]
# ppv lrp
# 1 [{tp: 0, tn: n, fp: 0, fn: p}]
# ppv lrn
# 1 [{tp: (-lrn*n*p*ppv + n*p*ppv)/(lrn*p*ppv - lrn*p + n*ppv), tn: (n**2*ppv + n*p*ppv - n*p)/(lrn*p*ppv - lrn*p + n*ppv), fp: (lrn*n*p*ppv - lrn*n*p - n*p*ppv + n*p)/(lrn*p*ppv - lrn*p + n*ppv), fn: (lrn*n*p*ppv + lrn*p**2*ppv - lrn*p**2)/(lrn*p*ppv - lrn*p + n*ppv)}]
# ppv mk
# 2 [{fn: p, fp: 0, tn: n, tp: 0}, {fn: (-mk*n*ppv - mk*p*ppv + mk*p + n*ppv**2 + p*ppv**2 - p*ppv)/mk, fp: -(ppv - 1)*(mk*n + mk*p - n*ppv - p*ppv + p)/mk, tn: (mk - ppv + 1)*(n*ppv + p*ppv - p)/mk, tp: ppv*(mk*n + mk*p - n*ppv - p*ppv + p)/mk}]
# ppv dor
# 2 [{fn: p, fp: 0, tn: n, tp: 0}, {fn: (-n*ppv - p*ppv + p)/(dor*ppv - dor - ppv + 1), fp: -(dor*p*ppv - dor*p + n*ppv)/(ppv*(dor - 1)), tn: dor*(n*ppv + p*ppv - p)/(ppv*(dor - 1)), tp: (dor*p*ppv - dor*p + n*ppv)/((dor - 1)*(ppv - 1))}]
# ppv mcc
# 2 [{fn: p, fp: 0, tn: n, tp: 0}, {fn: p*(-mcc**2*n**2*ppv - mcc**2*n*p*ppv + mcc**2*n*p + n**2*ppv**2 + 2*n*p*ppv**2 - 2*n*p*ppv + p**2*ppv**2 - 2*p**2*ppv + p**2)/(mcc**2*n*p + n**2*ppv**2 + 2*n*p*ppv**2 - 2*n*p*ppv + p**2*ppv**2 - 2*p**2*ppv + p**2), fp: mcc**2*n*p*(-n*ppv + n - p*ppv + p)/(mcc**2*n*p + n**2*ppv**2 + 2*n*p*ppv**2 - 2*n*p*ppv + p**2*ppv**2 - 2*p**2*ppv + p**2), tn: n*(mcc**2*n*p*ppv + mcc**2*p**2*ppv - mcc**2*p**2 + n**2*ppv**2 + 2*n*p*ppv**2 - 2*n*p*ppv + p**2*ppv**2 - 2*p**2*ppv + p**2)/(mcc**2*n*p + n**2*ppv**2 + 2*n*p*ppv**2 - 2*n*p*ppv + p**2*ppv**2 - 2*p**2*ppv + p**2), tp: mcc**2*n*p*ppv*(n + p)/(mcc**2*n*p + n**2*ppv**2 + 2*n*p*ppv**2 - 2*n*p*ppv + p**2*ppv**2 - 2*p**2*ppv + p**2)}]
# ppv ji
# 1 [{tp: ji*p*ppv/(ji*ppv - ji + ppv), tn: (ji*n*ppv - ji*n + ji*p*ppv - ji*p + n*ppv)/(ji*ppv - ji + ppv), fp: (-ji*p*ppv + ji*p)/(ji*ppv - ji + ppv), fn: (-ji*p + p*ppv)/(ji*ppv - ji + ppv)}]
# ppv ba
# 1 [{tp: (2.0*ba*n*p*ppv - n*p*ppv)/(n*ppv + p*ppv - p), tn: (2.0*ba*n*p*ppv - 2.0*ba*n*p + n**2*ppv)/(n*ppv + p*ppv - p), fp: (-2.0*ba*n*p*ppv + 2.0*ba*n*p + n*p*ppv - n*p)/(n*ppv + p*ppv - p), fn: (-2.0*ba*n*p*ppv + 2.0*n*p*ppv + p**2*ppv - p**2)/(n*ppv + p*ppv - p)}]
# ppv kappa
# 2 [{fn: (n*ppv + 2*p*ppv - p)/(2*ppv - 1), fp: n*(ppv - 1)/(2*ppv - 1), tn: n*ppv/(2*ppv - 1), tp: -n*ppv/(2*ppv - 1)}, {fn: (2*kappa*n**2*ppv - kappa*n*p*ppv - kappa*n*p + kappa*p**2*ppv + kappa*p**2 - 2*n**2*ppv + 2*n*p - 2*p**2*ppv)/(-kappa*n + kappa*p - 2*n*ppv + 2*n - 2*p*ppv), fp: (ppv - 1)*(2*kappa*n**2 - kappa*n*p + kappa*p**2 - 2*n**2 + 2*n*p)/(-kappa*n + kappa*p - 2*n*ppv + 2*n - 2*p*ppv), tn: -(2*kappa*n**2*ppv - kappa*n**2 - kappa*n*p*ppv + kappa*p**2*ppv - kappa*p**2 + 4*n*p*ppv - 2*n*p)/(-kappa*n + kappa*p - 2*n*ppv + 2*n - 2*p*ppv), tp: -ppv*(2*kappa*n**2 - kappa*n*p + kappa*p**2 - 2*n**2 + 2*n*p)/(-kappa*n + kappa*p - 2*n*ppv + 2*n - 2*p*ppv)}]
# ppv gm
# 2 [{fn: -sqrt(n*ppv*(4*gm**2*p*ppv - 4*gm**2*p + n*ppv))/(2*(ppv - 1)) + (n*ppv + 2*p*ppv - 2*p)/(2*(ppv - 1)), fp: (n*ppv - sqrt(n*ppv*(4*gm**2*p*ppv - 4*gm**2*p + n*ppv)))/(2*ppv), tn: (n*ppv + sqrt(n*ppv*(4*gm**2*p*ppv - 4*gm**2*p + n*ppv)))/(2*ppv), tp: (-n*ppv + sqrt(n*ppv*(4*gm**2*p*ppv - 4*gm**2*p + n*ppv)))/(2*(ppv - 1))}, {fn: sqrt(n*ppv*(4*gm**2*p*ppv - 4*gm**2*p + n*ppv))/(2*(ppv - 1)) + (n*ppv + 2*p*ppv - 2*p)/(2*(ppv - 1)), fp: (n*ppv + sqrt(n*ppv*(4*gm**2*p*ppv - 4*gm**2*p + n*ppv)))/(2*ppv), tn: (n*ppv - sqrt(n*ppv*(4*gm**2*p*ppv - 4*gm**2*p + n*ppv)))/(2*ppv), tp: (-n*ppv - sqrt(n*ppv*(4*gm**2*p*ppv - 4*gm**2*p + n*ppv)))/(2*(ppv - 1))}]
# ppv upm
# 4 [{fn: (-2*n*ppv**2*upm + 4*n*ppv**2 - n*ppv*upm - 2*p*ppv**2*upm + 8*p*ppv**2 + p*ppv*upm - 8*p*ppv + 2*p*upm - ppv*sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2))/(8*ppv**2 - 8*ppv + 2*upm), fp: (-2*n*ppv**2*upm + 4*n*ppv**2 + n*ppv*upm - 4*n*ppv + n*upm - 2*p*ppv**2*upm + 3*p*ppv*upm - p*upm - ppv*sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2) + sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2))/(2*(4*ppv**2 - 4*ppv + upm)), tn: (2*n*ppv**2*upm + 4*n*ppv**2 - n*ppv*upm - 4*n*ppv + n*upm + 2*p*ppv**2*upm - 3*p*ppv*upm + p*upm + ppv*sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2) - sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2))/(2*(4*ppv**2 - 4*ppv + upm)), tp: ppv*(2*n*ppv*upm - 4*n*ppv + n*upm + 2*p*ppv*upm - p*upm + sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2))/(2*(4*ppv**2 - 4*ppv + upm))}, {fn: (-2*n*ppv**2*upm + 4*n*ppv**2 - n*ppv*upm - 2*p*ppv**2*upm + 8*p*ppv**2 + p*ppv*upm - 8*p*ppv + 2*p*upm + ppv*sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2))/(8*ppv**2 - 8*ppv + 2*upm), fp: (-2*n*ppv**2*upm + 4*n*ppv**2 + n*ppv*upm - 4*n*ppv + n*upm - 2*p*ppv**2*upm + 3*p*ppv*upm - p*upm + ppv*sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2) - sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2))/(2*(4*ppv**2 - 4*ppv + upm)), tn: (2*n*ppv**2*upm + 4*n*ppv**2 - n*ppv*upm - 4*n*ppv + n*upm + 2*p*ppv**2*upm - 3*p*ppv*upm + p*upm - ppv*sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2) + sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2))/(2*(4*ppv**2 - 4*ppv + upm)), tp: ppv*(2*n*ppv*upm - 4*n*ppv + n*upm + 2*p*ppv*upm - p*upm - sqrt(4*n**2*ppv**2*upm**2 - 16*n**2*ppv**2*upm + 16*n**2*ppv**2 + 4*n**2*ppv*upm**2 - 8*n**2*ppv*upm + n**2*upm**2 + 8*n*p*ppv**2*upm**2 - 8*n*p*ppv*upm + 2*n*p*upm**2 + 4*p**2*ppv**2*upm**2 - 4*p**2*ppv*upm**2 + p**2*upm**2))/(2*(4*ppv**2 - 4*ppv + upm))}, {fn: p*ppv + p, fp: p*(ppv - 1), tn: n - p*ppv + p, tp: -p*ppv}, {fn: -2*n*ppv - p*ppv + p, fp: -(2*n + p)*(ppv - 1), tn: 2*n*ppv - n + p*ppv - p, tp: ppv*(2*n + p)}]
# f1_plus f1_minus
# 1 [{tp: (f1_minus*f1_plus*n + f1_minus*f1_plus*p - f1_plus*n - f1_plus*p)/(f1_minus + f1_plus - 2), tn: (f1_minus*f1_plus*n + f1_minus*f1_plus*p - f1_minus*n - f1_minus*p)/(f1_minus + f1_plus - 2), fp: (-f1_minus*f1_plus*n - f1_minus*f1_plus*p + 2*f1_minus*n + f1_minus*p + f1_plus*n - 2*n)/(f1_minus + f1_plus - 2), fn: (-f1_minus*f1_plus*n - f1_minus*f1_plus*p + f1_minus*p + f1_plus*n + 2*f1_plus*p - 2*p)/(f1_minus + f1_plus - 2)}]
# f1_plus fm
# 2 [{fn: -fm*p*sqrt(-(f1_plus - fm)*(f1_plus + fm))/f1_plus + p*(f1_plus - fm**2)/f1_plus, fp: p*(-f1_plus**2 - f1_plus*fm**2 - f1_plus*fm*sqrt(-f1_plus**2 + fm**2) + 2*fm**2 + 2*fm*sqrt(-f1_plus**2 + fm**2))/f1_plus**2, tn: n + p + fm**2*p/f1_plus + fm*p*sqrt(-f1_plus**2 + fm**2)/f1_plus - 2*fm**2*p/f1_plus**2 - 2*fm*p*sqrt(-f1_plus**2 + fm**2)/f1_plus**2, tp: fm*p*(fm + sqrt(-f1_plus**2 + fm**2))/f1_plus}, {fn: fm*p*sqrt(-(f1_plus - fm)*(f1_plus + fm))/f1_plus + p*(f1_plus - fm**2)/f1_plus, fp: p*(-f1_plus**2 - f1_plus*fm**2 + f1_plus*fm*sqrt(-f1_plus**2 + fm**2) + 2*fm**2 - 2*fm*sqrt(-f1_plus**2 + fm**2))/f1_plus**2, tn: n + p + fm**2*p/f1_plus - fm*p*sqrt(-f1_plus**2 + fm**2)/f1_plus - 2*fm**2*p/f1_plus**2 + 2*fm*p*sqrt(-f1_plus**2 + fm**2)/f1_plus**2, tp: fm*p*(fm - sqrt(-f1_plus**2 + fm**2))/f1_plus}]
# f1_plus bm
# 1 [{tp: (bm*f1_plus*n*p - f1_plus*p**2)/(f1_plus*n + f1_plus*p - 2*p), tn: (bm*f1_plus*n*p - 2*bm*n*p + f1_plus*n**2 + 2*f1_plus*n*p - 2*n*p)/(f1_plus*n + f1_plus*p - 2*p), fp: (-bm*f1_plus*n*p + 2*bm*n*p - f1_plus*n*p)/(f1_plus*n + f1_plus*p - 2*p), fn: (-bm*f1_plus*n*p + f1_plus*n*p + 2*f1_plus*p**2 - 2*p**2)/(f1_plus*n + f1_plus*p - 2*p)}]
# f1_plus pt
# 2 [{fn: p*(f1_plus*n + 2*f1_plus*p - 2*p)/(f1_plus*n + f1_plus*p - 2*p), fp: -f1_plus*n*p/(f1_plus*n + f1_plus*p - 2*p), tn: n*(f1_plus*n + 2*f1_plus*p - 2*p)/(f1_plus*n + f1_plus*p - 2*p), tp: -f1_plus*p**2/(f1_plus*n + f1_plus*p - 2*p)}, {fn: p*(f1_plus*n*pt**2 + 2*f1_plus*p*pt**2 - 4*f1_plus*p*pt + 2*f1_plus*p - 2*p*pt**2 + 4*p*pt - 2*p)/(f1_plus*n*pt**2 + f1_plus*p*pt**2 - 2*f1_plus*p*pt + f1_plus*p - 2*p*pt**2 + 4*p*pt - 2*p), fp: -f1_plus*n*p*pt**2/(f1_plus*n*pt**2 + f1_plus*p*pt**2 - 2*f1_plus*p*pt + f1_plus*p - 2*p*pt**2 + 4*p*pt - 2*p), tn: n*(f1_plus*n*pt**2 + 2*f1_plus*p*pt**2 - 2*f1_plus*p*pt + f1_plus*p - 2*p*pt**2 + 4*p*pt - 2*p)/(f1_plus*n*pt**2 + f1_plus*p*pt**2 - 2*f1_plus*p*pt + f1_plus*p - 2*p*pt**2 + 4*p*pt - 2*p), tp: f1_plus*p**2*(-pt**2 + 2*pt - 1)/(f1_plus*n*pt**2 + f1_plus*p*pt**2 - 2*f1_plus*p*pt + f1_plus*p - 2*p*pt**2 + 4*p*pt - 2*p)}]
# f1_plus lrp
# 1 [{tp: -f1_plus*lrp*p**2/(f1_plus*lrp*p + f1_plus*n - 2*lrp*p), tn: (f1_plus*lrp*n*p + f1_plus*n**2 + f1_plus*n*p - 2*lrp*n*p)/(f1_plus*lrp*p + f1_plus*n - 2*lrp*p), fp: -f1_plus*n*p/(f1_plus*lrp*p + f1_plus*n - 2*lrp*p), fn: (2*f1_plus*lrp*p**2 + f1_plus*n*p - 2*lrp*p**2)/(f1_plus*lrp*p + f1_plus*n - 2*lrp*p)}]
# f1_plus lrn
# 1 [{tp: (-f1_plus*lrn*n*p - f1_plus*lrn*p**2 + f1_plus*n*p)/(f1_plus*lrn*p + f1_plus*n - 2*lrn*p), tn: (f1_plus*n**2 + 2*f1_plus*n*p - 2*n*p)/(f1_plus*lrn*p + f1_plus*n - 2*lrn*p), fp: (f1_plus*lrn*n*p - 2*f1_plus*n*p - 2*lrn*n*p + 2*n*p)/(f1_plus*lrn*p + f1_plus*n - 2*lrn*p), fn: (f1_plus*lrn*n*p + 2*f1_plus*lrn*p**2 - 2*lrn*p**2)/(f1_plus*lrn*p + f1_plus*n - 2*lrn*p)}]
# f1_plus mk
# ...
# mcc ba
# 2 [{fn: 0.5*(-4.0*ba*n**2*p + 3.0*n**2*p + n*p**2 - sqrt(n**2*p**2*(mcc**2*(n**2 + 2.0*n*p + p**2) - 16.0*n*p*(ba - 0.5)**2)/mcc**2))/(n*(n + p)), fp: 0.5*(4.0*ba*n**2*p - 3.0*n**2*p - n*p**2 + 4.0*n*p*(1.0 - ba)*(n + p) + sqrt(n**2*p**2*(mcc**2*(n**2 + 2.0*n*p + p**2) - 16.0*n*p*(ba - 0.5)**2)/mcc**2))/(p*(n + p)), tn: 0.5*(-4.0*ba*n**2*p + 3.0*n**2*p + n*p**2 + 2.0*n*p*(2.0*ba - 1.0)*(n + p) - sqrt(n**2*p**2*(mcc**2*(n**2 + 2.0*n*p + p**2) - 16.0*n*p*(ba - 0.5)**2)/mcc**2))/(p*(n + p)), tp: 0.5*(4.0*ba*n**2*p - 3.0*n**2*p - n*p**2 + 2.0*n*p*(n + p) + sqrt(n**2*p**2*(mcc**2*(n**2 + 2.0*n*p + p**2) - 16.0*n*p*(ba - 0.5)**2)/mcc**2))/(n*(n + p))}, {fn: 0.5*(-4.0*ba*n**2*p + 3.0*n**2*p + n*p**2 + sqrt(n**2*p**2*(mcc**2*(n**2 + 2.0*n*p + p**2) - 16.0*n*p*(ba - 0.5)**2)/mcc**2))/(n*(n + p)), fp: 0.5*(4.0*ba*n**2*p - 3.0*n**2*p - n*p**2 + 4.0*n*p*(1.0 - ba)*(n + p) - sqrt(n**2*p**2*(mcc**2*(n**2 + 2.0*n*p + p**2) - 16.0*n*p*(ba - 0.5)**2)/mcc**2))/(p*(n + p)), tn: 0.5*(-4.0*ba*n**2*p + 3.0*n**2*p + n*p**2 + 2.0*n*p*(2.0*ba - 1.0)*(n + p) + sqrt(n**2*p**2*(mcc**2*(n**2 + 2.0*n*p + p**2) - 16.0*n*p*(ba - 0.5)**2)/mcc**2))/(p*(n + p)), tp: 0.5*(4.0*ba*n**2*p - 3.0*n**2*p - n*p**2 + 2.0*n*p*(n + p) - sqrt(n**2*p**2*(mcc**2*(n**2 + 2.0*n*p + p**2) - 16.0*n*p*(ba - 0.5)**2)/mcc**2))/(n*(n + p))}]
# mcc kappa
# 4 [{fn: (-kappa**2*n**3*p + 2*kappa**2*n**2*p**2 - 3*kappa**2*n*p**3 + 2*kappa**2*p**4 - 3*kappa*mcc**2*n**3*p + 2*kappa*mcc**2*n**2*p**2 - 3*kappa*mcc**2*n*p**3 - kappa*mcc*n*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) + kappa*mcc*p*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) + 2*kappa*n**3*p - 6*kappa*n**2*p**2 + 10*kappa*n*p**3 - 6*kappa*p**4 + 2*mcc**2*n**3*p - 2*mcc**2*n**2*p**2 + 4*mcc**2*n*p**3 + 2*mcc*n*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) + 4*n**2*p**2 - 8*n*p**3 + 4*p**4)/(kappa**2*n**3 - kappa**2*n**2*p - kappa**2*n*p**2 + kappa**2*p**3 - 4*kappa*n**3 + 4*kappa*n**2*p + 4*kappa*n*p**2 - 4*kappa*p**3 + 4*mcc**2*n**2*p + 4*mcc**2*n*p**2 + 4*n**3 - 4*n**2*p - 4*n*p**2 + 4*p**3), fp: (2*kappa**2*n**4 - 3*kappa**2*n**3*p + 2*kappa**2*n**2*p**2 - kappa**2*n*p**3 - 3*kappa*mcc**2*n**3*p + 2*kappa*mcc**2*n**2*p**2 - 3*kappa*mcc**2*n*p**3 - kappa*mcc*n*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) + kappa*mcc*p*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) - 6*kappa*n**4 + 10*kappa*n**3*p - 6*kappa*n**2*p**2 + 2*kappa*n*p**3 + 4*mcc**2*n**3*p - 2*mcc**2*n**2*p**2 + 2*mcc**2*n*p**3 - 2*mcc*p*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) + 4*n**4 - 8*n**3*p + 4*n**2*p**2)/(kappa**2*n**3 - kappa**2*n**2*p - kappa**2*n*p**2 + kappa**2*p**3 - 4*kappa*n**3 + 4*kappa*n**2*p + 4*kappa*n*p**2 - 4*kappa*p**3 + 4*mcc**2*n**2*p + 4*mcc**2*n*p**2 + 4*n**3 - 4*n**2*p - 4*n*p**2 + 4*p**3), tn: (-kappa**2*n**4 + 2*kappa**2*n**3*p - 3*kappa**2*n**2*p**2 + 2*kappa**2*n*p**3 + 3*kappa*mcc**2*n**3*p - 2*kappa*mcc**2*n**2*p**2 + 3*kappa*mcc**2*n*p**3 + kappa*mcc*n*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) - kappa*mcc*p*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) + 2*kappa*n**4 - 6*kappa*n**3*p + 10*kappa*n**2*p**2 - 6*kappa*n*p**3 + 6*mcc**2*n**2*p**2 - 2*mcc**2*n*p**3 + 2*mcc*p*sqrt(n*p*(-2*kappa**2*n**4 + 3*kappa**2*n**3*p - 6*kappa**2*n**2*p**2 + 3*kappa**2*n*p**3 - 2*kappa**2*p**4 + 2*kappa*n**4 - 8*kappa*n**3*p + 12*kappa*n**2*p**2 - 8*kappa*n*p**3 + 2*kappa*p**4 + mcc**2*n**3*p + 2*mcc**2*n**2*p**2 + mcc**2*n*p**3 + 4*n**3*p - 8*n**2*p**2 + 4*n*p**3)) +  ...
# ji ba
# 1 [{tp: (-2.0*ba*ji*n*p + ji*n*p + ji*p**2)/(-ji*n + p), tn: (2.0*ba*n*p - ji*n**2 - ji*n*p)/(-ji*n + p), fp: (-2.0*ba*n*p + ji*n*p + n*p)/(-ji*n + p), fn: (2.0*ba*ji*n*p - 2.0*ji*n*p - ji*p**2 + p**2)/(-ji*n + p)}]
# ji kappa
# 2 [{fn: (ji*n + 2*ji*p - p)/(ji - 1), fp: -(ji*p + n)/(ji - 1), tn: ji*(n + p)/(ji - 1), tp: -ji*(n + p)/(ji - 1)}, {fn: (2*ji*kappa*n**2 - ji*kappa*n*p + ji*kappa*p**2 - 2*ji*n**2 - 2*ji*p**2 - kappa*n*p + kappa*p**2 + 2*n*p)/(-ji*kappa*n + ji*kappa*p - 2*ji*p - kappa*n + kappa*p + 2*n), fp: -(-ji*kappa*n*p + ji*kappa*p**2 - 2*ji*p**2 + 2*kappa*n**2 - kappa*n*p + kappa*p**2 - 2*n**2 + 2*n*p)/(-ji*kappa*n + ji*kappa*p - 2*ji*p - kappa*n + kappa*p + 2*n), tn: (-ji*kappa*n**2 + ji*kappa*p**2 - 2*ji*n*p - 2*ji*p**2 + kappa*n**2 + kappa*p**2 + 2*n*p)/(-ji*kappa*n + ji*kappa*p - 2*ji*p - kappa*n + kappa*p + 2*n), tp: -2*ji*n**2*(kappa - 1)/(-ji*kappa*n + ji*kappa*p - 2*ji*p - kappa*n + kappa*p + 2*n)}]
# ji gm
# 2 [{fn: -ji*n/2 - ji*p/2 + p - sqrt(ji*(-4*gm**2*n*p + ji*n**2 + 2*ji*n*p + ji*p**2))/2, fp: (ji*n - ji*p + sqrt(ji*(-4*gm**2*n*p + ji*n**2 + 2*ji*n*p + ji*p**2)))/(2*ji), tn: (ji*n + ji*p - sqrt(ji*(-4*gm**2*n*p + ji*n**2 + 2*ji*n*p + ji*p**2)))/(2*ji), tp: ji*n/2 + ji*p/2 + sqrt(ji*(-4*gm**2*n*p + ji*n**2 + 2*ji*n*p + ji*p**2))/2}, {fn: -ji*n/2 - ji*p/2 + p + sqrt(ji*(-4*gm**2*n*p + ji*n**2 + 2*ji*n*p + ji*p**2))/2, fp: (ji*n - ji*p - sqrt(ji*(-4*gm**2*n*p + ji*n**2 + 2*ji*n*p + ji*p**2)))/(2*ji), tn: (ji*n + ji*p + sqrt(ji*(-4*gm**2*n*p + ji*n**2 + 2*ji*n*p + ji*p**2)))/(2*ji), tp: ji*n/2 + ji*p/2 - sqrt(ji*(-4*gm**2*n*p + ji*n**2 + 2*ji*n*p + ji*p**2))/2}]
# ji upm
# 3 [{fn: p, fp: -p, tn: n + p, tp: 0}, {fn: (-2*ji*n - ji*p + p)/(ji + 1), fp: -(ji*p - 2*n - p)/(ji + 1), tn: (ji - 1)*(n + p)/(ji + 1), tp: 2*ji*(n + p)/(ji + 1)}, {fn: (-3*ji**2*n*upm + 4*ji**2*n - 2*ji**2*p*upm + 4*ji**2*p - ji*n*upm + ji*p*upm - 4*ji*p + p*upm)/(ji**2*upm + 2*ji*upm - 4*ji + upm), fp: -(ji**2*p*upm - 3*ji*n*upm + 4*ji*n - ji*p*upm - n*upm)/(ji**2*upm + 2*ji*upm - 4*ji + upm), tn: ji*upm*(ji - 1)*(n + p)/(ji**2*upm + 2*ji*upm - 4*ji + upm), tp: ji*(n + p)*(3*ji*upm - 4*ji + upm)/(ji**2*upm + 2*ji*upm - 4*ji + upm)}]
# ba kappa
# 2 [{fn: (2.0*ba*n*p - n*p + p**2)/(-n + p), fp: -n*(2.0*ba*p + n - p)/(-n + p), tn: 2.0*ba*n*p/(-n + p), tp: -2.0*ba*n*p/(-n + p)}, {fn: (2.0*ba*kappa*n**2*p - 2.0*ba*kappa*n*p**2 - 4.0*ba*n**2*p + 2.0*kappa*p**3 + 2.0*n**2*p + 2.0*n*p**2 - 2.0*p**3)/(-kappa*n**2 + kappa*p**2 + 2.0*n**2 - 2.0*p**2), fp: -2.0*n*(-ba*kappa*n*p + ba*kappa*p**2 - 2.0*ba*p**2 + kappa*n**2 - n**2 + n*p + p**2)/((kappa - 2.0)*(-n + p)*(n + p)), tn: n*(-2.0*ba*kappa*n*p + 2.0*ba*kappa*p**2 - 4.0*ba*p**2 + kappa*n**2 + kappa*p**2 + 2.0*n*p)/((kappa - 2.0)*(-n + p)*(n + p)), tp: -p*(2.0*ba*kappa*n**2 - 2.0*ba*kappa*n*p - 4.0*ba*n**2 + kappa*n**2 + kappa*p**2 + 2.0*n*p)/((kappa - 2.0)*(-n + p)*(n + p))}]
# ba gm
# 2 [{fn: -p*sqrt((ba - gm)*(ba + gm)) - p*(ba - 1.0), fp: n*(-ba + sqrt(ba**2 - gm**2) + 1.0), tn: n*(ba - sqrt(ba**2 - gm**2)), tp: p*(ba + sqrt(ba**2 - gm**2))}, {fn: p*sqrt((ba - gm)*(ba + gm)) - p*(ba - 1.0), fp: n*(-ba - sqrt(ba**2 - gm**2) + 1.0), tn: n*(ba + sqrt(ba**2 - gm**2)), tp: p*(ba - sqrt(ba**2 - gm**2))}]
# ba upm
# 4 [{fn: (-2.0*ba*n*p + 2.0*n*p + 2.0*p**2)/(n + p), fp: -2.0*ba*n*p/(n + p), tn: n*(2.0*ba*p + n + p)/(n + p), tp: -p*(-2.0*ba*n + n + p)/(n + p)}, {fn: (-4.0*ba*n**2*p*upm - 4.0*ba*n*p**2*upm + 8.0*ba*n*p**2 + 3.0*n**2*p*upm + 4.0*n*p**2*upm - 8.0*n*p**2 + p**3*upm - 8.0*p*sqrt(-ba**2*n**2*p**2*upm + ba**2*n**2*p**2 + 0.25*ba*n**3*p*upm**2 - 0.25*ba*n**3*p*upm + 0.5*ba*n**2*p**2*upm**2 - 0.5*ba*n**2*p**2*upm + 0.25*ba*n*p**3*upm**2 - 0.25*ba*n*p**3*upm + 0.015625*n**4*upm**2 - 0.03125*n**2*p**2*upm**2 + 0.015625*p**4*upm**2))/(2.0*n**2*upm + 4.0*n*p*upm - 8.0*n*p + 2.0*p**2*upm), fp: 0.5*n*(-4.0*ba*n*p*upm + 8.0*ba*n*p - 4.0*ba*p**2*upm + n**2*upm + 4.0*n*p*upm - 8.0*n*p + 3.0*p**2*upm + 8.0*sqrt(-ba**2*n**2*p**2*upm + ba**2*n**2*p**2 + 0.25*ba*n**3*p*upm**2 - 0.25*ba*n**3*p*upm + 0.5*ba*n**2*p**2*upm**2 - 0.5*ba*n**2*p**2*upm + 0.25*ba*n*p**3*upm**2 - 0.25*ba*n*p**3*upm + 0.015625*n**4*upm**2 - 0.03125*n**2*p**2*upm**2 + 0.015625*p**4*upm**2))/(n**2*upm + 2.0*n*p*upm - 4.0*n*p + p**2*upm), tn: 0.5*n*(4.0*ba*n*p*upm - 8.0*ba*n*p + 4.0*ba*p**2*upm + n**2*upm - p**2*upm - 8.0*sqrt(-ba**2*n**2*p**2*upm + ba**2*n**2*p**2 + 0.25*ba*n**3*p*upm**2 - 0.25*ba*n**3*p*upm + 0.5*ba*n**2*p**2*upm**2 - 0.5*ba*n**2*p**2*upm + 0.25*ba*n*p**3*upm**2 - 0.25*ba*n*p**3*upm + 0.015625*n**4*upm**2 - 0.03125*n**2*p**2*upm**2 + 0.015625*p**4*upm**2))/(n**2*upm + 2.0*n*p*upm - 4.0*n*p + p**2*upm), tp: 0.5*p*(4.0*ba*n**2*upm + 4.0*ba*n*p*upm - 8.0*ba*n*p - n**2*upm + p**2*upm + 8.0*sqrt(-ba**2*n**2*p**2*upm + ba**2*n**2*p**2 + 0.25*ba*n**3*p*upm**2 - 0.25*ba*n**3*p*upm + 0.5*ba*n**2*p**2*upm**2 - 0.5*ba*n**2*p**2*upm + 0.25*ba*n*p**3*upm**2 - 0.25*ba*n*p**3*upm + 0.015625*n**4*upm**2 - 0.03125*n**2*p**2*upm**2 + 0.015625*p**4*upm**2))/(n**2*upm + 2.0*n*p*upm - 4.0*n*p + p**2*upm)}, {fn: (-4.0*ba*n**2*p*upm - 4.0*ba*n*p**2*upm + 8.0*ba*n*p**2 + 3.0*n**2*p*upm + 4.0*n*p**2*upm - 8.0*n*p**2 + p**3*upm + 8.0*p*sqrt(-ba**2*n**2*p**2*upm + ba**2*n**2*p**2 + 0.25*ba*n**3*p*upm**2 - 0.25*ba*n**3*p*upm + 0.5*ba*n**2*p**2*upm**2 - 0.5*ba*n**2*p**2*upm + 0.25*ba*n*p**3*upm**2 - 0.25*ba*n*p**3*upm + 0.015625*n**4*upm**2 - 0.03125*n**2*p**2*upm**2 + 0.015625*p**4*upm**2))/(2.0*n**2*upm + 4.0*n*p*upm - 8.0*n*p + 2.0*p**2*upm), fp: 0.5*n*(-4.0*ba*n*p*upm + 8.0*ba*n*p - 4.0*ba*p**2*upm + n**2*upm + 4.0*n*p*upm - 8.0*n*p + 3.0*p**2*upm - 8.0*sqrt(-ba**2*n**2*p**2*upm + ba**2*n**2*p**2 + 0.25*ba*n**3*p*upm**2 - 0.25*ba*n**3*p*upm + 0.5*ba*n**2*p**2*upm**2 - 0.5*ba*n**2*p**2*upm + 0.25*ba*n*p**3*upm**2 - 0.25*ba*n*p**3*upm + 0.015625*n**4*upm**2 - 0.03125*n**2*p**2*upm**2 + 0.015625*p**4*upm**2))/(n**2*upm + 2.0*n*p*upm - 4.0*n*p + p**2*upm), tn: 0.5*n*(4.0*ba*n*p*upm - 8.0*ba*n*p + 4.0*ba*p**2*upm + n**2*upm - p**2*upm + 8.0*sqrt(-ba**2*n**2*p**2*upm + ba**2*n**2*p**2 + 0.25*ba*n**3*p*upm**2 - 0.25*ba*n**3*p*upm + 0.5*ba*n**2*p**2*upm**2 - 0.5*ba*n**2*p**2*upm + 0.25*ba*n*p**3*upm**2 - 0.25*ba*n*p**3*upm + 0.015625*n**4*upm**2 - 0.03125*n**2*p**2*upm**2 + 0.015625*p**4*upm**2))/(n**2*upm + 2.0*n*p*upm - 4.0*n*p + p**2*upm), tp: 0.5*p*(4.0*ba*n**2*upm + 4.0*ba*n*p*upm - 8.0*ba*n*p - n**2*upm + p**2*upm - 8.0*sqrt(-ba**2*n**2*p**2*upm + ba**2*n**2*p**2 + 0.25*ba*n**3*p*upm**2 - 0.25*ba*n**3*p*upm + 0.5*ba*n**2*p**2*upm**2 - 0.5*ba*n**2*p**2*upm + 0.25*ba*n*p**3*upm**2 - 0.25*ba*n*p**3*upm + 0.015625*n**4*upm**2 - 0.03125*n**2*p**2*upm**2 + 0.015625*p**4*upm**2))/(n**2*upm + 2.0*n*p*upm - 4.0*n*p + p**2*upm)}, {fn: -2.0*ba*n*p/(n + p), fp: -2.0*n*(ba*p - n - p)/(n + p), tn: n*(2.0*ba*p - n - p)/(n + p), tp: p*(2.0*ba*n + n + p)/(n + p)}]
# kappa gm
# 4 [{fn: (kappa*n**2 - 2*kappa*n*p + 3*kappa*p**2 + 2*n*p - 4*p**2 - sqrt(4*gm**2*kappa**2*n**3*p - 8*gm**2*kappa**2*n**2*p**2 + 4*gm**2*kappa**2*n*p**3 - 8*gm**2*kappa*n**3*p + 16*gm**2*kappa*n**2*p**2 - 8*gm**2*kappa*n*p**3 - 16*gm**2*n**2*p**2 + kappa**2*n**4 + 2*kappa**2*n**2*p**2 + kappa**2*p**4 + 4*kappa*n**3*p + 4*kappa*n*p**3 + 4*n**2*p**2))/(-2*kappa*n + 2*kappa*p - 4*p), fp: (-3*kappa*n**2/2 + kappa*n*p - kappa*p**2/2 + 2*n**2 - n*p - sqrt(4*gm**2*kappa**2*n**3*p - 8*gm**2*kappa**2*n**2*p**2 + 4*gm**2*kappa**2*n*p**3 - 8*gm**2*kappa*n**3*p + 16*gm**2*kappa*n**2*p**2 - 8*gm**2*kappa*n*p**3 - 16*gm**2*n**2*p**2 + kappa**2*n**4 + 2*kappa**2*n**2*p**2 + kappa**2*p**4 + 4*kappa*n**3*p + 4*kappa*n*p**3 + 4*n**2*p**2)/2)/(-kappa*n + kappa*p + 2*n), tn: (kappa*n**2 + kappa*p**2 + 2*n*p + sqrt(4*gm**2*kappa**2*n**3*p - 8*gm**2*kappa**2*n**2*p**2 + 4*gm**2*kappa**2*n*p**3 - 8*gm**2*kappa*n**3*p + 16*gm**2*kappa*n**2*p**2 - 8*gm**2*kappa*n*p**3 - 16*gm**2*n**2*p**2 + kappa**2*n**4 + 2*kappa**2*n**2*p**2 + kappa**2*p**4 + 4*kappa*n**3*p + 4*kappa*n*p**3 + 4*n**2*p**2))/(2*(-kappa*n + kappa*p + 2*n)), tp: (kappa*n**2 + kappa*p**2 + 2*n*p - sqrt(4*gm**2*kappa**2*n**3*p - 8*gm**2*kappa**2*n**2*p**2 + 4*gm**2*kappa**2*n*p**3 - 8*gm**2*kappa*n**3*p + 16*gm**2*kappa*n**2*p**2 - 8*gm**2*kappa*n*p**3 - 16*gm**2*n**2*p**2 + kappa**2*n**4 + 2*kappa**2*n**2*p**2 + kappa**2*p**4 + 4*kappa*n**3*p + 4*kappa*n*p**3 + 4*n**2*p**2))/(2*(kappa*n - kappa*p + 2*p))}, {fn: (kappa*n**2 - 2*kappa*n*p + 3*kappa*p**2 + 2*n*p - 4*p**2 + sqrt(4*gm**2*kappa**2*n**3*p - 8*gm**2*kappa**2*n**2*p**2 + 4*gm**2*kappa**2*n*p**3 - 8*gm**2*kappa*n**3*p + 16*gm**2*kappa*n**2*p**2 - 8*gm**2*kappa*n*p**3 - 16*gm**2*n**2*p**2 + kappa**2*n**4 + 2*kappa**2*n**2*p**2 + kappa**2*p**4 + 4*kappa*n**3*p + 4*kappa*n*p**3 + 4*n**2*p**2))/(-2*kappa*n + 2*kappa*p - 4*p), fp: (-3*kappa*n**2/2 + kappa*n*p - kappa*p**2/2 + 2*n**2 - n*p + sqrt(4*gm**2*kappa**2*n**3*p - 8*gm**2*kappa**2*n**2*p**2 + 4*gm**2*kappa**2*n*p**3 - 8*gm**2*kappa*n**3*p + 16*gm**2*kappa*n**2*p**2 - 8*gm**2*kappa*n*p**3 - 16*gm**2*n**2*p**2 + kappa**2*n**4 + 2*kappa**2*n**2*p**2 + kappa**2*p**4 + 4*kappa*n**3*p + 4*kappa*n*p**3 + 4*n**2*p**2)/2)/(-kappa*n + kappa*p + 2*n), tn: (kappa*n**2 + kappa*p**2 + 2*n*p - sqrt(4*gm**2*kappa**2*n**3*p - 8*gm**2*kappa**2*n**2*p**2 + 4*gm**2*kappa**2*n*p**3 - 8*gm**2*kappa*n**3*p + 16*gm**2*kappa*n**2*p**2 - 8*gm**2*kappa*n*p**3 - 16*gm**2*n**2*p**2 + kappa**2*n**4 + 2*kappa**2*n**2*p**2 + kappa**2*p**4 + 4*kappa*n**3*p + 4*kappa*n*p**3 + 4*n**2*p**2))/(2*(-kappa*n + kappa*p + 2*n)), tp: (kappa*n**2 + kappa*p**2 + 2*n*p + sqrt(4*gm**2*kappa**2*n**3*p - 8*gm**2*kappa**2*n**2*p**2 + 4*gm**2*kappa**2*n*p**3 - 8*gm**2*kappa*n**3*p + 16*gm**2*kappa*n**2*p**2 - 8*gm**2*kappa*n*p**3 - 16*gm**2*n**2*p**2 + kappa**2*n**4 + 2*kappa**2*n**2*p**2 + kappa**2*p**4 + 4*kappa*n**3*p + 4*kappa*n*p**3 + 4*n**2*p**2))/(2*(kappa*n - kappa*p + 2*p))}, {fn: -gm*sqrt(-n*p) + p, fp: (gm*kappa*n*(-n*p)**(3/2) - gm*kappa*p*(-n*p)**(3/2) + 2*gm*n**2*p*sqrt(-n*p) + 2*gm*n*p**2*sqrt(-n*p) + 2*gm*p*(-n*p)**(3/2) - kappa*n**3*p + kappa*n**2*p**2 + 2*n**3*p)/(n*p*(-kappa*n + kappa*p + 2*n)), tn: -gm*sqrt(-n*p), tp: gm*sqrt(-n*p)}, {fn: gm*sqrt(-n*p) + p, fp: (-gm*kappa*n*(-n*p)**(3/2) + gm*kappa*p*(-n*p)**(3/2) - 2*gm*n**2*p*sqrt(-n*p) - 2*gm*n*p**2*sqrt(-n*p) - 2*gm*p*(-n*p)**(3/2) - kappa*n**3*p + kappa*n**2*p**2 + 2*n**3*p)/(n*p*(-kappa*n + kappa*p + 2*n)), tn: gm*sqrt(-n*p), tp: -gm*sqrt(-n*p)}]
# kappa upm
