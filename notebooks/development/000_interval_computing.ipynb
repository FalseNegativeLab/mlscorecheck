# %%
import numpy as np
import sympy
from sympy import Symbol

# %%
class Interval:
    def __init__(self, lower_bound, upper_bound):
        self.lower_bound = lower_bound
        self.upper_bound = upper_bound

    def __add__(self, other):
        if not isinstance(other, Interval):
            return Interval(lower_bound=self.lower_bound + other,
                            upper_bound=self.upper_bound + other)

        return Interval(lower_bound=self.lower_bound + other.lower_bound,
                        upper_bound=self.upper_bound + other.upper_bound)

    def __radd__(self, other):
        return self + other

    def __sub__(self, other):
        if not isinstance(other, Interval):
            return Interval(lower_bound=self.lower_bound - other,
                            upper_bound=self.upper_bound - other)
        return Interval(lower_bound=self.lower_bound - other.upper_bound,
                        upper_bound=self.upper_bound - other.lower_bound)

    def __rsub__(self, other):
        return -1 * self + other

    def __mul__(self, other):
        if not isinstance(other, Interval):
            return Interval(lower_bound=self.lower_bound * other,
                            upper_bound=self.upper_bound * other)

        term0 = self.lower_bound * other.lower_bound
        term1 = self.lower_bound * other.upper_bound
        term2 = self.upper_bound * other.lower_bound
        term3 = self.upper_bound * other.upper_bound

        terms = [term0, term1, term2, term3]

        constraints = []
        intervals = []

        for lower_idx, lower in enumerate(terms):
            for upper_idx, upper in enumerate(terms):
                print(lower_idx, upper_idx)
                if lower_idx != upper_idx:
                    lower_constraint = lower <= lower
                    upper_constraint = upper >= upper
                    for lower_tmp_idx, lower_tmp in enumerate(terms):
                        if lower_tmp_idx != lower_idx:
                            lower_constraint = lower_constraint & (lower <= lower_tmp)
                    for upper_tmp_idx, upper_tmp in enumerate(terms):
                        if upper_tmp_idx != upper_idx:
                            upper_constraint = upper_constraint & (upper >= upper_tmp)
                    print(lower_constraint, upper_constraint)
                    constraints.append(lower_constraint & upper_constraint)
                    intervals.append(Interval(lower, upper))

        return ConstrainedIntervals(constraints, intervals)

    def __rmul__(self, other):
        return self.__mul__(other)

    def __truediv__(self, other):
        if not isinstance(other, Interval):
            return Interval(lower_bound=self.lower_bound / other,
                            upper_bound=self.upper_bound / other)

        constraints = []
        intervals = []

        constraints.append(((other.lower_bound > 0) & (other.upper_bound > 0)) | ((other.lower_bound < 0) & (other.upper_bound < 0)))
        intervals.append(Interval(1.0/other.upper_bound, 1.0/other.lower_bound))
        constraints.append((other.upper_bound == 0) & (other.lower_bound != 0))
        intervals.append(Interval(-np.inf, 1.0/other.lower_bound))
        constraints.append((other.lower_bound == 0) & (other.upper_bound != 0))
        intervals.append(Interval(1.0/other.upper_bound, np.inf))
        constraints.append((other.lower_bound < 0) & (other.upper_bound > 0))
        intervals.append(Interval(-np.inf, 1.0/other.lower_bound))
        constraints.append((other.lower_bound < 0) & (other.upper_bound > 0))
        intervals.append(Interval(1.0/other.upper_bound, np.inf))

        inverse = ConstrainedIntervals(constraints, intervals)

        return inverse * self

    def __rtruediv__(self, other):
        if not isinstance(other, (Interval,)):
            other = Interval(other, other)
        return other.__truediv__(self)

    def __repr__(self):
        return str(f"[{str(self.lower_bound)},\n{str(self.upper_bound)}]")

class ConstrainedIntervals:
    def __init__(self, constraints=None, intervals=None):
        if constraints is None:
            constraints = []
        elif not isinstance(constraints, list):
            constraints = [constraints]

        self.constraints = constraints

        if intervals is None:
            intervals = []
        elif not isinstance(intervals, list):
            intervals = [intervals]

        self.intervals = intervals

    def __add__(self, other):
        if not isinstance(other, (Interval, ConstrainedIntervals)):
            other = Interval(other, other)
        if isinstance(other, Interval):
            other = ConstrainedIntervals([True], [other])

        final_constraints = []
        final_intervals = []

        for const_0, int_0 in zip(self.constraints, self.intervals, strict=False):
            for const_1, int_1 in zip(other.constraints, other.intervals, strict=False):
                final_constraints.append(const_0 & const_1)
                final_intervals.append(int_0 + int_1)

        return ConstrainedIntervals(final_constraints, final_intervals)

    def __radd__(self, other):
        return self + other

    def __sub__(self, other):
        if not isinstance(other, (Interval, ConstrainedIntervals)):
            other = Interval(other, other)
        if isinstance(other, Interval):
            other = ConstrainedIntervals([True], [other])

        final_constraints = []
        final_intervals = []

        for const_0, int_0 in zip(self.constraints, self.intervals, strict=False):
            for const_1, int_1 in zip(other.constraints, other.intervals, strict=False):
                final_constraints.append(const_0 & const_1)
                final_intervals.append(int_0 - int_1)

        return ConstrainedIntervals(final_constraints, final_intervals)

    def __rsub__(self, other):
        return -1 * self + other

    def __mul__(self, other):
        if not isinstance(other, (Interval, ConstrainedIntervals)):
            other = Interval(other, other)
        if isinstance(other, Interval):
            other = ConstrainedIntervals([True], [other])

        final_constraints = []
        final_intervals = []

        for const_0, int_0 in zip(self.constraints, self.intervals, strict=False):
            for const_1, int_1 in zip(other.constraints, other.intervals, strict=False):
                res = int_0 * int_1
                for constraint, interval in zip(res.constraints, res.intervals, strict=False):
                    final_constraints.append(const_0 & const_1 & constraint)
                    final_intervals.append(interval)

        return ConstrainedIntervals(final_constraints, final_intervals)

    def __rmul__(self, other):
        print('rmul ci')
        return other.__mul__(self)

    def __truediv__(self, other):
        if not isinstance(other, (Interval, ConstrainedIntervals)):
            other = Interval(other, other)
        if isinstance(other, Interval):
            other = ConstrainedIntervals([True], [other])

        final_constraints = []
        final_intervals = []

        for const_0, int_0 in zip(self.constraints, self.intervals, strict=False):
            for const_1, int_1 in zip(other.constraints, other.intervals, strict=False):
                res = int_0 / int_1

                for constraint, interval in zip(res.constraints, res.intervals, strict=False):
                    final_constraints.append(const_0 & const_1 & constraint)
                    final_intervals.append(interval)

        return ConstrainedIntervals(final_constraints, final_intervals)

    def __rtruediv__(self, other):
        if not isinstance(other, (Interval, ConstrainedIntervals)):
            other = Interval(other, other)
        if isinstance(other, Interval):
            other = ConstrainedIntervals([True], [other])
        return other / self

    def __repr__(self):
        return str(f"[{str(self.constraints)},\n{str(self.intervals)}]")

# %%
tp = Symbol('tp')
tn = Symbol('tn')
fp = Symbol('fp')
fn = Symbol('fn')
eps = Symbol('eps')
p = Symbol('p')
n = Symbol('n')
sens = Symbol('sens')
spec = Symbol('spec')
acc = Symbol('acc')
ppv = Symbol('ppv')
npv = Symbol('npv')

# %%
sens_e = tp/p
spec_e = tn/n
acc_e = (tp + tn)/(p + n)
ppv_e = tp/(tp + fp)
npv_e = tn/(tn + fn)

# %%
solutions = sympy.solve([ppv_e - ppv, npv_e - npv, p-tp-fn, n-tn-fp], [tp, tn, fp, fn])

# %%
solutions
# Out:
# {tp: ppv*(n*npv - n + npv*p)/(npv + ppv - 1),
#  tn: npv*(n*ppv + p*ppv - p)/(npv + ppv - 1),
#  fp: (-n*npv*ppv + n*npv + n*ppv - n - npv*p*ppv + npv*p)/(npv + ppv - 1),
#  fn: (-n*npv*ppv + n*ppv - npv*p*ppv + npv*p + p*ppv - p)/(npv + ppv - 1)}

# %%
str(solutions[tp])
# Out:
# 'ppv*(n*npv - n + npv*p)/(npv + ppv - 1)'

# %%
solutions[tp]
# Out:
# ppv*(n*npv - n + npv*p)/(npv + ppv - 1)

# %%
isens = Interval(sens-eps, sens+eps)
ispec = Interval(spec-eps, spec+eps)
ippv = Interval(ppv-eps, ppv+eps)
inpv = Interval(npv-eps, npv+eps)

# %%
tp = ippv*(n*inpv - n + inpv*p)/(inpv + ippv - 1)
# Out:
# rmul
# mul
# sub
# mul
# add
# mul
# 0 0
# 0 1
# ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 0 2
# ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 0 3
# ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 1 0
# ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 1 1
# 1 2
# ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 1 3
# ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 2 0
# ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 2 1
# ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 2 2
# 2 3
# ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 3 0
# ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 3 1
# ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 3 2
# ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 3 3
# add
# sub
# truediv ci
# truediv
# mul ci
# [((-2*eps + npv + ppv - 1 > 0) & (2*eps + npv + ppv - 1 > 0)) | ((-2*eps + npv + ppv - 1 < 0) & (2*eps + npv + ppv - 1 < 0)), False, False, (2*eps + npv + ppv - 1 > 0) & (-2*eps + npv + ppv - 1 < 0), (2*eps + npv + ppv - 1 > 0) & (-2*eps + npv + ppv - 1 < 0)]
# [True]
# mul
# 0 0
# 0 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 2
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 0
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 1
# 1 2
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 3
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 0
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 2
# 2 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 0
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 1
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 2
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 3
# mul
# 0 0
# 0 1
# (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 0 2
# (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 0 3
# (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 1 0
# (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 1 1
# 1 2
# (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 1 3
# (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 2 0
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 2 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 2 2
# 2 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 0
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 1
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 2
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 3
# mul
# 0 0
# 0 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 2
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 0
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 1
# 1 2
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 3
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 0
# (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 1
# ...
# 0 2
# (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 3
# (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 0
# (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 1
# 1 2
# (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 3
# (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 0
# (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 1
# (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 2
# 2 3
# (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 0
# (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 1
# (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 2
# (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 3
# mul ci final_constraints [(((-2*eps + npv + ppv - 1 > 0) & (2*eps + npv + ppv - 1 > 0)) | ((-2*eps + npv + ppv - 1 < 0) & (2*eps + npv + ppv - 1 < 0))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)), (((-2*eps + npv + ppv - 1 > 0) & (2*eps + npv + ppv - 1 > 0)) | ((-2*eps + npv + ppv - 1 < 0) & (2*eps + npv + ppv - 1 < 0))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)), (((-2*eps + npv + ppv - 1 > 0) & (2*eps + npv + ppv - 1 > 0)) | ((-2*eps + npv + ppv - 1 < 0) & (2*eps + npv + ppv - 1 < 0))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)), (((-2*eps + npv + ppv - 1 > 0) & (2*eps + npv + ppv - 1 > 0)) | ((-2*eps + npv + ppv - 1 < 0) & (2*eps + npv + ppv - 1 < 0))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv  ...

# %%
p_r=10
n_r=20
tp_r=5
fn_r=p_r - tp_r
tn_r=15
fp_r=n_r - tn_r

npv_r = np.round(tn_r/(tn_r + fn_r), 4)
ppv_r = np.round(tp_r/(tp_r + fp_r), 4)
eps_r=0.0001

# %%
results = [constraint.subs({'npv': npv_r, 'ppv': ppv_r, 'eps': eps_r, 'p': p_r, 'n': n_r}) for constraint in tp.constraints]

# %%
np.sum(np.array(results) == True)
# Out:
# 1

# %%
tp_int = tp.intervals[np.where(np.array(results) == True)[0][0]]

# %%
tp_int.lower_bound.subs({'npv': npv_r, 'ppv': ppv_r, 'eps': eps_r, 'p': p_r, 'n': n_r})
# Out:
# 4.98900999200640

# %%
tp_int.upper_bound.subs({'npv': npv_r, 'ppv': ppv_r, 'eps': eps_r, 'p': p_r, 'n': n_r})
# Out:
# 5.01101000800640

# %%
len(tp.constraints)
# Out:
# 720

# %%
tmp = 1.0/inpv
# Out:
# rtruediv
# truediv
# mul ci
# [((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0)), False, False, (eps + npv > 0) & (-eps + npv < 0), (eps + npv > 0) & (-eps + npv < 0)]
# [True]
# mul
# 0 0
# 0 1
# (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv))
# 0 2
# (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 0 3
# (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 1 0
# (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv))
# 1 1
# 1 2
# (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 1 3
# (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 2 0
# (1.0/(-eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv))
# 2 1
# (1.0/(-eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv))
# 2 2
# 2 3
# (1.0/(-eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 3 0
# (1.0/(-eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv))
# 3 1
# (1.0/(-eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv))
# 3 2
# (1.0/(-eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 3 3
# mul
# 0 0
# 0 1
# 1.0/(-eps + npv) >= -oo 1.0/(-eps + npv) <= -oo
# 0 2
# 1.0/(-eps + npv) >= -oo (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 0 3
# 1.0/(-eps + npv) >= -oo (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 1 0
# 1.0/(-eps + npv) >= -oo 1.0/(-eps + npv) <= -oo
# 1 1
# 1 2
# 1.0/(-eps + npv) >= -oo (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 1 3
# 1.0/(-eps + npv) >= -oo (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 2 0
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) 1.0/(-eps + npv) <= -oo
# 2 1
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) 1.0/(-eps + npv) <= -oo
# 2 2
# 2 3
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 3 0
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) 1.0/(-eps + npv) <= -oo
# 3 1
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) 1.0/(-eps + npv) <= -oo
# 3 2
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 3 3
# mul
# 0 0
# 0 1
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 0 2
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) 1.0/(eps + npv) <= oo
# 0 3
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) 1.0/(eps + npv) <= oo
# 1 0
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 1 1
# 1 2
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) 1.0/(eps + npv) <= oo
# 1 3
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) 1.0/(eps + npv) <= oo
# 2 0
# 1.0/(eps + npv) >= oo (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 2 1
# 1.0/(eps + npv) >= oo (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 2 2
# 2 3
# 1.0/(eps + npv) >= oo 1.0/(eps + npv) <= oo
# 3 0
# 1.0/(eps + npv) >= oo (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 3 1
# 1.0/(eps + npv) >= oo (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 3 2
# 1.0/(eps + npv) >= oo 1.0/(eps + npv) <= oo
# 3 3
# mul
# 0 0
# 0 1
# 1.0/(-eps + npv) >= -oo 1.0/(-eps + npv) <= -oo
# 0 2
# 1.0/(-eps + npv) >= -oo (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 0 3
# 1.0/(-eps + npv) >= -oo (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 1 0
# 1.0/(-eps + npv) >= -oo 1.0/(-eps + npv) <= -oo
# 1 1
# 1 2
# 1.0/(-eps + npv) >= -oo (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 1 3
# 1.0/(-eps + npv) >= -oo (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 2 0
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) 1.0/(-eps + npv) <= -oo
# 2 1
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) 1.0/(-eps + npv) <= -oo
# 2 2
# 2 3
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 3 0
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) 1.0/(-eps + npv) <= -oo
# 3 1
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) 1.0/(-eps + npv) <= -oo
# 3 2
# (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) (1.0/(-eps + npv) >= -oo) & (1.0/(-eps + npv) >= 1.0/(-eps + npv))
# 3 3
# mul
# 0 0
# 0 1
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 0 2
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) 1.0/(eps + npv) <= oo
# 0 3
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) 1.0/(eps + npv) <= oo
# 1 0
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 1 1
# 1 2
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) 1.0/(eps + npv) <= oo
# 1 3
# (1.0/(eps + npv) <= oo) & (1.0/(eps + npv) <= 1.0/(eps + npv)) 1.0/(eps + npv) <= oo
# 2 0
# 1.0/(eps + npv) >= oo (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 2 1
# 1.0/(eps + npv) >= oo (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 2 2
# 2 3
# 1.0/(eps + npv) >= oo 1.0/(eps + npv) <= oo
# 3 0
# 1.0/(eps + npv) >= oo (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 3 1
# 1.0/(eps + npv) >= oo (1.0/(eps + npv) >= oo) & (1.0/(eps + npv) >= 1.0/(eps + npv))
# 3 2
# 1.0/(eps + npv) >= oo 1.0/(eps + npv) <= oo
# 3 3
# mul ci final_constraints [(1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), (1.0/(-eps + npv) >= 1.0/(eps + npv)) & (1.0/(-eps + npv) <= 1.0/(eps + npv)) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0))), False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, False, (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) >= -oo) & (eps + npv > 0) & (-eps + npv < 0), (1.0/(-eps + npv) >= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)), (1.0/(-eps + npv) >= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)), (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) >= -oo) & (eps + npv > 0) & (-eps + npv < 0), (1.0/(-eps + npv) >= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)), (1.0/(-eps + npv) >= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)), (1.0/(-eps + npv) <= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)), (1.0/(-eps + npv) <= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)), (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) >= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) >= 1.0/(-eps + npv)) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)), (1.0/(-eps + npv) <= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)), (1.0/(-eps + npv) <= -oo) & (eps + npv > 0) & (-eps + npv < 0) & (1.0/(-eps + npv) <= 1.0/(-eps + npv)), (1.0/(-eps + npv) <= -oo) & (1.0/(-eps + npv) >= -oo) & (eps ...

# %%
tmp.__class__
# Out:
# __main__.ConstrainedIntervals

# %%
tmp.constraints[0]
# Out:
# (1.0/(eps + npv) >= 1.0/(eps + npv)) & (1.0/(eps + npv) <= 1.0/(eps + npv)) & (1.0/(eps + npv) >= 1.0/(-eps + npv)) & (1.0/(eps + npv) <= 1.0/(-eps + npv)) & (((eps + npv > 0) & (-eps + npv > 0)) | ((eps + npv < 0) & (-eps + npv < 0)))

# %%
tmp.intervals
# Out:
# [[1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [-inf,
#  -inf],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  -inf],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  inf],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  inf],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  inf],
#  [-inf,
#  -inf],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  -inf],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  inf],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  inf],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  inf]]

# %%
tmp.intervals
# Out:
# [[1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [-inf,
#  -inf],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  -inf],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  inf],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  inf],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  inf],
#  [-inf,
#  -inf],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  -inf],
#  [-inf,
#  1.0/(-eps + npv)],
#  [-inf,
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  -inf],
#  [1.0/(-eps + npv),
#  1.0/(-eps + npv)],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  1.0/(eps + npv)],
#  [1.0/(eps + npv),
#  inf],
#  [1.0/(eps + npv),
#  inf],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  inf],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  1.0/(eps + npv)],
#  [inf,
#  inf]]

# %%
ippv*(n*inpv - n + inpv*p)/(inpv + ippv - 1)
# Out:
# rmul
# mul
# sub
# mul
# add
# mul
# 0 0
# 0 1
# ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 0 2
# ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 0 3
# ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 1 0
# ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 1 1
# 1 2
# ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 1 3
# ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 2 0
# ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 2 1
# ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 2 2
# 2 3
# ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 3 0
# ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 3 1
# ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 3 2
# ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & ((eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= (-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)))
# 3 3
# add
# sub
# truediv ci
# truediv
# mul ci
# [((-2*eps + npv + ppv - 1 > 0) & (2*eps + npv + ppv - 1 > 0)) | ((-2*eps + npv + ppv - 1 < 0) & (2*eps + npv + ppv - 1 < 0)), False, False, (2*eps + npv + ppv - 1 > 0) & (-2*eps + npv + ppv - 1 < 0), (2*eps + npv + ppv - 1 > 0) & (-2*eps + npv + ppv - 1 < 0)]
# [True]
# mul
# 0 0
# 0 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 2
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 0
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 1
# 1 2
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 3
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 0
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 2
# 2 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 0
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 1
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 2
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 3
# mul
# 0 0
# 0 1
# (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 0 2
# (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 0 3
# (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 1 0
# (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 1 1
# 1 2
# (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 1 3
# (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 2 0
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 2 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 2 2
# 2 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 0
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 1
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 2
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 3
# mul
# 0 0
# 0 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 2
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 0
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 1
# 1 2
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 3
# (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 0
# (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 1
# ...
# 3 1
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (-oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 2
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= -oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(-2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(-2*eps + npv + ppv - 1))
# 3 3
# mul
# 0 0
# 0 1
# (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 2
# (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 0 3
# (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 0
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 1
# 1 2
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 1 3
# (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 0
# (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 1
# (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 2 2
# 2 3
# (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 0
# (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 1
# (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 2
# (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv)) <= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1)) (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= oo*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv))/(2*eps + npv + ppv - 1)) & (oo*(eps + ppv)*(n*(eps + npv) - n + p*(eps + npv)) >= 1.0*(-eps + ppv)*(n*(-eps + npv) - n + p*(-eps + npv))/(2*eps + npv + ppv - 1))
# 3 3
# mul ci final_constraints

# %%
solutions[tn]
# Out:
# n*spec

# %%
p * Interval(sens - eps, sens + eps)
# Out:
# [-eps + p + sens,
# eps + p + sens]
# subject to []

# %%
solutions[tp].subs(
    {sens: Interval(sens-eps, sens+eps)})
# Out:
# p*sens

# %%
2 + int0
# Out:
# [-eps + tp + 2,
# eps + tp + 2]
# subject to []

# %%
int0*int1
# Out:
# [(-eps + tn)*(-eps + tp),
# (eps + tn)*(eps + tp)]
# subject to ['-eps + tn >= 0', '-eps + tp >= 0']

# %%
int0 + int1 + p
# Out:
# [-2*eps + p + tn + tp,
# 2*eps + p + tn + tp]
# subject to []

# %%
int0/int1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[62], line 1
# ----> 1 int0/int1
#
# Cell In[57], line 64, in Interval.__truediv__(self, other)
#      60 constraint = f'zero not in [{other.lower_bound}, {other.upper_bound}]'
#      62 inverse = Interval(1.0/other.upper_bound, 1.0/other.lower_bound, constraints=[constraint])
# ---> 64 return self * inverse
#
# Cell In[57], line 47, in Interval.__mul__(self, other)
#      44 term2 = self.upper_bound * other.lower_bound
#      45 term3 = self.upper_bound * other.upper_bound
# ---> 47 return Interval(lower_bound=min(term0, term1, term2, term3),
#      48                 upper_bound=max(term0, term1, term2, term3),
#      49                 constraints=self.constraints + other.constraints)
#
# File ~/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/sympy/core/relational.py:511, in Relational.__bool__(self)
#     510 def __bool__(self):
# --> 511     raise TypeError("cannot determine truth value of Relational")
#
# TypeError: cannot determine truth value of Relational

# %%
sens = Symbol('sens')
spec = Symbol('spec')
ppv = Symbol('ppv')
npv = Symbol('npv')
acc = Symbol('acc')
tp = Symbol('tp')
tn = Symbol('tn')
fp = Symbol('fp')
fn = Symbol('fn')
p = Symbol('p')
n = Symbol('n')

# %%
results = sympy.solve([ppv - tp/(tp + fp), npv - (tn)/(tn + fn), p - tp - fn, n - tn - fp], [tp, tn, fp, fn])

# %%
results
# Out:
# {tp: ppv*(n*npv - n + npv*p)/(npv + ppv - 1),
#  tn: npv*(n*ppv + p*ppv - p)/(npv + ppv - 1),
#  fp: (-n*npv*ppv + n*npv + n*ppv - n - npv*p*ppv + npv*p)/(npv + ppv - 1),
#  fn: (-n*npv*ppv + n*ppv - npv*p*ppv + npv*p + p*ppv - p)/(npv + ppv - 1)}

# %%
sympy.factor(results[fn]).subs({tp: results[tp]})
# Out:
# -(npv - 1)*(n*ppv + p*ppv - p)/(npv + ppv - 1)
