# %%
import glob
import json

import numpy as np
from PIL import Image

# %%
citation = """@article{hrf,
  doi = {10.1155/2013/154860},
  url = {https://doi.org/10.1155/2013/154860},
  year = {2013},
  publisher = {Hindawi Limited},
  volume = {2013},
  pages = {1--11},
  author = {A. Budai and R. Bock and A. Maier and J. Hornegger and G. Michelson},
  title = {Robust Vessel Segmentation in Fundus Images},
  journal = {International Journal of Biomedical Imaging}
}"""

# %%
jpgs = glob.glob('../../../retina-datasets/hrf/*.jpg')
JPGS = glob.glob('../../../retina-datasets/hrf/*.JPG')
tifs = glob.glob('../../../retina-datasets/hrf/*.tif')

all_imgs = jpgs + JPGS + tifs

# %%
records = {}

for img in all_imgs:
    image = Image.open(img)
    identifier = img.lower()[:-4].split('/')[-1]
    identifier = '_'.join(identifier.split('_')[:2])

    if identifier not in records:
        records[identifier] = {}
    if img.endswith('.jpg' or '.JPG'):
        records[identifier]['image'] = img
    elif 'mask' in img:
        records[identifier]['fov'] = img
    else:
        records[identifier]['mask'] = img

# %%
with_fov = []
without_fov = []

for identifier in records:
    fov = Image.open(records[identifier]['fov'])
    mask = Image.open(records[identifier]['mask'])

    fov_array = np.array(fov.getchannel(0))
    mask_array = np.array(mask.getchannel(0))

    without_fov.append({'identifier': identifier,
                        'p': int(np.sum(mask_array > 0)),
                        'n': int(np.prod(mask_array.shape) - int(np.sum(mask_array > 0)))})
    with_fov.append({'identifier': identifier,
                    'p': int(np.sum((mask_array > 0) & (fov_array > 0))),
                    'n': int(np.sum((mask_array == 0) & (fov_array > 0)))})

# %%
with open('with_fov.json', 'w') as file:
    json.dump({'images': with_fov, 'citation': citation}, file, indent=2)

# %%
with open('without_fov.json', 'w') as file:
    json.dump({'images': without_fov, 'citation': citation}, file, indent=2)

# %%
print(json.dumps({'images': with_fov, 'citation': citation}, indent=2))
# Out:
# {
#   "images": [
#     {
#       "identifier": "13_h",
#       "p": 712528,
#       "n": 6199936
#     },
#     {
#       "identifier": "01_g",
#       "p": 547364,
#       "n": 6367039
#     },
#     {
#       "identifier": "02_g",
#       "p": 609533,
#       "n": 6306197
#     },
#     {
#       "identifier": "04_h",
#       "p": 771595,
#       "n": 6141417
#     },
#     {
#       "identifier": "03_g",
#       "p": 472628,
#       "n": 6441724
#     },
#     {
#       "identifier": "08_h",
#       "p": 821627,
#       "n": 6091059
#     },
#     {
#       "identifier": "06_g",
#       "p": 559555,
#       "n": 6353240
#     },
#     {
#       "identifier": "15_g",
#       "p": 599105,
#       "n": 6312786
#     },
#     {
#       "identifier": "14_h",
#       "p": 714043,
#       "n": 6196266
#     },
#     {
#       "identifier": "08_g",
#       "p": 555469,
#       "n": 6358247
#     },
#     {
#       "identifier": "12_g",
#       "p": 676331,
#       "n": 6237253
#     },
#     {
#       "identifier": "05_g",
#       "p": 534949,
#       "n": 6378706
#     },
#     {
#       "identifier": "15_h",
#       "p": 641245,
#       "n": 6271569
#     },
#     {
#       "identifier": "09_g",
#       "p": 541904,
#       "n": 6373741
#     },
#     {
#       "identifier": "02_h",
#       "p": 808422,
#       "n": 6105947
#     },
#     {
#       "identifier": "01_h",
#       "p": 833888,
#       "n": 6079895
#     },
#     {
#       "identifier": "13_g",
#       "p": 556950,
#       "n": 6359664
#     },
#     {
#       "identifier": "11_h",
#       "p": 765310,
#       "n": 6148731
#     },
#     {
#       "identifier": "14_g",
#       "p": 578059,
#       "n": 6337293
#     },
#     {
#       "identifier": "09_h",
#       "p": 636468,
#       "n": 6277468
#     },
#     {
#       "identifier": "07_g",
#       "p": 532711,
#       "n": 6380547
#     },
#     {
#       "identifier": "07_h",
#       "p": 729013,
#       "n": 6184159
#     },
#     {
#       "identifier": "04_g",
#       "p": 526821,
#       "n": 6386024
#     },
#     {
#       "identifier": "12_h",
#       "p": 859191,
#       "n": 6053519
#     },
#     {
#       "identifier": "03_h",
#       "p": 864126,
#       "n": 6047946
#     },
#     {
#       "identifier": "05_h",
#       "p": 738781,
#       "n": 6173325
#     },
#     {
#       "identifier": "06_h",
#       "p": 829870,
#       "n": 6081714
#     },
#     {
#       "identifier": "10_g",
#       "p": 536533,
#       "n": 6377189
#     },
#     {
#       "identifier": "11_g",
#       "p": 625555,
#       "n": 6287784
#     },
#     {
#       "identifier": "10_h",
#       "p": 705438,
#       "n": 6207821
#     },
#     {
#       "identifier": "09_dr",
#       "p": 554316,
#       "n": 6359135
#     },
#     {
#       "identifier": "08_dr",
#       "p": 615597,
#       "n": 6297723
#     },
#     {
#       "identifier": "01_dr",
#       "p": 415917,
#       "n": 6497074
#     },
#     {
#       "identifier": "03_dr",
#       "p": 494315,
#       "n": 6421515
#     },
#     {
#       "identifier": "12_dr",
#       "p": 556663,
#       "n": 6357461
#     },
#     {
#       "identifier": "15_dr",
#       "p": 534858,
#       "n": 6378062
#     },
#     {
#       "identifier": "10_dr",
#       "p": 714802,
#       "n": 6196747
#     },
#     {
#       "identifier": "07_dr",
#       "p": 636263,
#       "n": 6278673
#     },
#     {
#       "identifier": "05_dr",
#       "p": 508884,
#       "n": 6403490
#     },
#     {
#       "identifier": "02_dr",
#       "p": 521398,
#       "n": 6393626
#     },
#     {
#       "identifier": "13_dr",
#       "p": 559465,
#       "n": 6354548
#     },
#     {
#       "identifier": "06_dr",
#       "p": 617844,
#       "n": 6296407
#     },
#     {
#       "identifier": "14_dr",
#       "p": 624849,
#       "n": 6289184
#     },
#     {
#       "identifier": "11_dr",
#       "p": 692886,
#       "n": 6218889
#     },
#     {
#       "identifier": "04_dr",
#       "p": 461975,
#       "n": 6451423
#     }
#   ],
#   "citation": "@article{hrf,\n  doi = {10.1155/2013/154860},\n  url = {https://doi.org/10.1155/2013/154860},\n  year = {2013},\n  publisher = {Hindawi Limited},\n  volume = {2013},\n  pages = {1--11},\n  author = {A. Budai and R. Bock and A. Maier and J. Hornegger and G. Michelson},\n  title = {Robust Vessel Segmentation in Fundus Images},\n  journal = {International Journal of Biomedical Imaging}\n}"
# }

# %%
print(json.dumps({'images': without_fov, 'citation': citation}, indent=2))
# Out:
# {
#   "images": [
#     {
#       "identifier": "13_h",
#       "p": 712528,
#       "n": 7472816
#     },
#     {
#       "identifier": "01_g",
#       "p": 547632,
#       "n": 7637712
#     },
#     {
#       "identifier": "02_g",
#       "p": 609722,
#       "n": 7575622
#     },
#     {
#     },
#     {
#       "identifier": "14_dr",
#       "p": 624936,
#       "n": 7560408
#     },
#     {
#       "identifier": "11_dr",
#       "p": 692937,
#       "n": 7492407
#     },
#     {
#       "identifier": "04_dr",
#       "p": 462179,
#       "n": 7723165
#     }
#   ],
#   "citation": "@article{hrf,\n  doi = {10.1155/2013/154860},\n  url = {https://doi.org/10.1155/2013/154860},\n  year = {2013},\n  publisher = {Hindawi Limited},\n  volume = {2013},\n  pages = {1--11},\n  author = {A. Budai and R. Bock and A. Maier and J. Hornegger and G. Michelson},\n  title = {Robust Vessel Segmentation in Fundus Images},\n  journal = {International Journal of Biomedical Imaging}\n}"
# }

# %%
without_fov
# Out:
# [{'identifier': '13_h', 'p': 712528, 'n': 7472816},
#  {'identifier': '01_g', 'p': 547632, 'n': 7637712},
#  {'identifier': '02_g', 'p': 609722, 'n': 7575622},
#  {'identifier': '04_h', 'p': 771601, 'n': 7413743},
#  {'identifier': '03_g', 'p': 472735, 'n': 7712609},
#  {'identifier': '08_h', 'p': 821627, 'n': 7363717},
#  {'identifier': '06_g', 'p': 559765, 'n': 7625579},
#  {'identifier': '15_g', 'p': 599188, 'n': 7586156},
#  {'identifier': '14_h', 'p': 714054, 'n': 7471290},
#  {'identifier': '08_g', 'p': 555558, 'n': 7629786},
#  {'identifier': '12_g', 'p': 676424, 'n': 7508920},
#  {'identifier': '05_g', 'p': 535051, 'n': 7650293},
#  {'identifier': '15_h', 'p': 641245, 'n': 7544099},
#  {'identifier': '09_g', 'p': 541943, 'n': 7643401},
#  {'identifier': '02_h', 'p': 808438, 'n': 7376906},
#  {'identifier': '01_h', 'p': 833888, 'n': 7351456},
#  {'identifier': '13_g', 'p': 556981, 'n': 7628363},
#  {'identifier': '11_h', 'p': 765355, 'n': 7419989},
#  {'identifier': '14_g', 'p': 578169, 'n': 7607175},
#  {'identifier': '09_h', 'p': 636468, 'n': 7548876},
#  {'identifier': '07_g', 'p': 532784, 'n': 7652560},
#  {'identifier': '07_h', 'p': 729013, 'n': 7456331},
#  {'identifier': '04_g', 'p': 526916, 'n': 7658428},
#  {'identifier': '12_h', 'p': 859295, 'n': 7326049},
#  {'identifier': '03_h', 'p': 864171, 'n': 7321173},
#  {'identifier': '05_h', 'p': 738786, 'n': 7446558},
#  {'identifier': '06_h', 'p': 829870, 'n': 7355474},
#  {'identifier': '10_g', 'p': 536598, 'n': 7648746},
#  {'identifier': '11_g', 'p': 625693, 'n': 7559651},
#  {'identifier': '10_h', 'p': 705438, 'n': 7479906},
#  {'identifier': '09_dr', 'p': 554447, 'n': 7630897},
#  {'identifier': '08_dr', 'p': 615777, 'n': 7569567},
#  {'identifier': '01_dr', 'p': 416282, 'n': 7769062},
#  {'identifier': '03_dr', 'p': 494400, 'n': 7690944},
#  {'identifier': '12_dr', 'p': 556724, 'n': 7628620},
#  {'identifier': '15_dr', 'p': 535043, 'n': 7650301},
#  {'identifier': '10_dr', 'p': 714889, 'n': 7470455},
#  {'identifier': '07_dr', 'p': 636359, 'n': 7548985},
#  {'identifier': '05_dr', 'p': 508978, 'n': 7676366},
#  {'identifier': '02_dr', 'p': 521878, 'n': 7663466},
#  {'identifier': '13_dr', 'p': 559479, 'n': 7625865},
#  {'identifier': '06_dr', 'p': 617966, 'n': 7567378},
#  {'identifier': '14_dr', 'p': 624936, 'n': 7560408},
#  {'identifier': '11_dr', 'p': 692937, 'n': 7492407},
#  {'identifier': '04_dr', 'p': 462179, 'n': 7723165}]

# %%
with_fov
# Out:
# [{'identifier': '13_h', 'p': 712528, 'n': 6199936},
#  {'identifier': '01_g', 'p': 547364, 'n': 6367039},
#  {'identifier': '02_g', 'p': 609533, 'n': 6306197},
#  {'identifier': '04_h', 'p': 771595, 'n': 6141417},
#  {'identifier': '03_g', 'p': 472628, 'n': 6441724},
#  {'identifier': '08_h', 'p': 821627, 'n': 6091059},
#  {'identifier': '06_g', 'p': 559555, 'n': 6353240},
#  {'identifier': '15_g', 'p': 599105, 'n': 6312786},
#  {'identifier': '14_h', 'p': 714043, 'n': 6196266},
#  {'identifier': '08_g', 'p': 555469, 'n': 6358247},
#  {'identifier': '12_g', 'p': 676331, 'n': 6237253},
#  {'identifier': '05_g', 'p': 534949, 'n': 6378706},
#  {'identifier': '15_h', 'p': 641245, 'n': 6271569},
#  {'identifier': '09_g', 'p': 541904, 'n': 6373741},
#  {'identifier': '02_h', 'p': 808422, 'n': 6105947},
#  {'identifier': '01_h', 'p': 833888, 'n': 6079895},
#  {'identifier': '13_g', 'p': 556950, 'n': 6359664},
#  {'identifier': '11_h', 'p': 765310, 'n': 6148731},
#  {'identifier': '14_g', 'p': 578059, 'n': 6337293},
#  {'identifier': '09_h', 'p': 636468, 'n': 6277468},
#  {'identifier': '07_g', 'p': 532711, 'n': 6380547},
#  {'identifier': '07_h', 'p': 729013, 'n': 6184159},
#  {'identifier': '04_g', 'p': 526821, 'n': 6386024},
#  {'identifier': '12_h', 'p': 859191, 'n': 6053519},
#  {'identifier': '03_h', 'p': 864126, 'n': 6047946},
#  {'identifier': '05_h', 'p': 738781, 'n': 6173325},
#  {'identifier': '06_h', 'p': 829870, 'n': 6081714},
#  {'identifier': '10_g', 'p': 536533, 'n': 6377189},
#  {'identifier': '11_g', 'p': 625555, 'n': 6287784},
#  {'identifier': '10_h', 'p': 705438, 'n': 6207821},
#  {'identifier': '09_dr', 'p': 554316, 'n': 6359135},
#  {'identifier': '08_dr', 'p': 615597, 'n': 6297723},
#  {'identifier': '01_dr', 'p': 415917, 'n': 6497074},
#  {'identifier': '03_dr', 'p': 494315, 'n': 6421515},
#  {'identifier': '12_dr', 'p': 556663, 'n': 6357461},
#  {'identifier': '15_dr', 'p': 534858, 'n': 6378062},
#  {'identifier': '10_dr', 'p': 714802, 'n': 6196747},
#  {'identifier': '07_dr', 'p': 636263, 'n': 6278673},
#  {'identifier': '05_dr', 'p': 508884, 'n': 6403490},
#  {'identifier': '02_dr', 'p': 521398, 'n': 6393626},
#  {'identifier': '13_dr', 'p': 559465, 'n': 6354548},
#  {'identifier': '06_dr', 'p': 617844, 'n': 6296407},
#  {'identifier': '14_dr', 'p': 624849, 'n': 6289184},
#  {'identifier': '11_dr', 'p': 692886, 'n': 6218889},
#  {'identifier': '04_dr', 'p': 461975, 'n': 6451423}]
