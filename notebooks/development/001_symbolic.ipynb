# %%
import sympy
from sympy import Symbol

# %%
from mlscorecheck.core import Interval, IntervalUnion, SymbolicInterval, SymbolicIntervalUnion

# %%
a = Symbol('a')
b = Symbol('b')
c = Symbol('c')
d = Symbol('d')

int0 = SymbolicInterval(c - d, a + b)
int1 = SymbolicInterval(a*b, c*d)
int2 = SymbolicInterval(a, c)
int3 = SymbolicInterval(b, d)
int4 = SymbolicInterval(c, d)

intun0 = SymbolicIntervalUnion([int0, int1])
intun1 = SymbolicIntervalUnion([int2, int3, int4])

# %%
intun0 * 2
# Out:
# union mul
# aaa
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'int'> <class 'bool'>
# [2*a*b, 2*c*d] subject to True,
# [2*c*d, 2*a*b] subject to False
# <class 'mlscorecheck.core._symbolic_interval.SymbolicIntervalUnion'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'int'> <class 'bool'>
# [2*a + 2*b, 2*c - 2*d] subject to False,
# [2*c - 2*d, 2*a + 2*b] subject to True
# <class 'mlscorecheck.core._symbolic_interval.SymbolicIntervalUnion'>
# [2*a*b, 2*c*d] subject to True,
# [2*c - 2*d, 2*a + 2*b] subject to True,
# [2*c*d, 2*a*b] subject to False,
# [2*a + 2*b, 2*c - 2*d] subject to False

# %%
intun0 = SymbolicIntervalUnion([int2])

# %%
#sympy.simplify((0 >= a) & (1.0/a < 0))

# %%
1.0 / (1.0 / intun0)
# Out:
# union rdiv
# create
# l 1.0
# u 1.0
# c True
# sl 1.00000000000000
# su 1.00000000000000
# created
# union div
# div
# [1.00000000000000,
# 1.00000000000000]
# subject to True
# [a,
# c]
# subject to True
# create
# l 1.0/c
# u 1.0/a
# c (a > 0) | (c < 0)
# sl 1.0/c
# su 1.0/a
# created
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'bool'>
# aaa
# bbb
# ccc
# ddd
# 1.0/c 1.0/a True (a > 0) | (c < 0)
# x 1.0/a
# y 1.0/c
# lower 1.0/c <= 1.0/a
# upper 1.0/a >= 1.0/c
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/c
# u 1.0/a
# c ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c)
# sl 1.0/c
# su 1.0/a
# created
# nnn
# 1.0/a 1.0/c True (a > 0) | (c < 0)
# x 1.0/c
# y 1.0/a
# lower 1.0/a <= 1.0/c
# upper 1.0/c >= 1.0/a
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/a
# u 1.0/c
# c ((a > 0) | (c < 0)) & (1.0/c >= 1.0/a)
# sl 1.0/a
# su 1.0/c
# created
# nnn
# eee
# create
# l -inf
# u 1.0/a
# ...

# %%
1.0 / (1.0 / int2)
# Out:
# rdiv
# create
# l 1.0
# u 1.0
# c True
# sl 1.00000000000000
# su 1.00000000000000
# created
# div
# [1.00000000000000,
# 1.00000000000000]
# subject to True
# [a,
# c]
# subject to True
# create
# l 1.0/c
# u 1.0/a
# c (a > 0) | (c < 0)
# sl 1.0/c
# su 1.0/a
# created
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'bool'>
# aaa
# bbb
# ccc
# ddd
# 1.0/c 1.0/a True (a > 0) | (c < 0)
# x 1.0/a
# y 1.0/c
# lower 1.0/c <= 1.0/a
# upper 1.0/a >= 1.0/c
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/c
# u 1.0/a
# c ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c)
# sl 1.0/c
# su 1.0/a
# created
# nnn
# 1.0/a 1.0/c True (a > 0) | (c < 0)
# x 1.0/c
# y 1.0/a
# lower 1.0/a <= 1.0/c
# upper 1.0/c >= 1.0/a
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/a
# u 1.0/c
# c ((a > 0) | (c < 0)) & (1.0/c >= 1.0/a)
# sl 1.0/a
# su 1.0/c
# created
# nnn
# eee
# create
# l -inf
# u 1.0/a
# ...

# %%
subst = {a: 1, b: 2, c: 3, d: 4}

# %%
intun0.to_interval_union(subst) == (1.0 / (1.0 / intun0)).to_interval_union(subst)
# Out:
# union rdiv
# create
# l 1.0
# u 1.0
# c True
# sl 1.00000000000000
# su 1.00000000000000
# created
# union div
# div
# [1.00000000000000,
# 1.00000000000000]
# subject to True
# [a,
# c]
# subject to True
# create
# l 1.0/c
# u 1.0/a
# c (a > 0) | (c < 0)
# sl 1.0/c
# su 1.0/a
# created
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'bool'>
# aaa
# bbb
# ccc
# ddd
# 1.0/c 1.0/a True (a > 0) | (c < 0)
# x 1.0/a
# y 1.0/c
# lower 1.0/c <= 1.0/a
# upper 1.0/a >= 1.0/c
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/c
# u 1.0/a
# c ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c)
# sl 1.0/c
# su 1.0/a
# created
# nnn
# 1.0/a 1.0/c True (a > 0) | (c < 0)
# x 1.0/c
# y 1.0/a
# lower 1.0/a <= 1.0/c
# upper 1.0/c >= 1.0/a
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/a
# u 1.0/c
# c ((a > 0) | (c < 0)) & (1.0/c >= 1.0/a)
# sl 1.0/a
# su 1.0/c
# created
# nnn
# eee
# create
# l -inf
# u 1.0/a
# ...

# %%
intun0.to_interval_union(subst)
# Out:
# [1, 3]

# %%
(1.0 / intun0).to_interval_union(subst)
# Out:
# union rdiv
# create
# l 1.0
# u 1.0
# c True
# sl 1.00000000000000
# su 1.00000000000000
# created
# union div
# div
# [1.00000000000000,
# 1.00000000000000]
# subject to True
# [a,
# c]
# subject to True
# create
# l 1.0/c
# u 1.0/a
# c (a > 0) | (c < 0)
# sl 1.0/c
# su 1.0/a
# created
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'bool'>
# aaa
# bbb
# ccc
# ddd
# 1.0/c 1.0/a True (a > 0) | (c < 0)
# x 1.0/a
# y 1.0/c
# lower 1.0/c <= 1.0/a
# upper 1.0/a >= 1.0/c
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/c
# u 1.0/a
# c ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c)
# sl 1.0/c
# su 1.0/a
# created
# nnn
# 1.0/a 1.0/c True (a > 0) | (c < 0)
# x 1.0/c
# y 1.0/a
# lower 1.0/a <= 1.0/c
# upper 1.0/c >= 1.0/a
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/a
# u 1.0/c
# c ((a > 0) | (c < 0)) & (1.0/c >= 1.0/a)
# sl 1.0/a
# su 1.0/c
# created
# nnn
# eee
# create
# l -inf
# u 1.0/a
# ...

# %%
(1.0 / intun0).condition_mask(subst)
# Out:
# union rdiv
# create
# l 1.0
# u 1.0
# c True
# sl 1.00000000000000
# su 1.00000000000000
# created
# union div
# div
# [1.00000000000000,
# 1.00000000000000]
# subject to True
# [a,
# c]
# subject to True
# create
# l 1.0/c
# u 1.0/a
# c (a > 0) | (c < 0)
# sl 1.0/c
# su 1.0/a
# created
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'bool'>
# aaa
# bbb
# ccc
# ddd
# 1.0/c 1.0/a True (a > 0) | (c < 0)
# x 1.0/a
# y 1.0/c
# lower 1.0/c <= 1.0/a
# upper 1.0/a >= 1.0/c
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/c
# u 1.0/a
# c ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c)
# sl 1.0/c
# su 1.0/a
# created
# nnn
# 1.0/a 1.0/c True (a > 0) | (c < 0)
# x 1.0/c
# y 1.0/a
# lower 1.0/a <= 1.0/c
# upper 1.0/c >= 1.0/a
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/a
# u 1.0/c
# c ((a > 0) | (c < 0)) & (1.0/c >= 1.0/a)
# sl 1.0/a
# su 1.0/c
# created
# nnn
# eee
# create
# l -inf
# u 1.0/a
# ...

# %%
tmp = (1.0 / (1.0 / intun0))
# Out:
# union rdiv
# create
# l 1.0
# u 1.0
# c True
# sl 1.00000000000000
# su 1.00000000000000
# created
# union div
# div
# [1.00000000000000,
# 1.00000000000000]
# subject to True
# [a,
# c]
# subject to True
# create
# l 1.0/c
# u 1.0/a
# c (a > 0) | (c < 0)
# sl 1.0/c
# su 1.0/a
# created
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'bool'>
# aaa
# bbb
# ccc
# ddd
# 1.0/c 1.0/a True (a > 0) | (c < 0)
# x 1.0/a
# y 1.0/c
# lower 1.0/c <= 1.0/a
# upper 1.0/a >= 1.0/c
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/c
# u 1.0/a
# c ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c)
# sl 1.0/c
# su 1.0/a
# created
# nnn
# 1.0/a 1.0/c True (a > 0) | (c < 0)
# x 1.0/c
# y 1.0/a
# lower 1.0/a <= 1.0/c
# upper 1.0/c >= 1.0/a
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/a
# u 1.0/c
# c ((a > 0) | (c < 0)) & (1.0/c >= 1.0/a)
# sl 1.0/a
# su 1.0/c
# created
# nnn
# eee
# create
# l -inf
# u 1.0/a
# ...

# %%
mask = tmp.condition_mask(subst)

# %%
tmp2 = [interval for interval, m in zip(tmp.intervals, mask) if m]

# %%
tmp3 = [inter.to_interval(subst) for inter in tmp2]

# %%
tmp2
# Out:
# [[1.0*a,
#  1.0*c]
#  subject to (1.0*c >= 1.0*a) & ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c) & ((1.0/c > 0) | (1.0/a < 0))]

# %%
tmp3
# Out:
# [[1.00000000000000,
#  3.00000000000000]]

# %%
IntervalUnion(tmp3)
# Out:
# [1.00000000000000, 3.00000000000000]

# %%
.intervals
# Out:
# union rdiv
# create
# l 1.0
# u 1.0
# c True
# sl 1.00000000000000
# su 1.00000000000000
# created
# union div
# div
# [1.00000000000000,
# 1.00000000000000]
# subject to True
# [a,
# c]
# subject to True
# create
# l 1.0/c
# u 1.0/a
# c (a > 0) | (c < 0)
# sl 1.0/c
# su 1.0/a
# created
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'bool'>
# aaa
# bbb
# ccc
# ddd
# 1.0/c 1.0/a True (a > 0) | (c < 0)
# x 1.0/a
# y 1.0/c
# lower 1.0/c <= 1.0/a
# upper 1.0/a >= 1.0/c
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/c
# u 1.0/a
# c ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c)
# sl 1.0/c
# su 1.0/a
# created
# nnn
# 1.0/a 1.0/c True (a > 0) | (c < 0)
# x 1.0/c
# y 1.0/a
# lower 1.0/a <= 1.0/c
# upper 1.0/c >= 1.0/a
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/a
# u 1.0/c
# c ((a > 0) | (c < 0)) & (1.0/c >= 1.0/a)
# sl 1.0/a
# su 1.0/c
# created
# nnn
# eee
# create
# l -inf
# u 1.0/a
# ...

# %%
(1.0 / (1.0 / intun0)).to_interval_union(subst)
# Out:
# union rdiv
# create
# l 1.0
# u 1.0
# c True
# sl 1.00000000000000
# su 1.00000000000000
# created
# union div
# div
# [1.00000000000000,
# 1.00000000000000]
# subject to True
# [a,
# c]
# subject to True
# create
# l 1.0/c
# u 1.0/a
# c (a > 0) | (c < 0)
# sl 1.0/c
# su 1.0/a
# created
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'bool'>
# aaa
# bbb
# ccc
# ddd
# 1.0/c 1.0/a True (a > 0) | (c < 0)
# x 1.0/a
# y 1.0/c
# lower 1.0/c <= 1.0/a
# upper 1.0/a >= 1.0/c
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/c
# u 1.0/a
# c ((a > 0) | (c < 0)) & (1.0/a >= 1.0/c)
# sl 1.0/c
# su 1.0/a
# created
# nnn
# 1.0/a 1.0/c True (a > 0) | (c < 0)
# x 1.0/c
# y 1.0/a
# lower 1.0/a <= 1.0/c
# upper 1.0/c >= 1.0/a
# True
# (a > 0) | (c < 0)
# adding
# create
# l 1.0/a
# u 1.0/c
# c ((a > 0) | (c < 0)) & (1.0/c >= 1.0/a)
# sl 1.0/a
# su 1.0/c
# created
# nnn
# eee
# create
# l -inf
# u 1.0/a
# ...

# %%
sympy.simplify(True).__class__
# Out:
# sympy.logic.boolalg.BooleanTrue

# %%
tp = Symbol('tp')
tn = Symbol('tn')
fp = Symbol('fp')
fn = Symbol('fn')
ppv = Symbol('ppv')
npv = Symbol('npv')
eps = Symbol('eps')
p = Symbol('p')
n = Symbol('n')

# %%
solutions = sympy.solve([ppv - tp/(tp + fp), npv - tn/(tn + fn), p - tp - fn, n - tn - fp], [tp, tn, fp, fn])

# %%
Interval(1, 2) * IntervalUnion([Interval(2, 3)])
# Out:
# [2, 6]

# %%
solutions
# Out:
# {tp: ppv*(n*npv - n + npv*p)/(npv + ppv - 1),
#  tn: npv*(n*ppv + p*ppv - p)/(npv + ppv - 1),
#  fp: (-n*npv*ppv + n*npv + n*ppv - n - npv*p*ppv + npv*p)/(npv + ppv - 1),
#  fn: (-n*npv*ppv + n*ppv - npv*p*ppv + npv*p + p*ppv - p)/(npv + ppv - 1)}

# %%
ippv = SymbolicInterval(ppv - eps, ppv + eps)
inpv = SymbolicInterval(npv - eps, npv + eps)

# %%
tmp = (n * inpv)
# Out:
# rmul
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx

# %%
tmp.__class__
# Out:
# mlscorecheck.core._symbolic_interval.SymbolicIntervalUnion

# %%
itp = inpv * tmp
# Out:
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicIntervalUnion'> <class 'bool'>
# union mul
# aaa
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.StrictLessThan'>

# %%
itp.intervals[0].upper_bound
# Out:
# n*(-eps + npv)*(eps + npv)

# %%
len((n*inpv - n + inpv*p).intervals)
# Out:
# rmul
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union sub
# sub
# sub
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union add
# add
# add
# add
# add
# 4

# %%
len((1.0 / (inpv + ippv - 1)).intervals)
# Out:
# add
# sub
# rdiv
# 2

# %%
len(((n*inpv - n + inpv*p)/(inpv + ippv - 1)).intervals)
# Out:
# rmul
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union sub
# sub
# sub
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union add
# add
# add
# add
# add
# add
# sub
# union div
# div
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# ...

# %%
tmp0 = (n*inpv - n + inpv*p)
tmp1 = (inpv + ippv - 1)
# Out:
# rmul
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union sub
# sub
# sub
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union add
# add
# add
# add
# add
# add
# sub

# %%
len((tmp0/tmp1).intervals)
# Out:
# union div
# div
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# div
# ...

# %%
len((ippv * (n*inpv - n + inpv*p) /(inpv + ippv - 1)).intervals)
# Out:
# rmul
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union sub
# sub
# sub
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union add
# add
# add
# add
# add
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicIntervalUnion'> <class 'bool'>
# union mul
# aaa
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.GreaterThan'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.relational.StrictLessThan'>
# ...

# %%
len((ippv * (n*inpv - n + inpv*p) * ((1.0/(inpv + ippv - 1)))).intervals)
# Out:
# rmul
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union sub
# sub
# sub
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union add
# add
# add
# add
# add
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicIntervalUnion'> <class 'bool'>
# union mul
# aaa
# <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> And
# <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'>
# ...

# %%
len((1.0/(inpv + ippv - 1)).intervals)
# Out:
# add
# sub
# rdiv
# 2

# %%
itp = ippv * (n*inpv - n + inpv*p) / (inpv + ippv - 1)
# Out:
# rmul
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union sub
# sub
# sub
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'sympy.core.symbol.Symbol'> <class 'bool'>
# xxx
# union add
# add
# add
# add
# add
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicIntervalUnion'> <class 'bool'>
# union mul
# aaa
# <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'>
# mul <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> And
# <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'> <class 'mlscorecheck.core._symbolic_interval.SymbolicInterval'>
# ...

# %%
len(itp.intervals)
# Out:
# 2880

# %%
len(itp.intervals)
# Out:
# 2880

# %%
sym = SymbolicInterval(5, 6, True)

# %%
acc = Symbol('acc')
p = Symbol('p')

# %%
(acc >= 0) & (acc <= 0)
# Out:
# (acc >= 0) & (acc <= 0)

# %%
acc == 0
# Out:
# False

# %%
acc = p > 0

# %%
acc
# Out:
# p > 0

# %%
acc = p > 0

# %%
acc & False
# Out:
# False

# %%
(acc == acc).__class__
# Out:
# bool

# %%
True & (p > 0)
# Out:
# p > 0

# %%
import sympy

# %%
sympy.subs(True, {'a': 5})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 sympy.subs(True, {'a': 5})
#
# AttributeError: module 'sympy' has no attribute 'subs'

# %%
tmp = True
