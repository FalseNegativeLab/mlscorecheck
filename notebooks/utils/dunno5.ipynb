# %%
from mlscorecheck.bundles import drive_aggregated

# %%
results = drive_aggregated({'acc': 0.950, 'sens': 0.899, 'spec': 0.9834},
                                eps=1e-4,
                                image_set='test')
# Out:
# 2023-09-04 13:39:29,348:INFO:testing MoR FoV pixels
# 2023-09-04 13:39:29,353:INFO:a random identifier for the fold has been generated uannknabnsrwybqc
# 2023-09-04 13:39:29,354:INFO:a random identifier for the fold has been generated zihbtvhzucvxcywp
# 2023-09-04 13:39:29,356:INFO:a random identifier for the fold has been generated rhwiokpkyjjnahof
# 2023-09-04 13:39:29,359:INFO:a random identifier for the fold has been generated unpobbpftcmrfcjz
# 2023-09-04 13:39:29,360:INFO:a random identifier for the fold has been generated uueujlvjtipobzgs
# 2023-09-04 13:39:29,361:INFO:a random identifier for the fold has been generated ywkcoftlkltmwfiz
# 2023-09-04 13:39:29,362:INFO:a random identifier for the fold has been generated bkdzjlumqkqoagxv
# 2023-09-04 13:39:29,364:INFO:a random identifier for the fold has been generated qdklnnkxwlzjorkz
# 2023-09-04 13:39:29,365:INFO:a random identifier for the fold has been generated cfxjnndiuvdnbhgq
# 2023-09-04 13:39:29,367:INFO:a random identifier for the fold has been generated zvjdlzcqeebimgaz
# 2023-09-04 13:39:29,368:INFO:a random identifier for the fold has been generated xegyxspfqhkufmei
# 2023-09-04 13:39:29,369:INFO:a random identifier for the fold has been generated ipjitfznyzxlixsf
# 2023-09-04 13:39:29,370:INFO:a random identifier for the fold has been generated oqcjwaurkxabzrsg
# 2023-09-04 13:39:29,372:INFO:a random identifier for the fold has been generated dlosgmukfpunbwuw
# 2023-09-04 13:39:29,373:INFO:a random identifier for the fold has been generated cwlatrfzcjrahgzg
# 2023-09-04 13:39:29,374:INFO:a random identifier for the fold has been generated xgknquamvyxplfly
# 2023-09-04 13:39:29,375:INFO:a random identifier for the fold has been generated wviapsnvlswmqpvq
# 2023-09-04 13:39:29,376:INFO:a random identifier for the fold has been generated fwltelyicholonxd
# 2023-09-04 13:39:29,377:INFO:a random identifier for the fold has been generated zemxkqltovzdvney
# 2023-09-04 13:39:29,379:INFO:a random identifier for the fold has been generated nvxrvagpcifemzpd
# 2023-09-04 13:39:29,385:INFO:None: adding condition acc >= 0.949899
# 2023-09-04 13:39:29,387:INFO:None: adding condition acc <= 0.950101
# 2023-09-04 13:39:29,388:INFO:None: adding condition sens >= 0.898899
# 2023-09-04 13:39:29,389:INFO:None: adding condition sens <= 0.899101
# 2023-09-04 13:39:29,391:INFO:None: adding condition spec >= 0.983299
# 2023-09-04 13:39:29,394:INFO:None: adding condition spec <= 0.983501
# 2023-09-04 13:39:29,413:INFO:testing MoR all pixels
# 2023-09-04 13:39:29,416:INFO:a random identifier for the fold has been generated moufkltcrddftzsz
# 2023-09-04 13:39:29,418:INFO:a random identifier for the fold has been generated nyjrybsbceosiqxp
# 2023-09-04 13:39:29,419:INFO:a random identifier for the fold has been generated gbhoacgxetzrbmgn
# 2023-09-04 13:39:29,421:INFO:a random identifier for the fold has been generated dcrjwkmubacpypkl
# 2023-09-04 13:39:29,423:INFO:a random identifier for the fold has been generated alhdbqvuzblzllwi
# 2023-09-04 13:39:29,425:INFO:a random identifier for the fold has been generated ugudnkfljoorzknr
# 2023-09-04 13:39:29,426:INFO:a random identifier for the fold has been generated hmdwiwwcprhiulnk
# 2023-09-04 13:39:29,428:INFO:a random identifier for the fold has been generated idnhcqzmpwxmywis
# 2023-09-04 13:39:29,429:INFO:a random identifier for the fold has been generated dznsruphpuhacnsi
# 2023-09-04 13:39:29,431:INFO:a random identifier for the fold has been generated vrameokwydmmvpqj
# 2023-09-04 13:39:29,432:INFO:a random identifier for the fold has been generated amqisitfwdjfxfxe
# 2023-09-04 13:39:29,434:INFO:a random identifier for the fold has been generated iweajilovcybgrhi
# 2023-09-04 13:39:29,435:INFO:a random identifier for the fold has been generated briyamcmauicjgvr
# 2023-09-04 13:39:29,436:INFO:a random identifier for the fold has been generated hvjnxbdsdtbalctz
# 2023-09-04 13:39:29,438:INFO:a random identifier for the fold has been generated czdwpgafdcqcnark
# 2023-09-04 13:39:29,439:INFO:a random identifier for the fold has been generated vuotrdccclziterl
# 2023-09-04 13:39:29,440:INFO:a random identifier for the fold has been generated fitppjvroadgbqcl
# 2023-09-04 13:39:29,441:INFO:a random identifier for the fold has been generated dvjmyydpsqnsfqon
# 2023-09-04 13:39:29,442:INFO:a random identifier for the fold has been generated mjkxewxwnvlzifya
# 2023-09-04 13:39:29,443:INFO:a random identifier for the fold has been generated ieyfrhlxjpdbifqp
# 2023-09-04 13:39:29,454:INFO:None: adding condition acc >= 0.949899
# 2023-09-04 13:39:29,459:INFO:None: adding condition acc <= 0.950101
# 2023-09-04 13:39:29,461:INFO:None: adding condition sens >= 0.898899
# 2023-09-04 13:39:29,462:INFO:None: adding condition sens <= 0.899101
# 2023-09-04 13:39:29,464:INFO:None: adding condition spec >= 0.983299
# 2023-09-04 13:39:29,465:INFO:None: adding condition spec <= 0.983501
# 2023-09-04 13:39:29,483:INFO:testing RoM FoV pixels
# 2023-09-04 13:39:29,487:INFO:a random identifier for the fold has been generated mxpnbyqkcgscmepk
# 2023-09-04 13:39:29,488:INFO:a random identifier for the fold has been generated xjzvkrhjykirzxiv
# 2023-09-04 13:39:29,489:INFO:a random identifier for the fold has been generated paujathdmkohoyco
# 2023-09-04 13:39:29,490:INFO:a random identifier for the fold has been generated pwqvkckubmkeinaf
# 2023-09-04 13:39:29,491:INFO:a random identifier for the fold has been generated bgefkuiwvtfstcyi
# 2023-09-04 13:39:29,493:INFO:a random identifier for the fold has been generated uoygyddvwovdldzz
# 2023-09-04 13:39:29,496:INFO:a random identifier for the fold has been generated jlgfhehzwjzpveii
# 2023-09-04 13:39:29,498:INFO:a random identifier for the fold has been generated vojryehrygpoliah
# 2023-09-04 13:39:29,500:INFO:a random identifier for the fold has been generated upzgpkfdawfpiuof
# 2023-09-04 13:39:29,502:INFO:a random identifier for the fold has been generated yprslqdqnneogmxx
# 2023-09-04 13:39:29,503:INFO:a random identifier for the fold has been generated jzricauzeuqpgswg
# 2023-09-04 13:39:29,504:INFO:a random identifier for the fold has been generated dquoxsdjplcwknnt
# 2023-09-04 13:39:29,505:INFO:a random identifier for the fold has been generated unhiramddvgjtktx
# 2023-09-04 13:39:29,506:INFO:a random identifier for the fold has been generated sngfxcdvxltnwwyy
# 2023-09-04 13:39:29,508:INFO:a random identifier for the fold has been generated jmreucssootjgihs
# 2023-09-04 13:39:29,513:INFO:a random identifier for the fold has been generated tgrbnikmerwwsddj
# 2023-09-04 13:39:29,515:INFO:a random identifier for the fold has been generated omwqgxoedcjmzldc
# 2023-09-04 13:39:29,517:INFO:a random identifier for the fold has been generated kjmousoepulqdtrh
# 2023-09-04 13:39:29,519:INFO:a random identifier for the fold has been generated ceqpuaaymlzipwez
# 2023-09-04 13:39:29,520:INFO:a random identifier for the fold has been generated tecdnzcltutavpay
# 2023-09-04 13:39:29,521:INFO:testing acc, feasible tptn pairs: 2287775398606
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/828a4eab0acb4ab99b3b84a66fa7184e-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/828a4eab0acb4ab99b3b84a66fa7184e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 253 RHS
# At line 260 BOUNDS
# At line 302 ENDATA
# Problem MODEL has 6 rows, 41 columns and 160 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6c2cc88de271493cb05f071461fce23b-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/6c2cc88de271493cb05f071461fce23b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 253 RHS
# At line 260 BOUNDS
# At line 302 ENDATA
# Problem MODEL has 6 rows, 41 columns and 160 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 results = drive_aggregated({'acc': 0.950, 'sens': 0.899, 'spec': 0.9834},
#       2                                 eps=1e-4,
#       3                                 image_set='test')
#
# File ~/workspaces/mlscorecheck/mlscorecheck/bundles/_retina_drive.py:140, in drive_aggregated(scores, eps, image_set, subset, solver_name, timeout, verbosity, numerical_tolerance)
#     130 results_no_fov_mor = drive_aggregated_all_pixels(scores=scores,
#     131                                                 eps=eps,
#     132                                                 aggregation='mor',
#    (...)
#     137                                                 verbosity=verbosity,
#     138                                                 numerical_tolerance=numerical_tolerance)
#     139 logger.info('testing RoM FoV pixels')
# --> 140 results_fov_rom = drive_aggregated_fov_pixels(scores=scores,
#     141                                             eps=eps,
#     142                                             aggregation='rom',
#     143                                             image_set=image_set,
#     144                                             subset=subset,
#     145                                             solver_name=solver_name,
#     146                                             timeout=timeout,
#     147                                             verbosity=verbosity,
#     148                                             numerical_tolerance=numerical_tolerance)
#     149 logger.info('testing RoM all pixels')
#     150 results_no_fov_rom = drive_aggregated_all_pixels(scores=scores,
#     151                                                 eps=eps,
#     152                                                 aggregation='rom',
#    (...)
#     157                                                 verbosity=verbosity,
#     158                                                 numerical_tolerance=numerical_tolerance)
#
# File ~/workspaces/mlscorecheck/mlscorecheck/bundles/_retina_drive.py:252, in drive_aggregated_fov_pixels(scores, eps, aggregation, image_set, subset, solver_name, timeout, verbosity, numerical_tolerance)
#     249 data = load_drive()[f'{image_set}_fov']['datasets']
#     250 data = filter_drive(data, subset)
# --> 252 return _drive_aggregated_test_scores(data,
#     253                                         scores,
#     254                                         eps,
#     255                                         aggregation,
#     256                                         solver_name=solver_name,
#     257                                         timeout=timeout,
#     258                                         verbosity=verbosity,
#     259                                         numerical_tolerance=numerical_tolerance)
#
# File ~/workspaces/mlscorecheck/mlscorecheck/bundles/_retina_drive.py:46, in _drive_aggregated_test_scores(data, scores, eps, aggregation, solver_name, timeout, verbosity, numerical_tolerance)
#      42 if aggregation == 'mor':
#      43     return check_n_datasets_mor_kfold_rom_scores(scores=scores,
#      44                                                     eps=eps,
#      45                                                     datasets=data)
# ---> 46 return check_n_datasets_rom_kfold_rom_scores(scores=scores,
#      47                                             eps=eps,
#      48                                             datasets=data)
#
# File ~/workspaces/mlscorecheck/mlscorecheck/check/_check_n_datasets_rom_kfold_rom_scores.py:140, in check_n_datasets_rom_kfold_rom_scores(scores, eps, datasets, solver_name, timeout, verbosity, numerical_tolerance)
#     137 figures = experiment.calculate_figures()
#     139 # executing the individual tests
# --> 140 ind_results = check_scores_tptn(scores=scores,
#     141                                 eps=eps,
#     142                                 p=figures['p'],
#     143                                 n=figures['n'],
#     144                                 numerical_tolerance=numerical_tolerance)
#     146 result = {'inconsistency': ind_results['inconsistency'],
#     147             'individual_results': ind_results}
#     149 if not experiment.has_downstream_bounds():
#
# File ~/workspaces/mlscorecheck/mlscorecheck/individual/_check_tptn_solutions.py:166, in check_scores_tptn(p, n, scores, eps, numerical_tolerance, solve_for)
#     158     to_iterate = list({pair[idx] for pair in valid_pairs})
#     160 params = {score: score_int,
#     161             'p': p,
#     162             'n': n,
#     163             'beta_plus': scores.get('beta_plus'),
#     164             'beta_minus': scores.get('beta_minus')}
# --> 166 score_pairs = iterate_tptn(to_iterate, sol_fun, params, p+1 if solve_for == 'tp' else n+1, solve_for, iterate_by)
#     168 detail['n_tptn_pairs_before'] = p*n if valid_pairs is None else len(valid_pairs)
#     170 valid_pairs = (score_pairs if valid_pairs is None
#     171                     else valid_pairs.intersection(score_pairs))
#
# File ~/workspaces/mlscorecheck/mlscorecheck/individual/_check_tptn_solutions.py:92, in iterate_tptn(to_iterate, sol_fun, params, upper_bound, solve_for, iterate_by)
#      89 score_pairs = set()
#      91 for value in to_iterate:
# ---> 92     interval = sol_fun(**params, **{iterate_by: value})
#      93     if interval is None:
#      94         continue
#
# File ~/workspaces/mlscorecheck/mlscorecheck/individual/_tptn_solutions.py:215, in acc_tp(tn, p, n, acc, **kwargs)
#     201 def acc_tp(*, tn, p, n, acc, **kwargs):
#     202     """
#     203     Solves tp from the score acc
#     204
#    (...)
#     213         float|Interval|IntervalUnion: the value or interval for tp
#     214     """
# --> 215     return acc*n + acc*p - tn
#
# File ~/workspaces/mlscorecheck/mlscorecheck/individual/_interval.py:144, in Interval.__add__(self, other)
#     140 if not isinstance(other, Interval):
#     141     return Interval(lower_bound=self.lower_bound + other,
#     142                     upper_bound=self.upper_bound + other)
# --> 144 return Interval(lower_bound=self.lower_bound + other.lower_bound,
#     145                 upper_bound=self.upper_bound + other.upper_bound)
#
# File ~/workspaces/mlscorecheck/mlscorecheck/individual/_interval.py:27, in Interval.__init__(self, lower_bound, upper_bound)
#      23 class Interval:
#      24     """
#      25     The interval abstraction
#      26     """
# ---> 27     def __init__(self, lower_bound, upper_bound):
#      28         """
#      29         Constructor of the interval
#      30
#    (...)
#      33             upper_bound (int|float): the upper bound
#      34         """
#      35         self.lower_bound = lower_bound
#
# KeyboardInterrupt:
