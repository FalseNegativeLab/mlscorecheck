# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy.stats import wilcoxon

from mlscorecheck import auc

# %%
data = pd.read_csv('raw-aggregated3.csv')

# %%
data.head()
# Out:
#    Unnamed: 0   dataset  k       acc      sens      spec       auc  best_acc  \
# 0           0      bupa  8  0.678383  0.705000  0.642909  0.730965  0.704413
# 1           1    ecoli1  7  0.857143  0.857143  0.857143  0.955423  0.910714
# 2           2    glass0  9  0.826490  0.840278  0.799603  0.828311  0.836151
# 3           3  vehicle0  2  0.903073  0.893375  0.934848  0.976526  0.931442
# 4           4       crx  4  0.843839  0.812360  0.881757  0.914755  0.856118
#
#    best_sens  best_spec  threshold  best_threshold  best_acc_orig    p    n  \
# 0   0.835000   0.525219   0.579711        0.489203       0.704413  200  145
# 1   0.792208   0.945946   0.229167        0.560225       0.910714   77  259
# 2   0.861111   0.785714   0.672900        0.500000       0.836151  144   70
# 3   0.967559   0.814495   0.764775        0.224935       0.931442  647  199
# 4   0.857241   0.854730   0.546707        0.446358       0.856118  357  296
#
#      n_nodes              classifier  \
# 0  20.750000                     SVC
# 1   9.571429                     SVC
# 2   3.444444  DecisionTreeClassifier
# 3  50.000000                     SVC
# 4  35.500000                     SVC
#
#                                  classifier_params
# 0   {'probability': True, 'C': 0.4603054539689608}
# 1  {'probability': True, 'C': 0.04459933938631211}
# 2              {'max_depth': 8, 'random_state': 5}
# 3   {'probability': True, 'C': 0.0496136065615112}
# 4   {'probability': True, 'C': 0.2982487258875685}

# %%
lower_bounds = ['min', 'rmin', 'amin', 'armin']
upper_bounds = ['max', 'amax', 'maxa']

# %%
def wrapper(func, **kwargs):
    #try:
        return func(**kwargs)[0]
    #except:
    #    return None

# %%
def wrapper_debug(func, **kwargs):
    try:
        #print(kwargs, flush=True)
        return func(**kwargs)[0]
    except Exception as exc:
        return str(exc)

# %%
for lb in lower_bounds:
    data[f'auc_{lb}'] = data.apply(
        lambda row:
        wrapper_debug(auc.auc_lower_from_aggregated,
        scores={
            'acc': row['acc'],
            'sens': row['sens'],
            'spec': row['spec']
        },
        folding={
            'p': row['p'],
            'n': row['n'],
            'n_repeats': 1,
            'n_folds': row['k'],
            'folding': 'stratified_sklearn'
        },
        eps=1e-4,
        lower=lb),
        axis=1
    )

    data[f'auc_{lb}_best'] = data.apply(
        lambda row:
        wrapper_debug(auc.auc_lower_from_aggregated,
        scores={
            'acc': row['best_acc'],
            'sens': row['best_sens'],
            'spec': row['best_spec']
        },
        folding={
            'p': row['p'],
            'n': row['n'],
            'n_repeats': 1,
            'n_folds': row['k'],
            'folding': 'stratified_sklearn'
        },
        eps=1e-4,
        lower=lb),
        axis=1
    )

# %%
for ub in upper_bounds:
    data[f'auc_{ub}'] = data.apply(
        lambda row:
        wrapper_debug(
        auc.auc_upper_from_aggregated,
        scores={
            'acc': row['acc'] if ub != 'maxa' else row['best_acc'],
            'sens': row['sens'] if ub != 'maxa' else row['best_sens'],
            'spec': row['spec'] if ub != 'maxa' else row['best_spec']
        },
        folding={
            'p': row['p'],
            'n': row['n'],
            'n_repeats': 1,
            'n_folds': row['k'],
            'folding': 'stratified_sklearn'
        },
        eps=1e-4,
        upper=ub),
        axis=1
    )
    data[f'auc_{ub}_best'] = data.apply(
        lambda row:
        wrapper_debug(
        auc.auc_upper_from_aggregated,
        scores={
            'acc': row['best_acc'],
            'sens': row['best_sens'],
            'spec': row['best_spec']
        },
        folding={
            'p': row['p'],
            'n': row['n'],
            'n_repeats': 1,
            'n_folds': row['k'],
            'folding': 'stratified_sklearn'
        },
        eps=1e-4,
        upper=ub),
        axis=1
    )

# %%
lower_bounds = ['min', 'rmin']
upper_bounds = ['max', 'rmax']

# %%
for lb in lower_bounds:
    data[f'acc_{lb}'] = data.apply(
        lambda row:
        wrapper_debug(auc.acc_lower_from_aggregated,
        scores={
            'acc': row['acc'],
            'sens': row['sens'],
            'spec': row['spec'],
            'auc': row['auc']
        },
        folding={
            'p': row['p'],
            'n': row['n'],
            'n_repeats': 1,
            'n_folds': row['k'],
            'folding': 'stratified_sklearn'
        },
        eps=1e-4,
        lower=lb),
        axis=1
    )

# %%
for ub in upper_bounds:
    data[f'acc_{ub}'] = data.apply(
        lambda row:
        wrapper_debug(auc.acc_upper_from_aggregated,
        scores={
            'acc': row['acc'],
            'sens': row['sens'],
            'spec': row['spec'],
            'auc': row['auc']
        },
        folding={
            'p': row['p'],
            'n': row['n'],
            'n_repeats': 1,
            'n_folds': row['k'],
            'folding': 'stratified_sklearn'
        },
        eps=1e-4,
        upper=ub),
        axis=1
    )

# %%
lower_bounds = ['min']
upper_bounds = ['max', 'rmax']

# %%
for lb in lower_bounds:
    data[f'max_acc_{lb}'] = data.apply(
        lambda row:
        wrapper_debug(auc.max_acc_lower_from_aggregated,
        scores={
            'acc': row['acc'],
            'sens': row['sens'],
            'spec': row['spec'],
            'auc': row['auc']
        },
        folding={
            'p': row['p'],
            'n': row['n'],
            'n_repeats': 1,
            'n_folds': row['k'],
            'folding': 'stratified_sklearn'
        },
        eps=1e-4,
        lower=lb),
        axis=1
    )

# %%
for ub in upper_bounds:
    data[f'max_acc_{ub}'] = data.apply(
        lambda row:
        wrapper_debug(auc.max_acc_upper_from_aggregated,
        scores={
            'acc': row['acc'],
            'sens': row['sens'],
            'spec': row['spec'],
            'auc': row['auc']
        },
        folding={
            'p': row['p'],
            'n': row['n'],
            'n_repeats': 1,
            'n_folds': row['k'],
            'folding': 'stratified_sklearn'
        },
        eps=1e-4,
        upper=ub),
        axis=1
    )

# %%
data[data['auc'] > 0.999]
# Out:
#       Unnamed: 0           dataset   k       acc      sens  spec       auc  \
# 9              9             iris0   3  1.000000  1.000000   1.0  1.000000
# 11            11  shuttle-c0-vs-c4   5  0.998359  0.998244   1.0  0.999976
# 16            16             iris0   4  1.000000  1.000000   1.0  1.000000
# 25            25  shuttle-c0-vs-c4   3  1.000000  1.000000   1.0  1.000000
# 27            27  shuttle-c0-vs-c4   3  0.998359  0.998240   1.0  0.999986
# ...          ...               ...  ..       ...       ...   ...       ...
# 9977        9977     dermatology-6   3  1.000000  1.000000   1.0  1.000000
# 9981        9981            monk-2   9  0.972222  0.947692   1.0  1.000000
# 9983        9983     dermatology-6  10  1.000000  1.000000   1.0  1.000000
# 9988        9988             iris0   6  1.000000  1.000000   1.0  1.000000
# 9991        9991  shuttle-c0-vs-c4   9  1.000000  1.000000   1.0  1.000000
#
#       best_acc  best_sens  best_spec  ...  auc_amax_best  auc_maxa  \
# 9     1.000000    1.00000        1.0  ...            1.0       1.0
# 11    0.998907    0.99883        1.0  ...            1.0  0.999992
# 16    1.000000    1.00000        1.0  ...            1.0       1.0
# 25    1.000000    1.00000        1.0  ...            1.0       1.0
# 27    0.998359    0.99824        1.0  ...            1.0  0.999981
# ...        ...        ...        ...  ...            ...       ...
# 9977  1.000000    1.00000        1.0  ...            1.0       1.0
# 9981  1.000000    1.00000        1.0  ...            1.0       1.0
# 9983  1.000000    1.00000        1.0  ...            1.0       1.0
# 9988  1.000000    1.00000        1.0  ...            1.0       1.0
# 9991  1.000000    1.00000        1.0  ...            1.0       1.0
#
#       auc_maxa_best                              acc_min  \
# 9               1.0  'float' object is not subscriptable
# 11         0.999992  'float' object is not subscriptable
# 16              1.0  'float' object is not subscriptable
# 25              1.0  'float' object is not subscriptable
# 27         0.999981  'float' object is not subscriptable
# ...             ...                                  ...
# 9977            1.0  'float' object is not subscriptable
# 9981            1.0  'float' object is not subscriptable
# 9983            1.0  'float' object is not subscriptable
# 9988            1.0  'float' object is not subscriptable
# 9991            1.0  'float' object is not subscriptable
#
#                                acc_rmin                              acc_max  \
# 9     invalid index to scalar variable.  'float' object is not subscriptable
# 11    invalid index to scalar variable.  'float' object is not subscriptable
# 16    invalid index to scalar variable.  'float' object is not subscriptable
# 25    invalid index to scalar variable.  'float' object is not subscriptable
# 27    invalid index to scalar variable.  'float' object is not subscriptable
# ...                                 ...                                  ...
# 9977  invalid index to scalar variable.  'float' object is not subscriptable
# 9981  invalid index to scalar variable.  'float' object is not subscriptable
# 9983  invalid index to scalar variable.  'float' object is not subscriptable
# 9988  invalid index to scalar variable.  'float' object is not subscriptable
# 9991  invalid index to scalar variable.  'float' object is not subscriptable
#
#                                acc_rmax                          max_acc_min  \
# 9     invalid index to scalar variable.  'float' object is not subscriptable
# 11    invalid index to scalar variable.    invalid index to scalar variable.
# 16    invalid index to scalar variable.  'float' object is not subscriptable
# 25    invalid index to scalar variable.    invalid index to scalar variable.
# 27    invalid index to scalar variable.    invalid index to scalar variable.
# ...                                 ...                                  ...
# 9977  invalid index to scalar variable.  'float' object is not subscriptable
# 9981  invalid index to scalar variable.  'float' object is not subscriptable
# 9983  invalid index to scalar variable.  'float' object is not subscriptable
# 9988  invalid index to scalar variable.  'float' object is not subscriptable
# 9991  invalid index to scalar variable.    invalid index to scalar variable.
#
#                               max_acc_max                       max_acc_rmax
# 9     'float' object is not subscriptable  invalid index to scalar variable.
# 11    'float' object is not subscriptable  invalid index to scalar variable.
# 16    'float' object is not subscriptable  invalid index to scalar variable.
# 25    'float' object is not subscriptable  invalid index to scalar variable.
# 27    'float' object is not subscriptable  invalid index to scalar variable.
# ...                                   ...                                ...
# 9977  'float' object is not subscriptable  invalid index to scalar variable.
# 9981  'float' object is not subscriptable  invalid index to scalar variable.
# 9983  'float' object is not subscriptable  invalid index to scalar variable.
# 9988  'float' object is not subscriptable  invalid index to scalar variable.
# 9991  'float' object is not subscriptable  invalid index to scalar variable.
#
# [1440 rows x 39 columns]

# %%
data.to_csv('processed-aggregated3.csv', index=False)
