# %% [markdown]
# # All examples used in the README and documentation

# %%
from mlscorecheck.check import check_1_testset_no_kfold_scores

result = check_1_testset_no_kfold_scores(testset={'p': 100, 'n': 200},
                                         scores={'acc': 0.9567, 'sens': 0.8545, 'spec': 0.9734},
                                         eps=1e-4)
result['inconsistency']
# True
# Out:
# 2023-10-21 09:33:42,692:INFO:Use this function if the scores originate from the tp and tn statistics calculated on one test set with no aggregation of any kind.
# 2023-10-21 09:33:42,694:INFO:calling the score check with scores {'acc': 0.9567, 'sens': 0.8545, 'spec': 0.9734}, uncertainty 0.0001, p 100 and n 200
# 2023-10-21 09:33:42,695:INFO:checking the scores {'acc': 0.9567, 'sens': 0.8545, 'spec': 0.9734}
# 2023-10-21 09:33:42,697:INFO:evaluating the tp and tn solution for acc and sens
# 2023-10-21 09:33:42,698:INFO:intervals before: (0, 100), (0, 200)
# 2023-10-21 09:33:42,699:INFO:the tp solutions: (85.4398, 85.46020000000001)
# 2023-10-21 09:33:42,700:INFO:the tn solutions: (201.51919999999993, 201.6008)
# 2023-10-21 09:33:42,701:INFO:intervals after: [(1, 0)], []
# 2023-10-21 09:33:42,702:INFO:evaluating the tp and tn solution for acc and spec
# 2023-10-21 09:33:42,704:INFO:intervals before: [(1, 0)], []
# 2023-10-21 09:33:42,705:INFO:the tp solutions: (92.27899999999991, 92.38099999999997)
# 2023-10-21 09:33:42,706:INFO:the tn solutions: (194.6596, 194.70040000000003)
# 2023-10-21 09:33:42,706:INFO:intervals after: [], []
# 2023-10-21 09:33:42,707:INFO:evaluating the tp and tn solution for sens and spec
# 2023-10-21 09:33:42,708:INFO:intervals before: [], []
# 2023-10-21 09:33:42,709:INFO:the tp solutions: (85.4398, 85.46020000000001)
# 2023-10-21 09:33:42,710:INFO:the tn solutions: (194.6596, 194.70040000000003)
# 2023-10-21 09:33:42,710:INFO:intervals after: [], []
# 2023-10-21 09:33:42,711:INFO:testing acc, feasible tptn pairs: 0
# 2023-10-21 09:33:42,712:INFO:no more feasible tp,tn pairs left
# 2023-10-21 09:33:42,712:INFO:constructing final tp, tn pair set
# 2023-10-21 09:33:42,713:INFO:final number of intervals: 0
# 2023-10-21 09:33:42,714:INFO:final number of pairs: 0
# True

# %% [markdown]
# ## 1 testset no kfold

# %%
from mlscorecheck.check import check_1_testset_no_kfold_scores

testset = {'p': 530, 'n': 902}

scores = {'acc': 0.62, 'sens': 0.22, 'spec': 0.86, 'f1p': 0.3, 'fm': 0.32}

result = check_1_testset_no_kfold_scores(testset=testset,
                                        scores=scores,
                                        eps=1e-2)
result['inconsistency']
# False
# Out:
# 2023-10-21 09:33:59,488:INFO:Use this function if the scores originate from the tp and tn statistics calculated on one test set with no aggregation of any kind.
# 2023-10-21 09:33:59,490:INFO:calling the score check with scores {'acc': 0.62, 'sens': 0.22, 'spec': 0.86, 'f1p': 0.3, 'fm': 0.32}, uncertainty 0.01, p 530 and n 902
# 2023-10-21 09:33:59,493:INFO:checking the scores {'acc': 0.62, 'sens': 0.22, 'spec': 0.86, 'f1p': 0.3, 'fm': 0.32}
# 2023-10-21 09:33:59,495:INFO:evaluating the tp and tn solution for acc and sens
# 2023-10-21 09:33:59,498:INFO:intervals before: (0, 530), (0, 902)
# 2023-10-21 09:33:59,500:INFO:the tp solutions: (111.29894, 121.90106)
# 2023-10-21 09:33:59,503:INFO:the tn solutions: (751.6160759999999, 790.8639240000001)
# 2023-10-21 09:33:59,507:INFO:intervals after: [(112, 121)], [(752, 790)]
# 2023-10-21 09:33:59,509:INFO:evaluating the tp and tn solution for acc and spec
# 2023-10-21 09:33:59,511:INFO:intervals before: [(112, 121)], [(752, 790)]
# 2023-10-21 09:33:59,518:INFO:the tp solutions: (88.77533199999993, 135.4646680000002)
# 2023-10-21 09:33:59,520:INFO:the tn solutions: (766.6981959999999, 784.741804)
# 2023-10-21 09:33:59,523:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,525:INFO:evaluating the tp and tn solution for acc and f1p
# 2023-10-21 09:33:59,528:INFO:intervals before: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,529:INFO:the tp solutions: (108.20512460931658, 125.45746857652338)
# 2023-10-21 09:33:59,531:INFO:the tn solutions: (720.729741489652, 822.9954069390577)
# 2023-10-21 09:33:59,533:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,535:INFO:evaluating the tp and tn solution for acc and fm
# 2023-10-21 09:33:59,539:INFO:intervals before: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,541:INFO:the tp solutions: (-16.316815204318672, 3.5854769758786067) | (101.7831884021151, 128.25349360431866)
# 2023-10-21 09:33:59,544:INFO:the tn solutions: (745.2636423956811, 800.379675597885) | (866.6502819978749, 921.7663152000788)
# 2023-10-21 09:33:59,554:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,559:INFO:evaluating the tp and tn solution for sens and spec
# 2023-10-21 09:33:59,562:INFO:intervals before: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,565:INFO:the tp solutions: (111.29894, 121.90106)
# 2023-10-21 09:33:59,567:INFO:the tn solutions: (766.6981959999999, 784.741804)
# 2023-10-21 09:33:59,569:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,570:INFO:evaluating the tp and tn solution for sens and f1p
# 2023-10-21 09:33:59,578:INFO:intervals before: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,583:INFO:the tp solutions: (111.29894, 121.90106)
# 2023-10-21 09:33:59,586:INFO:the tn solutions: (657.2586176931766, 893.5046324530509)
# 2023-10-21 09:33:59,587:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,589:INFO:evaluating the tp and tn solution for sens and fm
# 2023-10-21 09:33:59,591:INFO:intervals before: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,597:INFO:the tp solutions: (111.29894, 121.90106)
# 2023-10-21 09:33:59,601:INFO:the tn solutions: (636.7166535970434, 917.0942703288408)
# 2023-10-21 09:33:59,604:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,606:INFO:evaluating the tp and tn solution for spec and f1p
# 2023-10-21 09:33:59,608:INFO:intervals before: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,610:INFO:the tp solutions: (109.76804841374923, 122.0385407814731)
# 2023-10-21 09:33:59,611:INFO:the tn solutions: (766.6981959999999, 784.741804)
# 2023-10-21 09:33:59,613:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,615:INFO:evaluating the tp and tn solution for spec and fm
# 2023-10-21 09:33:59,619:INFO:intervals before: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,621:INFO:the tp solutions: (-65.8536328094769, -54.25856650052427) | (106.83422730052428, 121.82197200947691)
# 2023-10-21 09:33:59,623:INFO:the tn solutions: (766.6981959999999, 784.741804)
# 2023-10-21 09:33:59,625:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,626:INFO:evaluating the tp and tn solution for f1p and fm
# 2023-10-21 09:33:59,636:INFO:intervals before: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,638:INFO:the tp solutions: (80.82924045095699, 294.0107283921828)
# 2023-10-21 09:33:59,657:INFO:the tn solutions: (-420.04420024360695, 1292.9374484676016)
# 2023-10-21 09:33:59,660:INFO:intervals after: [(112, 121)], [(767, 784)]
# 2023-10-21 09:33:59,662:INFO:testing acc, feasible tptn pairs: 10
# 2023-10-21 09:33:59,666:INFO:testing sens, feasible tptn pairs: 10
# 2023-10-21 09:33:59,668:INFO:testing spec, feasible tptn pairs: 10
# 2023-10-21 09:33:59,674:INFO:testing f1p, feasible tptn pairs: 10
# 2023-10-21 09:33:59,677:INFO:testing fm, feasible tptn pairs: 10
# 2023-10-21 09:33:59,681:INFO:constructing final tp, tn pair set
# 2023-10-21 09:33:59,682:INFO:final number of intervals: 10
# 2023-10-21 09:33:59,685:INFO:final number of pairs: 130
# False

# %%
scores = {'acc': 0.92, 'sens': 0.22, 'spec': 0.86, 'f1p': 0.3, 'fm': 0.32}

result = check_1_testset_no_kfold_scores(testset=testset,
                                        scores=scores,
                                        eps=1e-2)
result['inconsistency']
# True
# Out:
# 2023-10-21 09:34:03,215:INFO:Use this function if the scores originate from the tp and tn statistics calculated on one test set with no aggregation of any kind.
# 2023-10-21 09:34:03,217:INFO:calling the score check with scores {'acc': 0.92, 'sens': 0.22, 'spec': 0.86, 'f1p': 0.3, 'fm': 0.32}, uncertainty 0.01, p 530 and n 902
# 2023-10-21 09:34:03,219:INFO:checking the scores {'acc': 0.92, 'sens': 0.22, 'spec': 0.86, 'f1p': 0.3, 'fm': 0.32}
# 2023-10-21 09:34:03,220:INFO:evaluating the tp and tn solution for acc and sens
# 2023-10-21 09:34:03,222:INFO:intervals before: (0, 530), (0, 902)
# 2023-10-21 09:34:03,222:INFO:the tp solutions: (111.29894, 121.90106)
# 2023-10-21 09:34:03,223:INFO:the tn solutions: (1181.216076, 1220.4639240000004)
# 2023-10-21 09:34:03,224:INFO:intervals after: [(112, 121)], []
# 2023-10-21 09:34:03,225:INFO:evaluating the tp and tn solution for acc and spec
# 2023-10-21 09:34:03,226:INFO:intervals before: [(112, 121)], []
# 2023-10-21 09:34:03,227:INFO:the tp solutions: (518.3753319999998, 565.0646680000003)
# 2023-10-21 09:34:03,227:INFO:the tn solutions: (766.6981959999999, 784.741804)
# 2023-10-21 09:34:03,228:INFO:intervals after: [], []
# 2023-10-21 09:34:03,229:INFO:evaluating the tp and tn solution for acc and f1p
# 2023-10-21 09:34:03,231:INFO:intervals before: [], []
# 2023-10-21 09:34:03,232:INFO:the tp solutions: (20.470765551173063, 28.952218416378013)
# 2023-10-21 09:34:03,232:INFO:the tn solutions: (1232.0122032291965, 1355.3280073234066)
# 2023-10-21 09:34:03,233:INFO:intervals after: [], []
# 2023-10-21 09:34:03,234:INFO:evaluating the tp and tn solution for acc and fm
# 2023-10-21 09:34:03,235:INFO:all negative bases - iteration finished
# 2023-10-21 09:34:03,236:INFO:testing acc, feasible tptn pairs: 0
# 2023-10-21 09:34:03,237:INFO:no more feasible tp,tn pairs left
# 2023-10-21 09:34:03,237:INFO:constructing final tp, tn pair set
# 2023-10-21 09:34:03,238:INFO:final number of intervals: 0
# 2023-10-21 09:34:03,239:INFO:final number of pairs: 0
# True

# %% [markdown]
# ## 1 dataset with k-fold, mean-of-scores (MoS)

# %%
from mlscorecheck.check import check_1_dataset_known_folds_mos_scores

dataset = {'p': 126, 'n': 131}
folding = {'folds': [{'p': 52, 'n': 94}, {'p': 74, 'n': 37}]}

scores = {'acc': 0.573, 'sens': 0.768, 'bacc': 0.662}

result = check_1_dataset_known_folds_mos_scores(dataset=dataset,
                                                folding=folding,
                                                scores=scores,
                                                eps=1e-3)
result['inconsistency']
# False
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/da79c68b6f7b4735a9ffe1fbc6bbf933-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/da79c68b6f7b4735a9ffe1fbc6bbf933-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 4 columns (4 integer (0 of which binary)) and 10 elements
# Cbc0012I Integer solution of 0 found by DiveCoefficient after 97 iterations and 0 nodes (0.01 seconds)
# Cbc0031I 3 added rows had average density of 3.3333333
# Cbc0013I At root node, 3 cuts changed objective from 0 to 0 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 178 row cuts average 3.9 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 5 row cuts average 2.4 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 0, took 97 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 100 times and created 178 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 100 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               97
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
# False

# %%
scores = {'acc': 0.573, 'sens': 0.568, 'bacc': 0.662}
result = check_1_dataset_known_folds_mos_scores(dataset=dataset,
                                                folding=folding,
                                                scores=scores,
                                                eps=1e-3)
result['inconsistency']
# True
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3ba384b6ae0544d68f84994cb910e430-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/3ba384b6ae0544d68f84994cb910e430-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 3 rows, 4 columns (4 integer (0 of which binary)) and 10 elements
# Cbc0031I 2 added rows had average density of 4
# Cbc0013I At root node, 2 cuts changed objective from 0 to 0 in 28 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 45 row cuts average 3.6 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 12 row cuts average 2.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 0 (0.00 seconds)
# Cbc0001I Search completed - best objective 1e+50, took 77 iterations and 4 nodes (0.01 seconds)
# Cbc0032I Strong branching done 16 times (23 iterations), fathomed 3 nodes and fixed 1 variables
# Cbc0035I Maximum depth 1, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 28 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 28 times and created 45 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 28 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               4
# Total iterations:               77
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
# True

# %%
dataset = {'dataset_name': 'common_datasets.glass_0_1_6_vs_2'}
folding = {'n_folds': 4, 'n_repeats': 2, 'strategy': 'stratified_sklearn'}

scores = {'acc': 0.9, 'spec': 0.9, 'sens': 0.6, 'bacc': 0.1, 'f1': 0.95}

result = check_1_dataset_known_folds_mos_scores(dataset=dataset,
                                                folding=folding,
                                                fold_score_bounds={'acc': (0.8, 1.0)},
                                                scores=scores,
                                                eps=1e-2,
                                                numerical_tolerance=1e-6)
result['inconsistency']
# True
# Out:
# 2023-10-21 09:34:39,566:INFO:common_datasets.glass_0_1_6_vs_2_kpj_0_0: adding lower bound 0.8 for acc
# 2023-10-21 09:34:39,568:INFO:common_datasets.glass_0_1_6_vs_2_kpj_0_0: adding upper bound 1.0 for acc
# 2023-10-21 09:34:39,569:INFO:common_datasets.glass_0_1_6_vs_2_kpj_0_1: adding lower bound 0.8 for acc
# 2023-10-21 09:34:39,569:INFO:common_datasets.glass_0_1_6_vs_2_kpj_0_1: adding upper bound 1.0 for acc
# 2023-10-21 09:34:39,570:INFO:common_datasets.glass_0_1_6_vs_2_kpj_0_2: adding lower bound 0.8 for acc
# 2023-10-21 09:34:39,571:INFO:common_datasets.glass_0_1_6_vs_2_kpj_0_2: adding upper bound 1.0 for acc
# 2023-10-21 09:34:39,572:INFO:common_datasets.glass_0_1_6_vs_2_kpj_0_3: adding lower bound 0.8 for acc
# 2023-10-21 09:34:39,572:INFO:common_datasets.glass_0_1_6_vs_2_kpj_0_3: adding upper bound 1.0 for acc
# 2023-10-21 09:34:39,573:INFO:common_datasets.glass_0_1_6_vs_2_kpj_1_0: adding lower bound 0.8 for acc
# 2023-10-21 09:34:39,574:INFO:common_datasets.glass_0_1_6_vs_2_kpj_1_0: adding upper bound 1.0 for acc
# 2023-10-21 09:34:39,574:INFO:common_datasets.glass_0_1_6_vs_2_kpj_1_1: adding lower bound 0.8 for acc
# 2023-10-21 09:34:39,575:INFO:common_datasets.glass_0_1_6_vs_2_kpj_1_1: adding upper bound 1.0 for acc
# 2023-10-21 09:34:39,576:INFO:common_datasets.glass_0_1_6_vs_2_kpj_1_2: adding lower bound 0.8 for acc
# 2023-10-21 09:34:39,577:INFO:common_datasets.glass_0_1_6_vs_2_kpj_1_2: adding upper bound 1.0 for acc
# 2023-10-21 09:34:39,577:INFO:common_datasets.glass_0_1_6_vs_2_kpj_1_3: adding lower bound 0.8 for acc
# 2023-10-21 09:34:39,578:INFO:common_datasets.glass_0_1_6_vs_2_kpj_1_3: adding upper bound 1.0 for acc
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cd4494dba8a94d05bc0ad8858d9cff69-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/cd4494dba8a94d05bc0ad8858d9cff69-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 29 COLUMNS
# At line 191 RHS
# At line 216 BOUNDS
# At line 234 ENDATA
# Problem MODEL has 24 rows, 17 columns and 128 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# True

# %% [markdown]
# ## 1 dataset with kfold ratio-of-means (SoM)

# %%
from mlscorecheck.check import check_1_dataset_som_scores

dataset = {'dataset_name': 'common_datasets.monk-2'}
folding = {'n_folds': 4, 'n_repeats': 3, 'strategy': 'stratified_sklearn'}

scores = {'spec': 0.668, 'npv': 0.744, 'ppv': 0.667,
            'bacc': 0.706, 'f1p': 0.703, 'fm': 0.704}

result = check_1_dataset_som_scores(dataset=dataset,
                                    folding=folding,
                                    scores=scores,
                                    eps=1e-3)
result['inconsistency']
# False
# Out:
# 2023-10-21 09:35:35,466:INFO:testing spec, feasible tptn pairs: 613
# 2023-10-21 09:35:35,472:INFO:testing bacc, feasible tptn pairs: 613
# 2023-10-21 09:35:35,510:INFO:testing npv, feasible tptn pairs: 2
# 2023-10-21 09:35:35,513:INFO:testing ppv, feasible tptn pairs: 1
# 2023-10-21 09:35:35,514:INFO:testing f1p, feasible tptn pairs: 1
# 2023-10-21 09:35:35,515:INFO:testing fm, feasible tptn pairs: 1
# 2023-10-21 09:35:35,517:INFO:constructing final tp, tn pair set
# 2023-10-21 09:35:35,519:INFO:final number of intervals: 1
# 2023-10-21 09:35:35,521:INFO:final number of pairs: 1
# False

# %%
scores = {'spec': 0.668, 'npv': 0.754, 'ppv': 0.667,
        'bacc': 0.706, 'f1p': 0.703, 'fm': 0.704}

result = check_1_dataset_som_scores(dataset=dataset,
                                    folding=folding,
                                    scores=scores,
                                    eps=1e-3)
result['inconsistency']
# True
# Out:
# 2023-10-21 09:36:06,701:INFO:testing spec, feasible tptn pairs: 613
# 2023-10-21 09:36:06,705:INFO:testing bacc, feasible tptn pairs: 613
# 2023-10-21 09:36:06,718:INFO:testing npv, feasible tptn pairs: 2
# 2023-10-21 09:36:06,720:INFO:no more feasible tp,tn pairs left
# 2023-10-21 09:36:06,720:INFO:constructing final tp, tn pair set
# 2023-10-21 09:36:06,721:INFO:final number of intervals: 0
# 2023-10-21 09:36:06,722:INFO:final number of pairs: 0
# True

# %% [markdown]
# ## N datasets with k-folds, SoM over datasets and SoM over folds

# %%
from mlscorecheck.check import check_n_datasets_som_kfold_som_scores

evaluation0 = {'dataset': {'p': 389, 'n': 630},
                'folding': {'n_folds': 5, 'n_repeats': 2,
                            'strategy': 'stratified_sklearn'}}
evaluation1 = {'dataset': {'dataset_name': 'common_datasets.saheart'},
                'folding': {'n_folds': 5, 'n_repeats': 2,
                            'strategy': 'stratified_sklearn'}}
evaluations = [evaluation0, evaluation1]

scores = {'acc': 0.631, 'sens': 0.341, 'spec': 0.802, 'f1p': 0.406, 'fm': 0.414}

result = check_n_datasets_som_kfold_som_scores(scores=scores,
                                                evaluations=evaluations,
                                                eps=1e-3)
result['inconsistency']
# False
# Out:
# 2023-10-21 09:38:28,527:INFO:testing acc, feasible tptn pairs: 1099
# 2023-10-21 09:38:28,555:INFO:testing sens, feasible tptn pairs: 1097
# 2023-10-21 09:38:28,556:INFO:testing spec, feasible tptn pairs: 2
# 2023-10-21 09:38:28,558:INFO:testing f1p, feasible tptn pairs: 2
# 2023-10-21 09:38:28,559:INFO:testing fm, feasible tptn pairs: 2
# 2023-10-21 09:38:28,560:INFO:constructing final tp, tn pair set
# 2023-10-21 09:38:28,561:INFO:final number of intervals: 2
# 2023-10-21 09:38:28,563:INFO:final number of pairs: 4
# False

# %%
scores = {'acc': 0.731, 'sens': 0.341, 'spec': 0.802, 'f1p': 0.406, 'fm': 0.414}

result = check_n_datasets_som_kfold_som_scores(scores=scores,
                                                evaluations=evaluations,
                                                eps=1e-3)
result['inconsistency']
# True
# Out:
# 2023-10-21 09:38:33,779:INFO:testing acc, feasible tptn pairs: 1099
# 2023-10-21 09:38:33,805:INFO:testing sens, feasible tptn pairs: 801
# 2023-10-21 09:38:33,806:INFO:testing spec, feasible tptn pairs: 2
# 2023-10-21 09:38:33,807:INFO:no more feasible tp,tn pairs left
# 2023-10-21 09:38:33,808:INFO:constructing final tp, tn pair set
# 2023-10-21 09:38:33,809:INFO:final number of intervals: 0
# 2023-10-21 09:38:33,810:INFO:final number of pairs: 0
# True

# %% [markdown]
# ## N datasets with k-folds, MoS over datasets and SoM over folds

# %%
from mlscorecheck.check import check_n_datasets_mos_kfold_som_scores

evaluation0 = {'dataset': {'p': 39, 'n': 822},
                'folding': {'n_folds': 5, 'n_repeats': 3,
                            'strategy': 'stratified_sklearn'}}
evaluation1 = {'dataset': {'dataset_name': 'common_datasets.winequality-white-3_vs_7'},
                'folding': {'n_folds': 5, 'n_repeats': 3,
                            'strategy': 'stratified_sklearn'}}
evaluations = [evaluation0, evaluation1]

scores = {'acc': 0.312, 'sens': 0.45, 'spec': 0.312, 'bacc': 0.381}

result = check_n_datasets_mos_kfold_som_scores(evaluations=evaluations,
                                                dataset_score_bounds={'acc': (0.0, 0.5)},
                                                eps=1e-4,
                                                scores=scores)
result['inconsistency']
# False
# Out:
# 2023-10-21 09:38:55,027:INFO:somkf: adding lower bound 0.0 for acc
# 2023-10-21 09:38:55,028:INFO:somkf: adding upper bound 0.5 for acc
# 2023-10-21 09:38:55,029:INFO:common_datasets.winequality-white-3_vs_7_gcr: adding lower bound 0.0 for acc
# 2023-10-21 09:38:55,029:INFO:common_datasets.winequality-white-3_vs_7_gcr: adding upper bound 0.5 for acc
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/62cacdf79aac4b57b3a9bf8c43b43092-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/62cacdf79aac4b57b3a9bf8c43b43092-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 59 RHS
# At line 72 BOUNDS
# At line 78 ENDATA
# Problem MODEL has 12 rows, 5 columns and 32 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 6 rows, 4 columns (4 integer (0 of which binary)) and 16 elements
# Cbc0012I Integer solution of 0 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# False

# %%
scores = {'acc': 0.412, 'sens': 0.45, 'spec': 0.312, 'bacc': 0.381}
result = check_n_datasets_mos_kfold_som_scores(evaluations=evaluations,
                                                dataset_score_bounds={'acc': (0.5, 1.0)},
                                                eps=1e-4,
                                                scores=scores)
result['inconsistency']
# True
# Out:
# 2023-10-21 09:38:59,786:INFO:gpaqw: adding lower bound 0.5 for acc
# 2023-10-21 09:38:59,788:INFO:gpaqw: adding upper bound 1.0 for acc
# 2023-10-21 09:38:59,790:INFO:common_datasets.winequality-white-3_vs_7_kqi: adding lower bound 0.5 for acc
# 2023-10-21 09:38:59,791:INFO:common_datasets.winequality-white-3_vs_7_kqi: adding upper bound 1.0 for acc
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3032de59459c4abcba7ff401d95f2da3-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/3032de59459c4abcba7ff401d95f2da3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 17 COLUMNS
# At line 59 RHS
# At line 72 BOUNDS
# At line 78 ENDATA
# Problem MODEL has 12 rows, 5 columns and 32 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# True

# %% [markdown]
# ## N datasets with k-folds, MoS over datasets and MoS over folds

# %%
from mlscorecheck.check import check_n_datasets_mos_known_folds_mos_scores

evaluation0 = {'dataset': {'p': 118, 'n': 95},
                'folding': {'folds': [{'p': 22, 'n': 23}, {'p': 96, 'n': 72}]}}
evaluation1 = {'dataset': {'p': 781, 'n': 423},
                'folding': {'folds': [{'p': 300, 'n': 200}, {'p': 481, 'n': 223}]}}
evaluations = [evaluation0, evaluation1]

scores = {'acc': 0.61, 'sens': 0.709, 'spec': 0.461, 'bacc': 0.585}

result = check_n_datasets_mos_known_folds_mos_scores(evaluations=evaluations,
                                                    scores=scores,
                                                    eps=1e-3)
result['inconsistency']
# False
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1526735dcd114cc8a22ada4fcda7e06c-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/1526735dcd114cc8a22ada4fcda7e06c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 79 RHS
# At line 88 BOUNDS
# At line 98 ENDATA
# Problem MODEL has 8 rows, 9 columns and 48 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 8 columns (8 integer (0 of which binary)) and 24 elements
# Cbc0012I Integer solution of 0 found by DiveCoefficient after 0 iterations and 0 nodes (0.00 seconds)
# Cbc0001I Search completed - best objective 0, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# False

# %%
scores = {'acc': 0.71, 'sens': 0.709, 'spec': 0.461}

result = check_n_datasets_mos_known_folds_mos_scores(evaluations=evaluations,
                                                    scores=scores,
                                                    eps=1e-3)
result['inconsistency']
# True
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/986b4c799de44992807d8336dc882d6a-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/986b4c799de44992807d8336dc882d6a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 61 RHS
# At line 68 BOUNDS
# At line 78 ENDATA
# Problem MODEL has 6 rows, 9 columns and 32 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# True

# %% [markdown]
# ## Not knowing the k-folding scheme

# %%
from mlscorecheck.check import check_1_dataset_unknown_folds_mos_scores

dataset = {'p': 126, 'n': 131}
folding = {'n_folds': 2, 'n_repeats': 1}

scores = {'acc': 0.573, 'sens': 0.768, 'bacc': 0.662}

result = check_1_dataset_unknown_folds_mos_scores(dataset=dataset,
                                                    folding=folding,
                                                    scores=scores,
                                                    eps=1e-3)
result['inconsistency']
# False
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/52903a97b8aa440e9afba88361017fa4-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/52903a97b8aa440e9afba88361017fa4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 2 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/439496451084437d8ccf3d40f8f05021-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/439496451084437d8ccf3d40f8f05021-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6561e4e0713c4ea299aaf2958ea1b34d-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/6561e4e0713c4ea299aaf2958ea1b34d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 4 columns (4 integer (0 of which binary)) and 10 elements
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b0a208be0c244bd38c2c270d13a2db28-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/b0a208be0c244bd38c2c270d13a2db28-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 2 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/910ef8d6f48c4bc9bc1733f1f97af3d2-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/910ef8d6f48c4bc9bc1733f1f97af3d2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 2 fixed, 12 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 0 rows, 0 columns (0 integer (0 of which binary)) and 0 elements
# Cbc3007W No integer variables - nothing to do
# Cuts at root node changed objective from 0 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               0
# Total iterations:               3
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# False

# %%
scores = {'acc': 0.573, 'sens': 0.768, 'bacc': 0.862}

result = check_1_dataset_unknown_folds_mos_scores(dataset=dataset,
                                                    folding=folding,
                                                    scores=scores,
                                                    eps=1e-3)
result['inconsistency']
# True
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c37dc2ae666d4f70b79707e8aa839126-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/c37dc2ae666d4f70b79707e8aa839126-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2f919d8752024e22a8d53c9d7bb681e3-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/2f919d8752024e22a8d53c9d7bb681e3-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4ca69c107fd94822a0c5fe6968f41d2c-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/4ca69c107fd94822a0c5fe6968f41d2c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6a845417e60942eeab4e3853704fb84b-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/6a845417e60942eeab4e3853704fb84b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d72deed369b9460b91e735fc678aa2dd-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/d72deed369b9460b91e735fc678aa2dd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/93160507f1c3403ca60ea3e8a8581187-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/93160507f1c3403ca60ea3e8a8581187-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5e90bbbdb67a4464b68e53ef3c81df74-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/5e90bbbdb67a4464b68e53ef3c81df74-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/58b90ed05c234878966be66bb247b14f-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/58b90ed05c234878966be66bb247b14f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/2a2271d7507242e190c892cde31cc1ec-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/2a2271d7507242e190c892cde31cc1ec-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/86b2bfba07f94c95bf13783744b69fd4-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/86b2bfba07f94c95bf13783744b69fd4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1cd9cb6527564699b9ca2baca240e928-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/1cd9cb6527564699b9ca2baca240e928-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3f02b4ea2d75448cada4d9e7244f46e4-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/3f02b4ea2d75448cada4d9e7244f46e4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/df9bd48a0964404fa481bb4d13a012ce-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/df9bd48a0964404fa481bb4d13a012ce-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c732388d88704e968b2116d995cb48a7-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/c732388d88704e968b2116d995cb48a7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp
pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 41 RHS
# At line 48 BOUNDS
# At line 54 ENDATA
# Problem MODEL has 6 rows, 5 columns and 20 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# True

# %%
from mlscorecheck.check import check_n_datasets_mos_unknown_folds_mos_scores

evaluation0 = {'dataset': {'p': 13, 'n': 73},
                'folding': {'n_folds': 4, 'n_repeats': 1}}
evaluation1 = {'dataset': {'p': 7, 'n': 26},
                'folding': {'n_folds': 3, 'n_repeats': 1}}
evaluations = [evaluation0, evaluation1]

scores = {'acc': 0.357, 'sens': 0.323, 'spec': 0.362, 'bacc': 0.343}

result = check_n_datasets_mos_unknown_folds_mos_scores(evaluations=evaluations,
                                                        scores=scores,
                                                        eps=1e-3)
result['inconsistency']
# False
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ae0a6e54d8504c25a4f24c0cbc59bbb4-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/ae0a6e54d8504c25a4f24c0cbc59bbb4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 10 columns (10 integer (2 of which binary)) and 30 elements
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 6 added rows had average density of 2.8333333
# Cbc0013I At root node, 6 cuts changed objective from 0 to 0 in 26 passes
# Cbc0014I Cut generator 0 (Probing) - 10 row cuts average 1.8 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 114 row cuts average 8.4 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 3 row cuts average 2.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 30 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 35 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 132 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 26 times and created 13 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 25 times and created 114 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 25 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 25 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 25 times and created 30 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 25 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 25 times and created 35 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               132
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/870cde2313544baaaca83673f49c4e79-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/870cde2313544baaaca83673f49c4e79-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (2 of which binary)) and 36 elements
# Cbc0031I 3 added rows had average density of 7.3333333
# Cbc0013I At root node, 30 cuts changed objective from 0 to 0 in 28 passes
# Cbc0014I Cut generator 0 (Probing) - 7 row cuts average 3.6 elements, 1 column cuts (1 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 136 row cuts average 8.4 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 31 row cuts average 7.3 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 50 row cuts average 5.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 147 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 28 times and created 8 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 28 times and created 136 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 28 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 28 times and created 50 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               147
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e1373d0ff234486c8d3669a3cab74ab7-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/e1373d0ff234486c8d3669a3cab74ab7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 10 columns (10 integer (2 of which binary)) and 30 elements
# Cbc0031I 5 added rows had average density of 7.8
# Cbc0013I At root node, 5 cuts changed objective from 0 to 0 in 30 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 71 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 30 row cuts average 5.9 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 29 row cuts average 5.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 0 (0.01 seconds)
# Cbc0016I Integer solution of 0 found by strong branching after 182 iterations and 32 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective 0, took 182 iterations and 32 nodes (0.02 seconds)
# Cbc0032I Strong branching done 96 times (198 iterations), fathomed 7 nodes and fixed 6 variables
# Cbc0035I Maximum depth 17, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 30 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 30 times and created 71 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 30 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 30 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 30 times and created 30 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 30 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 30 times and created 29 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               32
# Total iterations:               182
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.02
# False

# %%
scores = {'acc': 0.357, 'sens': 0.323, 'spec': 0.362, 'bacc': 0.9}

result = check_n_datasets_mos_unknown_folds_mos_scores(evaluations=evaluations,
                                                        scores=scores,
                                                        eps=1e-3)
result['inconsistency']
# True
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3be7be26f2f54e9193e43d291947e6c9-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/3be7be26f2f54e9193e43d291947e6c9-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/36be4562154f4973b3db30599223485c-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/36be4562154f4973b3db30599223485c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/b327de5ab73545e2b68e58b7630bec2b-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/b327de5ab73545e2b68e58b7630bec2b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3eb38c685eaf4961a0467418b53fbce4-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/3eb38c685eaf4961a0467418b53fbce4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp
-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/91adfae373214c978265323e770ea6a2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8fe210e95ade4f0eae6cd4d6fe99d413-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/8fe210e95ade4f0eae6cd4d6fe99d413-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/61fa692abcab46f589fdcd8e04913026-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/61fa692abcab46f589fdcd8e04913026-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7a1885a447a74f58bc4d966bdd14febe-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/7a1885a447a74f58bc4d966bdd14febe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/004342ea76a540fda7baccf03941ce91-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/004342ea76a540fda7baccf03941ce91-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/420b0a702b484538b3c41626b3f469c2-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/420b0a702b484538b3c41626b3f469c2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7ca13fc06ff5449c90431623c85e3007-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/7ca13fc06ff5449c90431623c85e3007-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8756ec57382f48c8b65bd0cfd50b9a73-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/8756ec57382f48c8b65bd0cfd50b9a73-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ededf7d18eea449580aac3cf2bcc9618-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/ededf7d18eea449580aac3cf2bcc9618-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/592ac180bc0c4a7d9989bb2d16fe5759-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/592ac180bc0c4a7d9989bb2d16fe5759-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4dcff0856b7148ebb995c29070515f1b-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/4dcff0856b7148ebb995c29070515f1b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ff6c5d27c2fc417abbb1a093aa9997b7-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/ff6c5d27c2fc417abbb1a093aa9997b7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# True

# %% [markdown]
# ## Test bundles

# %%
from mlscorecheck.bundles import (drive_image, drive_aggregated)

drive_image(scores={'acc': 0.9478, 'npv': 0.8532, 'f1p': 0.9801, 'ppv': 0.8543},
            eps=1e-4,
            image_set='test',
            identifier='01')
# {'fov_inconsistency': True, 'no_fov_inconsistency': True}
# Out:
# 2023-10-21 09:43:10,368:INFO:Use this function if the scores originate from the tp and tn statistics calculated on one test set with no aggregation of any kind.
# 2023-10-21 09:43:10,369:INFO:calling the score check with scores {'acc': 0.9478, 'npv': 0.8532, 'f1p': 0.9801, 'ppv': 0.8543}, uncertainty 0.0001, p 29412 and n 194965
# 2023-10-21 09:43:10,370:INFO:checking the scores {'acc': 0.9478, 'npv': 0.8532, 'f1p': 0.9801, 'ppv': 0.8543}
# 2023-10-21 09:43:10,370:INFO:evaluating the tp and tn solution for acc and npv
# 2023-10-21 09:43:10,371:INFO:intervals before: (0, 29412), (0, 194965)
# 2023-10-21 09:43:10,372:INFO:the tp solutions: (-8768.013230485234, -8573.01389180878)
# 2023-10-21 09:43:10,372:INFO:the tn solutions: (221217.02457201527, 221453.0688222425)
# 2023-10-21 09:43:10,373:INFO:intervals after: [], []
# 2023-10-21 09:43:10,373:INFO:evaluating the tp and tn solution for acc and f1p
# 2023-10-21 09:43:10,374:INFO:intervals before: [], []
# 2023-10-21 09:43:10,375:INFO:the tp solutions: (286365.8061167398, 290509.87677600095)
# 2023-10-21 09:43:10,375:INFO:the tn solutions: (-79001.35445865653, -72557.07723756711)
# 2023-10-21 09:43:10,378:INFO:intervals after: [], []
# 2023-10-21 09:43:10,379:INFO:evaluating the tp and tn solution for acc and ppv
# 2023-10-21 09:43:10,380:INFO:intervals before: [], []
# 2023-10-21 09:43:10,381:INFO:the tp solutions: (21302.56817716164, 21375.13485642454)
# 2023-10-21 09:43:10,381:INFO:the tn solutions: (191152.08805289588, 191499.38416613272)
# 2023-10-21 09:43:10,382:INFO:intervals after: [], []
# 2023-10-21 09:43:10,411:INFO:intervals after: [], []
# 2023-10-21 09:43:10,411:INFO:evaluating the tp and tn solution for npv and f1p
# 2023-10-21 09:43:10,412:INFO:intervals before: [], []
# 2023-10-21 09:43:10,414:INFO:the tp solutions: (-33363.98344042302, -33222.699582527835)
# 2023-10-21 09:43:10,415:INFO:the tn solutions: (364353.7321007062, 364857.06806710316)
# 2023-10-21 09:43:10,416:INFO:intervals after: [], []
# 2023-10-21 09:43:10,417:INFO:evaluating the tp and tn solution for npv and ppv
# 2023-10-21 09:43:10,418:INFO:intervals before: [], []
# 2023-10-21 09:43:10,418:INFO:the tp solutions: (-22990.083705854206, -22890.098292212304)
# 2023-10-21 09:43:10,419:INFO:the tn solutions: (304267.6967759173, 304597.2199558656)
# 2023-10-21 09:43:10,420:INFO:intervals after: [], []
# 2023-10-21 09:43:10,420:INFO:evaluating the tp and tn solution for f1p and ppv
# 2023-10-21 09:43:10,422:INFO:intervals before: [], []
# 2023-10-21 09:43:10,423:INFO:the tp solutions: (33815.01667442605, 33858.565174343326)
# 2023-10-21 09:43:10,424:INFO:the tn solutions: (294487.56053383433, 295011.0025742671)
# 2023-10-21 09:43:10,424:INFO:intervals after: [], []
# 2023-10-21 09:43:10,425:INFO:testing acc, feasible tptn pairs: 0
# 2023-10-21 09:43:10,426:INFO:no more feasible tp,tn pairs left
# 2023-10-21 09:43:10,427:INFO:constructing final tp, tn pair set
# 2023-10-21 09:43:10,427:INFO:final number of intervals: 0
# 2023-10-21 09:43:10,428:INFO:final number of pairs: 0
# {'fov_pixels_inconsistency': True, 'all_pixels_inconsistency': True}

# %%
drive_aggregated(scores={'acc': 0.9478, 'sens': 0.8532, 'spec': 0.9801},
                eps=1e-4,
                image_set='test')
# {'mos_fov_inconsistency': True,
#   'mos_no_fov_inconsistency': True,
#   'som_fov_inconsistency': True,
#   'som_no_fov_inconsistency': True}
# Out:
# 2023-10-21 09:45:21,372:INFO:testing MoS FoV pixels
# 2023-10-21 09:45:21,385:INFO:testing MoS all pixels
# 2023-10-21 09:45:21,398:INFO:testing SoM FoV pixels
# 2023-10-21 09:45:21,452:INFO:testing acc, feasible tptn pairs: 577650
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/48ad339a473d439d8baacf2cbc8ca095-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/48ad339a473d439d8baacf2cbc8ca095-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 253 RHS
# At line 260 BOUNDS
# At line 302 ENDATA
# Problem MODEL has 6 rows, 41 columns and 160 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/76380c5d03cb4e3896d6844df2a93718-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/76380c5d03cb4e3896d6844df2a93718-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 253 RHS
# At line 260 BOUNDS
# At line 302 ENDATA
# Problem MODEL has 6 rows, 41 columns and 160 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# 2023-10-21 09:45:34,020:INFO:testing sens, feasible tptn pairs: 237351
# 2023-10-21 09:45:34,062:INFO:testing spec, feasible tptn pairs: 117
# 2023-10-21 09:45:34,063:INFO:no more feasible tp,tn pairs left
# 2023-10-21 09:45:34,064:INFO:constructing final tp, tn pair set
# 2023-10-21 09:45:34,064:INFO:final number of intervals: 0
# 2023-10-21 09:45:34,065:INFO:final number of pairs: 0
# 2023-10-21 09:45:34,066:INFO:testing SoM all pixels
# 2023-10-21 09:45:34,101:INFO:testing acc, feasible tptn pairs: 577946
# 2023-10-21 09:45:44,069:INFO:testing sens, feasible tptn pairs: 345146
# 2023-10-21 09:45:44,139:INFO:testing spec, feasible tptn pairs: 117
# 2023-10-21 09:45:44,140:INFO:no more feasible tp,tn pairs left
# 2023-10-21 09:45:44,140:INFO:constructing final tp, tn pair set
# 2023-10-21 09:45:44,141:INFO:final number of intervals: 0
# 2023-10-21 09:45:44,142:INFO:final number of pairs: 0
# {'mos_fov_pixels_inconsistency': True,
#  'mos_all_pixels_inconsistency': True,
#  'som_fov_pixels_inconsistency': True,
#  'som_all_pixels_inconsistency': True}

# %%
from mlscorecheck.bundles import check_ehg

scores = {'acc': 0.9552, 'sens': 0.9351, 'spec': 0.9713}

results = check_ehg(scores=scores, eps=10**(-4), n_folds=10, n_repeats=1)
results['inconsistency']
# True
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/02b2564ca6a640dcb1329900b428620b-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/02b2564ca6a640dcb1329900b428620b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0da70219ca344815b70f93de9b168ce6-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/0da70219ca344815b70f93de9b168ce6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 3 rows, 4 columns (4 integer (1 of which binary)) and 8 elements
# 1 infeasibilities
# Problem is infeasible!
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d14cebbfd93d4e45a5dbd3d7a150c8af-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/d14cebbfd93d4e45a5dbd3d7a150c8af-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9d4f5babd7fb489f943e2e1557f54c72-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/9d4f5babd7fb489f943e2e1557f54c72-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 2 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0f9ec5583d5e423b88b3f2a658bd7f83-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/0f9ec5583d5e423b88b3f2a658bd7f83-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 5 columns (5 integer (0 of which binary)) and 10 elements
# 1 infeasibilities
# Problem is infeasible!
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/4b625872a87a4767bab477a6842b83aa-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/4b625872a87a4767bab477a6842b83aa-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 5 columns (5 integer (0 of which binary)) and 10 elements
# 1 infeasibilities
# Problem is infeasible!
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e673946d44ad45eebba3562c975a7c57-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/e673946d44ad45eebba3562c975a7c57-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 1 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/acde824a9815428f972e35c27bf1a0ab-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/acde824a9815428f972e35c27bf1a0ab-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/1f827e28e5e043b49ad3a575fd79c477-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/1f827e28e5e043b49ad3a575fd79c477-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/59d26a97ac5b4191a025e0066f58b020-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/59d26a97ac5b4191a025e0066f58b020-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 5 columns (5 integer (0 of which binary)) and 10 elements
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 1 added rows had average density of 5
# Cbc0013I At root node, 1 cuts changed objective from 0 to 0 in 3 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 6 row cuts average 3.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 7 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 14 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 3 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               14
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5eea235b733b44e2b7e4c7433b77614d-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/5eea235b733b44e2b7e4c7433b77614d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 5 columns (5 integer (0 of which binary)) and 10 elements
# 1 infeasibilities
# Problem is infeasible!
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9809d18a1c6e45e1898ab0f47c8fbe5e-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/9809d18a1c6e45e1898ab0f47c8fbe5e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 5 columns (5 integer (0 of which binary)) and 10 elements
# 1 infeasibilities
# Problem is infeasible!
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d8750d450f8040d28c9f8753f5940ff4-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/d8750d450f8040d28c9f8753f5940ff4-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/45c27702acd5490992ef654ff8059f4e-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/45c27702acd5490992ef654ff8059f4e-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 0 fixed, 6 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 2 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 9 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 2 fixed, 1 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/66e2b8323e474035977c9bdef53cce3f-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/66e2b8323e474035977c9bdef53cce3f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e63b03f496c948f89891e523162ab32a-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/e63b03f496c948f89891e523162ab32a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 2 fixed, 8 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 5 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/95576e0eddee4eb09a86ca0bdb60c4cd-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/95576e0eddee4eb09a86ca0bdb60c4cd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 3 rows, 7 columns (7 integer (0 of which binary)) and 14 elements
# Cbc0038I Initial state - 3 integers unsatisfied sum - 0.52684
# Cbc0038I Pass   1: suminf.    0.52684 (3) obj. 0 iterations 0
# Cbc0038I P
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# ...
# Cgl0003I 1 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 6 columns (6 integer (0 of which binary)) and 12 elements
# 1 infeasibilities
# Problem is infeasible!
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9ece73646f594351813e5232ab6404f2-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/9ece73646f594351813e5232ab6404f2-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 3 rows, 9 columns (9 integer (0 of which binary)) and 18 elements
# Cbc0031I 2 added rows had average density of 4
# Cbc0013I At root node, 5 cuts changed objective from 0 to 0 in 28 passes
# Cbc0014I Cut generator 0 (Probing) - 2 row cuts average 2.5 elements, 2 column cuts (2 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 90 row cuts average 5.1 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 20 row cuts average 4.7 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 115 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 28 times and created 4 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 28 times and created 90 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Knapsack was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 28 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 28 times and created 20 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               115
# Time (CPU seconds):             0.01
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.01   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/98a0fccac5d740e6abb07dd040277ead-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/98a0fccac5d740e6abb07dd040277ead-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 3 rows, 5 columns (5 integer (0 of which binary)) and 10 elements
# 1 infeasibilities
# Problem is infeasible!
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/152b715c5fac48cbbd3af09bc382127b-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/152b715c5fac48cbbd3af09bc382127b-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 2 fixed, 3 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 1 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 7 columns (7 integer (0 of which binary)) and 14 elements
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cuts at root node changed objective from 1.79769e+308 to -1.79769e+308
# Probing was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Linear relaxation infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/66603e5d9d8a482b8d0f2aaa00937add-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/66603e5d9d8a482b8d0f2aaa00937add-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 3 fixed, 7 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 2 rows, 5 columns (5 integer (0 of which binary)) and 10 elements
# Cbc0031I 1 added rows had average density of 4
# Cbc0013I At root node, 7 cuts changed objective from 0 to 0 in 2 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 5 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 5 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 4 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 2 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 2 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 2 times and created 5 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               4
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/f5bafc3cb2914d14a2fa0d7827ca1357-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/f5bafc3cb2914d14a2fa0d7827ca1357-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 4 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0000I Cut generators found to be infeasible! (or unbounded)
# Pre-processing says infeasible or unbounded
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ba2c5877b12b4e509d0f496250baa566-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/ba2c5877b12b4e509d0f496250baa566-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 2 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 7 columns (7 integer (0 of which binary)) and 14 elements
# 1 infeasibilities
# Problem is infeasible!
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/c09352d0f10c4b6ca79b8ed1c7ea890c-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/c09352d0f10c4b6ca79b8ed1c7ea890c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 11 COLUMNS
# At line 133 RHS
# At line 140 BOUNDS
# At line 162 ENDATA
# Problem MODEL has 6 rows, 21 columns and 80 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0003I 1 fixed, 0 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0003I 0 fixed, 4 tightened bounds, 0 strengthened rows, 0 substitutions
# Cgl0004I processed model has 3 rows, 8 columns (8 integer (0 of which binary)) and 16 elements
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0013I At root node, 0 cuts changed objective from 0 to 0 in 1 passes
# Cbc0014I Cut generator 0 (Probing) - 1 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 7 (ZeroHalf) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 0 iterations and 0 nodes (0.00 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 1 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 0 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               0
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.00
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
