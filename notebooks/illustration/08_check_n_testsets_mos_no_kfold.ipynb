# %%
from mlscorecheck.check import check_n_testsets_mos_no_kfold_scores

# %%
testsets = [{'p': 349, 'n': 50},
  {'p': 478, 'n': 323},
  {'p': 324, 'n': 83},
  {'p': 123, 'n': 145}]

scores = {'acc': 0.6441, 'sens': 0.6706, 'spec': 0.3796, 'bacc': 0.5251}

# %%
check_n_testsets_mos_no_kfold_scores(testsets=testsets,
                                        scores=scores,
                                        eps=0.0001)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/98606e9f0fd341aeae56db1c519f5213-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/98606e9f0fd341aeae56db1c519f5213-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 79 RHS
# At line 88 BOUNDS
# At line 98 ENDATA
# Problem MODEL has 8 rows, 9 columns and 48 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 8 columns (8 integer (0 of which binary)) and 24 elements
# Cbc0031I 4 added rows had average density of 5.75
# Cbc0013I At root node, 4 cuts changed objective from 0 to 0 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 165 row cuts average 7.6 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 3 row cuts average 4.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 12 row cuts average 5.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 0 (0.01 seconds)
# Cbc0012I Integer solution of 0 found by DiveCoefficient after 82 iterations and 4 nodes (0.02 seconds)
# Cbc0001I Search completed - best objective 0, took 82 iterations and 4 nodes (0.02 seconds)
# Cbc0032I Strong branching done 32 times (56 iterations), fathomed 0 nodes and fixed 4 variables
# Cbc0035I Maximum depth 4, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 100 times and created 165 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 3 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 100 times and created 12 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               4
# Total iterations:               82
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
# {'inconsistency': False,
#  'lp_scores': {'acc': 0.6441101931819913,
#   'sens': 0.6706799398461988,
#   'spec': 0.3795947320830241,
#   'bacc': 0.5251373359646114},
#  'lp_status': 'feasible',
#  'lp_configuration_scores_match': True,
#  'lp_configuration_bounds_match': True,
#  'lp_configuration': {'evaluations': [{'folds': {'folds': [{'fold': {'p': 349,
#         'n': 50,
#         'identifier': 'geefs',
#         'tp': 115.0,
#         'tn': 0.0},
#        'scores': {'acc': 0.2882205513784461,
#         'sens': 0.32951289398280803,
#         'spec': 0.0,
#         'bacc': 0.16475644699140402},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True},
#     'scores': {'acc': 0.2882205513784461,
#      'sens': 0.32951289398280803,
#      'spec': 0.0,
#      'bacc': 0.16475644699140402},
#     'score_bounds': None,
#     'bounds_flag': {'folds': [{'fold': {'p': 349,
#         'n': 50,
#         'identifier': 'geefs',
#         'tp': 115.0,
#         'tn': 0.0},
#        'scores': {'acc': 0.2882205513784461,
#         'sens': 0.32951289398280803,
#         'spec': 0.0,
#         'bacc': 0.16475644699140402},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True}},
#    {'folds': {'folds': [{'fold': {'p': 478,
#         'n': 323,
#         'identifier': 'ucndh',
#         'tp': 478.0,
#         'tn': 168.0},
#        'scores': {'acc': 0.8064918851435705,
#         'sens': 0.9999999999999999,
#         'spec': 0.5201238390092879,
#         'bacc': 0.7600619195046439},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True},
#     'scores': {'acc': 0.8064918851435705,
#      'sens': 0.9999999999999999,
#      'spec': 0.5201238390092879,
#      'bacc': 0.7600619195046439},
#     'score_bounds': None,
#     'bounds_flag': {'folds': [{'fold': {'p': 478,
#         'n': 323,
#         'identifier': 'ucndh',
#         'tp': 478.0,
#         'tn': 168.0},
#        'scores': {'acc': 0.8064918851435705,
#         'sens': 0.9999999999999999,
#         'spec': 0.5201238390092879,
#         'bacc': 0.7600619195046439},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True}},
#    {'folds': {'folds': [{'fold': {'p': 324,
#         'n': 83,
#         'identifier': 'gxqct',
#         'tp': 312.0,
#         'tn': 1.0},
#        'scores': {'acc': 0.769041769041769,
#         'sens': 0.9629629629629629,
#         'spec': 0.012048192771084338,
#         'bacc': 0.48750557786702364},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True},
#     'scores': {'acc': 0.769041769041769,
#      'sens': 0.9629629629629629,
#      'spec': 0.012048192771084338,
#      'bacc': 0.48750557786702364},
#     'score_bounds': None,
#     'bounds_flag': {'folds': [{'fold': {'p': 324,
#         'n': 83,
#         'identifier': 'gxqct',
#         'tp': 312.0,
#         'tn': 1.0},
#        'scores': {'acc': 0.769041769041769,
#         'sens': 0.9629629629629629,
#         'spec': 0.012048192771084338,
#         'bacc': 0.48750557786702364},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True}},
#    {'folds': {'folds': [{'fold': {'p': 123,
#         'n': 145,
#         'identifier': 'cvdze',
#         'tp': 48.0,
#         'tn': 143.0},
#        'scores': {'acc': 0.7126865671641791,
#         'sens': 0.3902439024390244,
#         'spec': 0.9862068965517241,
#         'bacc': 0.6882253994953742},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True},
#     'scores': {'acc': 0.7126865671641791,
#      'sens': 0.3902439024390244,
#      'spec': 0.9862068965517241,
#      'bacc': 0.6882253994953742},
#     'score_bounds': None,
#     'bounds_flag': {'folds': [{'fold': {'p': 123,
#         'n': 145,
#         'identifier': 'cvdze',
#         'tp': 48.0,
#         'tn': 143.0},
#        'scores': {'acc': 0.7126865671641791,
#         'sens': 0.3902439024390244,
#         'spec': 0.9862068965517241,
#         'bacc': 0.6882253994953742},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True}}],
#   'bounds_flag': True}}

# %%
scores['sens'] = 0.6756

# %%
check_n_testsets_mos_no_kfold_scores(testsets=testsets,
                                        scores=scores,
                                        eps=0.0001)
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/663d57a774334ee098ba47024362725a-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/663d57a774334ee098ba47024362725a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 79 RHS
# At line 88 BOUNDS
# At line 98 ENDATA
# Problem MODEL has 8 rows, 9 columns and 48 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
# {'inconsistency': True,
#  'lp_status': 'infeasible',
#  'lp_configuration': {'evaluations': [{'folds': {'folds': [{'fold': {'p': 349,
#         'n': 50,
#         'identifier': 'pejcy',
#         'tp': 244.9966,
#         'tn': 30.326935},
#        'scores': {'acc': 0.6900339223057643,
#         'sens': 0.701995988538682,
#         'spec': 0.6065387,
#         'bacc': 0.654267344269341},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True},
#     'scores': {'acc': 0.6900339223057643,
#      'sens': 0.701995988538682,
#      'spec': 0.6065387,
#      'bacc': 0.654267344269341},
#     'score_bounds': None,
#     'bounds_flag': {'folds': [{'fold': {'p': 349,
#         'n': 50,
#         'identifier': 'pejcy',
#         'tp': 244.9966,
#         'tn': 30.326935},
#        'scores': {'acc': 0.6900339223057643,
#         'sens': 0.701995988538682,
#         'spec': 0.6065387,
#         'bacc': 0.654267344269341},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True}},
#    {'folds': {'folds': [{'fold': {'p': 478,
#         'n': 323,
#         'identifier': 'qaiul',
#         'tp': 478.0,
#         'tn': 0.0},
#        'scores': {'acc': 0.5967540574282147,
#         'sens': 0.9999999999999999,
#         'spec': 0.0,
#         'bacc': 0.49999999999999994},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True},
#     'scores': {'acc': 0.5967540574282147,
#      'sens': 0.9999999999999999,
#      'spec': 0.0,
#      'bacc': 0.49999999999999994},
#     'score_bounds': None,
#     'bounds_flag': {'folds': [{'fold': {'p': 478,
#         'n': 323,
#         'identifier': 'qaiul',
#         'tp': 478.0,
#         'tn': 0.0},
#        'scores': {'acc': 0.5967540574282147,
#         'sens': 0.9999999999999999,
#         'spec': 0.0,
#         'bacc': 0.49999999999999994},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True}},
#    {'folds': {'folds': [{'fold': {'p': 324,
#         'n': 83,
#         'identifier': 'izbfg',
#         'tp': 324.0,
#         'tn': 0.0},
#        'scores': {'acc': 0.7960687960687961,
#         'sens': 1.0,
#         'spec': 0.0,
#         'bacc': 0.5},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True},
#     'scores': {'acc': 0.7960687960687961,
#      'sens': 1.0,
#      'spec': 0.0,
#      'bacc': 0.5},
#     'score_bounds': None,
#     'bounds_flag': {'folds': [{'fold': {'p': 324,
#         'n': 83,
#         'identifier': 'izbfg',
#         'tp': 324.0,
#         'tn': 0.0},
#        'scores': {'acc': 0.7960687960687961,
#         'sens': 1.0,
#         'spec': 0.0,
#         'bacc': 0.5},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True}},
#    {'folds': {'folds': [{'fold': {'p': 123,
#         'n': 145,
#         'identifier': 'idkpe',
#         'tp': 0.0,
#         'tn': 132.16131},
#        'scores': {'acc': 0.49313921641791036,
#         'sens': 0.0,
#         'spec': 0.9114573103448275,
#         'bacc': 0.45572865517241373},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True},
#     'scores': {'acc': 0.49313921641791036,
#      'sens': 0.0,
#      'spec': 0.9114573103448275,
#      'bacc': 0.45572865517241373},
#     'score_bounds': None,
#     'bounds_flag': {'folds': [{'fold': {'p': 123,
#         'n': 145,
#         'identifier': 'idkpe',
#         'tp': 0.0,
#         'tn': 132.16131},
#        'scores': {'acc': 0.49313921641791036,
#         'sens': 0.0,
#         'spec': 0.9114573103448275,
#         'bacc': 0.45572865517241373},
#        'score_bounds': None,
#        'bounds_flag': True}],
#      'bounds_flag': True}}],
#   'bounds_flag': True}}
