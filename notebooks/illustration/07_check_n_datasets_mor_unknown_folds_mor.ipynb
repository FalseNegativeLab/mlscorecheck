# %%
import numpy as np

from mlscorecheck.check import check_n_datasets_mos_unknown_folds_mos_scores
from mlscorecheck.aggregated import generate_experiment, experiment_kfolds_generator

# %%
def generate_test_case(random_seed, rounding_decimals):
    """
    Generate one random test case

    Args:
        random_seed (int): the random seed to use
        rounding_decimals (int): the number of decimals to round to
    """
    evaluation_params = {'max_p': 25,
                        'max_n': 200,
                        'max_folds': 4,
                        'max_repeats': 1,
                        'aggregation': 'mos',
                        'no_folds': True,
                        'no_name': True}

    random_state = np.random.RandomState(random_seed)
    experiment, scores = generate_experiment(random_state=random_state,
                                                rounding_decimals=rounding_decimals,
                                                evaluation_params=evaluation_params,
                                                max_evaluations=2,
                                                aggregation='mos',
                                                return_scores=True)

    n_configurations = experiment_kfolds_generator(experiment,
                                                    available_scores=list(scores.keys()))

    while n_configurations > 1000\
        or len(experiment['evaluations']) == 1:
        experiment, scores = generate_experiment(random_state=random_state,
                                                rounding_decimals=rounding_decimals,
                                                evaluation_params=evaluation_params,
                                                max_evaluations=2,
                                                aggregation='mos',
                                                return_scores=True)

        n_configurations = experiment_kfolds_generator(experiment,
                                                    available_scores=list(scores.keys()))
    return experiment, scores

# %%
experiment, scores = generate_test_case(random_seed=1, rounding_decimals=3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb Cell 3 line 1
# ----> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=0'>1</a> experiment, scores = generate_test_case(random_seed=1, rounding_decimals=3)
#
# /home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb Cell 3 line 2
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=17'>18</a> experiment, scores = generate_experiment(random_state=random_state,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=18'>19</a>                                             rounding_decimals=rounding_decimals,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=19'>20</a>                                             evaluation_params=evaluation_params,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=20'>21</a>                                             max_evaluations=2,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=21'>22</a>                                             aggregation='mos',
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=22'>23</a>                                             return_scores=True)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=24'>25</a> n_configurations = experiment_kfolds_generator(experiment,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=25'>26</a>                                                 available_scores=list(scores.keys()))
# ---> <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=27'>28</a> while n_configurations > 1000\
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=28'>29</a>     or len(experiment['evaluations']) == 1:
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=29'>30</a>     experiment, scores = generate_experiment(random_state=random_state,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=30'>31</a>                                             rounding_decimals=rounding_decimals,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=31'>32</a>                                             evaluation_params=evaluation_params,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=32'>33</a>                                             max_evaluations=2,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=33'>34</a>                                             aggregation='mos',
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=34'>35</a>                                             return_scores=True)
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=36'>37</a>     n_configurations = experiment_kfolds_generator(experiment,
#      <a href='vscode-notebook-cell://wsl%2Bubuntu-20.04/home/gykovacs/workspaces/mlscorecheck/notebooks/illustration/07_check_n_datasets_mor_unknown_folds_mor.ipynb#W2sdnNjb2RlLXJlbW90ZQ%3D%3D?line=37'>38</a>                                                 available_scores=list(scores.keys()))
#
# TypeError: '>' not supported between instances of 'generator' and 'int'

# %%
evaluation0 = {'dataset': {'p': 13, 'n': 73},
                'folding': {'n_folds': 4, 'n_repeats': 1}}
evaluation1 = {'dataset': {'p': 7, 'n': 26},
                'folding': {'n_folds': 3, 'n_repeats': 1}}
evaluations = [evaluation0, evaluation1]
scores = {'acc': 0.357, 'sens': 0.323, 'spec': 0.362, 'bacc': 0.343}

result = check_n_datasets_mos_unknown_folds_mos_scores(evaluations=evaluations,
                                                        scores=scores,
                                                        eps=1e-3)
result['inconsistency']
# Out:
# [<generator object kfolds_generator at 0x7fe3fde0d150>]
# [<generator object kfolds_generator at 0x7fe460679e00>]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/00083cf78ce4496091eec0307b75f208-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/00083cf78ce4496091eec0307b75f208-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 10 columns (10 integer (2 of which binary)) and 30 elements
# Cbc0031I 3 added rows had average density of 7.3333333
# Cbc0013I At root node, 19 cuts changed objective from 0 to 0 in 66 passes
# Cbc0014I Cut generator 0 (Probing) - 28 row cuts average 2.4 elements, 1 column cuts (1 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 356 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 31 row cuts average 5.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 87 row cuts average 4.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 395 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 66 times and created 29 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 66 times and created 356 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 66 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 66 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 66 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 66 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 66 times and created 87 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               395
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bd1670644b0a4034a78629fb4a8a5a73-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/bd1670644b0a4034a78629fb4a8a5a73-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (2 of which binary)) and 36 elements
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 1 added rows had average density of 2
# Cbc0013I At root node, 1 cuts changed objective from 0 to 0 in 54 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 1.0 elements, 3 column cuts (3 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 208 row cuts average 10.2 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 85 row cuts average 8.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 83 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 256 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 54 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 53 times and created 208 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 53 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Clique was tried 53 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 53 times and created 85 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 53 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 53 times and created 83 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               256
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cd7ba5d5d87f4ed9ae09c44a32d3187c-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/cd7ba5d5d87f4ed9ae09c44a32d3187c-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 10 columns (10 integer (2 of which binary)) and 30 elements
# Cbc0031I 3 added rows had average density of 5
# Cbc0013I At root node, 3 cuts changed objective from 0 to 0 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 6 row cuts average 4.7 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 288 row cuts average 9.4 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 39 row cuts average 6.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 55 row cuts average 5.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 0 (0.02 seconds)
# Cbc0016I Integer solution of 0 found by strong branching after 462 iterations and 41 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective 0, took 462 iterations and 41 nodes (0.03 seconds)
# Cbc0032I Strong branching done 168 times (374 iterations), fathomed 12 nodes and fixed 8 variables
# Cbc0035I Maximum depth 10, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 100 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Gomory was tried 100 times and created 288 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 100 times and created 55 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               41
# Total iterations:               462
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
# False

# %%
evaluation0 = {'dataset': {'p': 13, 'n': 73},
                'folding': {'n_folds': 4, 'n_repeats': 1}}
evaluation1 = {'dataset': {'p': 7, 'n': 26},
                'folding': {'n_folds': 3, 'n_repeats': 1}}
evaluations = [evaluation0, evaluation1]
scores = {'acc': 0.357, 'sens': 0.323, 'spec': 0.362, 'bacc': 0.9}

result = check_n_datasets_mos_unknown_folds_mos_scores(evaluations=evaluations,
                                                        scores=scores,
                                                        eps=1e-3)
result['inconsistency']
# Out:
# [<generator object kfolds_generator at 0x7fe3fde0e340>]
# [<generator object kfolds_generator at 0x7fe3fde0e340>]
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/8c6d0ded38a849f8a35ce2a7a93b2287-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/8c6d0ded38a849f8a35ce2a7a93b2287-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/379d5fab5d0f4924b5454ecf9c3424dd-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/379d5fab5d0f4924b5454ecf9c3424dd-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0adc25305cba4c5fa4c5925e93ab8410-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/0adc25305cba4c5fa4c5925e93ab8410-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ab93ae3ec4194181a28bae337b5599d7-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/ab93ae3ec4194181a28bae337b5599d7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bedd4453f93046c5b1f9a77351ab51e7-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/bedd4453f93046c5b1f9a77351ab51e7-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/72fb651ad1cc4161ab7aa27b5bb411c1-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/72fb651ad1cc4161ab7aa27b5bb411c1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/e20aac9fada94f2696d55ec43ec77a14-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/e20aac9fada94f2696d55ec43ec77a14-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/7cda6aac38c5403ba3ecfd84228444ab-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/7cda6aac38c5403ba3ecfd84228444ab-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/5cc80ea4474148c8b29cec0b2a47eb37-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/5cc80ea4474148c8b29cec0b2a47eb37-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/