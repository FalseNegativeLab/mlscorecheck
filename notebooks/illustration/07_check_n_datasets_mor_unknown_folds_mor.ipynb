# %%
import numpy as np

from mlscorecheck.check import check_n_datasets_mor_unknown_folds_mor_scores
from mlscorecheck.aggregated import generate_experiment, generate_experiments_with_all_kfolds

# %%
def generate_test_case(random_seed, rounding_decimals):
    """
    Generate one random test case

    Args:
        random_seed (int): the random seed to use
        rounding_decimals (int): the number of decimals to round to
    """
    evaluation_params = {'max_p': 25,
                        'max_n': 200,
                        'max_folds': 4,
                        'max_repeats': 1,
                        'aggregation': 'mor',
                        'no_folds': True,
                        'no_name': True}

    random_state = np.random.RandomState(random_seed)
    experiment, scores = generate_experiment(random_state=random_state,
                                                rounding_decimals=rounding_decimals,
                                                evaluation_params=evaluation_params,
                                                max_evaluations=2,
                                                aggregation='mor',
                                                return_scores=True)

    while len(generate_experiments_with_all_kfolds(experiment)) > 1000\
        or len(experiment['evaluations']) == 1:
        experiment, scores = generate_experiment(random_state=random_state,
                                                rounding_decimals=rounding_decimals,
                                                evaluation_params=evaluation_params,
                                                max_evaluations=2,
                                                aggregation='mor',
                                                return_scores=True)
    return experiment, scores

# %%
experiment, scores = generate_test_case(random_seed=1, rounding_decimals=3)

# %%
evaluation0 = {'dataset': {'p': 13, 'n': 73},
                'folding': {'n_folds': 4, 'n_repeats': 1, 
                            'strategy': 'stratified_sklearn'}}
evaluation1 = {'dataset': {'p': 7, 'n': 26},
                'folding': {'n_folds': 3, 'n_repeats': 1, 
                            'strategy': 'stratified_sklearn'}}
experiment = {'evaluations': [evaluation0, evaluation1]}

scores = {'acc': 0.357, 'sens': 0.323, 'spec': 0.362, 'bacc': 0.343}

# %%
result = check_n_datasets_mor_unknown_folds_mor_scores(experiment=experiment,
                                                        scores=scores,
                                                        eps=1e-3)
result['inconsistency']
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/178da28509214fb59be8f1a04cdf4fbe-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/178da28509214fb59be8f1a04cdf4fbe-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 10 columns (10 integer (2 of which binary)) and 30 elements
# Cbc0031I 3 added rows had average density of 7.3333333
# Cbc0013I At root node, 19 cuts changed objective from 0 to 0 in 66 passes
# Cbc0014I Cut generator 0 (Probing) - 28 row cuts average 2.4 elements, 1 column cuts (1 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 356 row cuts average 9.0 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 31 row cuts average 5.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 87 row cuts average 4.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 395 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 66 times and created 29 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 66 times and created 356 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 66 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 66 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 66 times and created 31 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 66 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 66 times and created 87 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               395
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/3e7bf442f08b416e9bde3a3128501716-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/3e7bf442f08b416e9bde3a3128501716-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (2 of which binary)) and 36 elements
# Cbc0006I The LP relaxation is infeasible or too expensive
# Cbc0031I 1 added rows had average density of 2
# Cbc0013I At root node, 1 cuts changed objective from 0 to 0 in 54 passes
# Cbc0014I Cut generator 0 (Probing) - 4 row cuts average 1.0 elements, 3 column cuts (3 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 1 (Gomory) - 208 row cuts average 10.2 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 85 row cuts average 8.5 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is 1
# Cbc0014I Cut generator 5 (FlowCover) - 1 row cuts average 3.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 83 row cuts average 6.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 256 iterations and 0 nodes (0.01 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 54 times and created 7 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Gomory was tried 53 times and created 208 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Knapsack was tried 53 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# Clique was tried 53 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 53 times and created 85 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# FlowCover was tried 53 times and created 1 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# TwoMirCuts was tried 53 times and created 83 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               256
# Time (CPU seconds):             0.00
# Time (Wallclock seconds):       0.01
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.01
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/42d8ed9009ec47f2ba1e5a31b069035d-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/42d8ed9009ec47f2ba1e5a31b069035d-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 12 columns (12 integer (2 of which binary)) and 36 elements
# Cbc0031I 6 added rows had average density of 4.6666667
# Cbc0013I At root node, 19 cuts changed objective from 0 to 0 in 67 passes
# Cbc0014I Cut generator 0 (Probing) - 9 row cuts average 4.6 elements, 1 column cuts (1 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 282 row cuts average 10.7 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 82 row cuts average 8.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 86 row cuts average 5.9 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0001I Search completed - best objective 1e+50, took 306 iterations and 0 nodes (0.02 seconds)
# Cbc0035I Maximum depth 0, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 67 times and created 10 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 67 times and created 282 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 67 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 67 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 67 times and created 82 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 67 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 67 times and created 86 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Problem proven infeasible
#
# No feasible solution found
# Enumerated nodes:               0
# Total iterations:               306
# Time (CPU seconds):             0.02
# Time (Wallclock seconds):       0.02
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.02   (Wallclock seconds):       0.02
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/95e84cc17dc74e3f91a9e3b315aed0a6-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/95e84cc17dc74e3f91a9e3b315aed0a6-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Continuous objective value is 0 - 0.00 seconds
# Cgl0004I processed model has 4 rows, 10 columns (10 integer (2 of which binary)) and 30 elements
# Cbc0031I 3 added rows had average density of 5
# Cbc0013I At root node, 3 cuts changed objective from 0 to 0 in 100 passes
# Cbc0014I Cut generator 0 (Probing) - 6 row cuts average 4.7 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 1 (Gomory) - 288 row cuts average 9.4 elements, 0 column cuts (0 active)  in 0.002 seconds - new frequency is -100
# Cbc0014I Cut generator 2 (Knapsack) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 3 (Clique) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.000 seconds - new frequency is -100
# Cbc0014I Cut generator 4 (MixedIntegerRounding2) - 39 row cuts average 6.3 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 5 (FlowCover) - 0 row cuts average 0.0 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0014I Cut generator 6 (TwoMirCuts) - 55 row cuts average 5.5 elements, 0 column cuts (0 active)  in 0.001 seconds - new frequency is -100
# Cbc0010I After 0 nodes, 1 on tree, 1e+50 best solution, best possible 0 (0.02 seconds)
# Cbc0016I Integer solution of 0 found by strong branching after 462 iterations and 41 nodes (0.03 seconds)
# Cbc0001I Search completed - best objective 0, took 462 iterations and 41 nodes (0.03 seconds)
# Cbc0032I Strong branching done 168 times (374 iterations), fathomed 12 nodes and fixed 8 variables
# Cbc0035I Maximum depth 10, 0 variables fixed on reduced cost
# Cuts at root node changed objective from 0 to 0
# Probing was tried 100 times and created 6 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Gomory was tried 100 times and created 288 cuts of which 0 were active after adding rounds of cuts (0.002 seconds)
# Knapsack was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# Clique was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
# MixedIntegerRounding2 was tried 100 times and created 39 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# FlowCover was tried 100 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# TwoMirCuts was tried 100 times and created 55 cuts of which 0 were active after adding rounds of cuts (0.001 seconds)
# ZeroHalf was tried 1 times and created 0 cuts of which 0 were active after adding rounds of cuts (0.000 seconds)
#
# Result - Optimal solution found
#
# Objective value:                0.00000000
# Enumerated nodes:               41
# Total iterations:               462
# Time (CPU seconds):             0.03
# Time (Wallclock seconds):       0.03
#
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.03   (Wallclock seconds):       0.03
# False

# %%
evaluation0 = {'dataset': {'p': 13, 'n': 73},
                'folding': {'n_folds': 4, 'n_repeats': 1, 
                            'strategy': 'stratified_sklearn'}}
evaluation1 = {'dataset': {'p': 7, 'n': 26},
                'folding': {'n_folds': 3, 'n_repeats': 1, 
                            'strategy': 'stratified_sklearn'}}
experiment = {'evaluations': [evaluation0, evaluation1]}

scores = {'acc': 0.357, 'sens': 0.323, 'spec': 0.362, 'bacc': 0.9}

# %%
result = check_n_datasets_mor_unknown_folds_mor_scores(experiment=experiment,
                                                        scores=scores,
                                                        eps=1e-3)
result['inconsistency']
# Out:
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/0a74136a53ff4c91b1a5acbf7fd5b02f-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/0a74136a53ff4c91b1a5acbf7fd5b02f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/68df546b34ba4f0d8f0aca45759f42c1-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/68df546b34ba4f0d8f0aca45759f42c1-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/ad15288e383540d4b6362e8200d0d574-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/ad15288e383540d4b6362e8200d0d574-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/40d3960bc21c46c2941b8317adc78eaf-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/40d3960bc21c46c2941b8317adc78eaf-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/9c760ea8f29a4301a1d5ec9227353f13-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/9c760ea8f29a4301a1d5ec9227353f13-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/cf0a120053d64d0a85efb7fe848af834-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/cf0a120053d64d0a85efb7fe848af834-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bf318275869140d0af1ef24fdc508644-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/bf318275869140d0af1ef24fdc508644-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/59da06438a344027a5bff32300b86f03-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/59da06438a344027a5bff32300b86f03-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/263c54ee290e4568a43dc5a730d2f07f-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/263c54ee290e4568a43dc5a730d2f07f-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/6c790b958f744c57af795dafb9090b9a-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/6c790b958f744c57af795dafb9090b9a-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/17575e9bd99646a48dc30ec128650707-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/17575e9bd99646a48dc30ec128650707-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/69b3ba73f2164f2caaf1e1d42a2b1240-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/69b3ba73f2164f2caaf1e1d42a2b1240-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/a10e7c0af2a44c1da5bfae4a9c386b32-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/a10e7c0af2a44c1da5bfae4a9c386b32-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/d3f84c269b684a1483832749cce585d0-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/d3f84c269b684a1483832749cce585d0-pulp.sol (default strategy 1)
# At line 2 NAME          MODEL
# At line 3 ROWS
# At line 13 COLUMNS
# At line 127 RHS
# At line 136 BOUNDS
# At line 152 ENDATA
# Problem MODEL has 8 rows, 15 columns and 84 elements
# Coin0008I MODEL read with 0 errors
# Option for timeMode changed from cpu to elapsed
# Problem is infeasible - 0.00 seconds
# Option for printingOptions changed from normal to all
# Total time (CPU seconds):       0.00   (Wallclock seconds):       0.00
#
# Welcome to the CBC MILP Solver
# Version: 2.10.3
# Build Date: Dec 15 2019
#
# command line - /home/gykovacs/anaconda3/envs/mlscorecheck/lib/python3.10/site-packages/pulp/solverdir/cbc/linux/64/cbc /tmp/bdbbf3c6f3d846e58a5ba5deaf51d2a1-pulp.mps timeMode elapsed branch printingOptions all solution /tmp/